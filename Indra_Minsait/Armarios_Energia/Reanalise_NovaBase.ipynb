# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import seaborn as sns
import datetime as dt

# %%
PATH = "../Dados/Armarios/Bases/"
FILE = "base_nordeste_V2.csv"

# %%
consumo_macroregioes = pd.read_csv(PATH + FILE, sep = '|')
consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_nordeste_atualizada.', '')
consumo_macroregioes['mes'] = consumo_macroregioes['mes'].astype('string')
consumo_macroregioes.dtypes
# Out:
# C:\Users\TALMEI~1\AppData\Local\Temp/ipykernel_4048/4097695963.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_nordeste_atualizada.', '')
# macroregiao                    object
# uf                             object
# mes                            string
# consumoacumuladodomes_soma    float64
# valortotal_soma               float64
# consumoponta_soma             float64
# consumoforaponta_soma         float64
# demandaconsumida_soma         float64
# dtype: object

# %%
consumo_macroregioes
# Out:
#     macroregiao  uf     mes  consumoacumuladodomes_soma  valortotal_soma  \
# 0            NE  AL  201701                    68556.00         47076.41
# 1            NE  BA  201701                   396122.19        271562.70
# 2            NE  CE  201701                     3789.00          3149.63
# 3            NE  PB  201701                    98214.42         99565.66
# 4            NE  PE  201701                    21423.89         14954.37
# ..          ...  ..     ...                         ...              ...
# 503          NE  PB  202205                    80984.00         74838.27
# 504          NE  PE  202205                    20301.00         15081.12
# 505          NE  PI  202205                     7227.00          7000.97
# 506          NE  RN  202205                    28711.00         29275.28
# 507          NE  SE  202205                    48993.00         53155.08
#
#      consumoponta_soma  consumoforaponta_soma  demandaconsumida_soma
# ...

# %%
consumo_macroregioes['mes'].loc[consumo_macroregioes['uf']=='CE'].tolist()
# Out:
# ['201701',
#  '201702',
#  '201703',
#  '201704',
#  '201705',
#  '201706',
#  '201707',
#  '201708',
#  '201709',
#  '201710',
#  '201711',
#  '201712',
#  '201801',
#  '201802',
#  '201803',
#  '201804',
#  '201805',
#  '201806',
#  '201807',
#  '201808',
#  '201809',
#  '201810',
#  '201811',
#  '201812',
#  '201901',
#  '201902',
#  '201903',
#  '201904',
#  '201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '201911',
#  '201912',
#  '202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105',
#  '202106',
#  '202107',
#  '202108',
#  '202109',
#  '202110',
#  '202111',
#  '202112',
#  '202201',
#  '202202',
#  '202203',
#  '202204',
#  '202205']

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,8))


plot = plt.subplot(2, 1, 1)
ax = sns.lineplot(data=consumo_macroregioes, x="mes", y="consumoacumuladodomes_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")
#plt.show()
leg = plt.legend()

ax.get_legend().set_visible(False)


plot = plt.subplot(2, 1, 2)
sns.lineplot(data=consumo_macroregioes, x="mes", y="valortotal_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.show()

# %%
consumo_macroregioes = pd.read_csv(PATH + 'base_sul.csv', sep = '|')
consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sul_atualizada.', '')
consumo_macroregioes['mes'] = consumo_macroregioes['mes'].astype('string')
# Out:
# C:\Users\TALMEI~1\AppData\Local\Temp/ipykernel_10404/627799176.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sul_atualizada.', '')

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,8))


plot = plt.subplot(2, 1, 1)
ax = sns.lineplot(data=consumo_macroregioes, x="mes", y="consumoacumuladodomes_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")
#plt.show()
leg = plt.legend()

ax.get_legend().set_visible(False)


plot = plt.subplot(2, 1, 2)
sns.lineplot(data=consumo_macroregioes, x="mes", y="valortotal_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.show()

# %%
consumo_macroregioes = pd.read_csv(PATH + 'base_sudeste.csv', sep = '|')
consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sudeste_atualizada.', '')
consumo_macroregioes['mes'] = consumo_macroregioes['mes'].astype('string')
# Out:
# C:\Users\TALMEI~1\AppData\Local\Temp/ipykernel_10404/3075094194.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sudeste_atualizada.', '')

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,8))


plot = plt.subplot(2, 1, 1)
ax = sns.lineplot(data=consumo_macroregioes, x="mes", y="consumoacumuladodomes_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")
#plt.show()
leg = plt.legend()

ax.get_legend().set_visible(False)


plot = plt.subplot(2, 1, 2)
sns.lineplot(data=consumo_macroregioes, x="mes", y="valortotal_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.show()

# %%
consumo_macroregioes = pd.read_csv(PATH + 'base_centrooeste_V2.csv', sep = '|')
consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_centrooeste_atualizada.', '')
consumo_macroregioes['mes'] = consumo_macroregioes['mes'].astype('string')
# Out:
# C:\Users\TALMEI~1\AppData\Local\Temp/ipykernel_10404/1750493115.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_centrooeste_atualizada.', '')

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,8))


plot = plt.subplot(2, 1, 1)
ax = sns.lineplot(data=consumo_macroregioes, x="mes", y="consumoacumuladodomes_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")
#plt.show()
leg = plt.legend()

ax.get_legend().set_visible(False)


plot = plt.subplot(2, 1, 2)
sns.lineplot(data=consumo_macroregioes, x="mes", y="valortotal_soma", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.show()

# %%
consumo_macroregioes = pd.read_csv(PATH + 'contagem_armarios.csv', sep = '|')
#consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sudeste_atualizada.', '')
consumo_macroregioes['mes'] = consumo_macroregioes['mes'].astype('string')
consumo_macroregioes
# Out:
#       contagem  uf macroregiao     mes
# 0          231  DF          CO  201701
# 1          264  GO          CO  201701
# 2           94  MS          CO  201701
# 3           77  MT          CO  201701
# 4           59  AL          NE  201701
# ...        ...  ..         ...     ...
# 1385       359  SC           S  202205
# 1386       182  ES          SE  202205
# 1387       288  MG          SE  202205
# 1388       283  RJ          SE  202205
# 1389       645  SP          SE  202205
#
# [1390 rows x 4 columns]

# %%
consumo_macroregioes_GO = pd.read_csv(PATH + 'contagem_armarios_goias.txt', sep = '|')
#consumo_macroregioes.columns = consumo_macroregioes.columns.str.replace('ml_ca_energia_consumo_armarios_sudeste_atualizada.', '')
consumo_macroregioes_GO['mes'] = consumo_macroregioes_GO['mes'].astype('string')
consumo_macroregioes_GO.drop(['Unnamed: 0', 'Unnamed: 4'], axis = 1, inplace=True)
consumo_macroregioes_GO['macroregiao'] = 'CO'
consumo_macroregioes_GO
# Out:
#     contagem  uf     mes macroregiao
# 0        260  GO  201701          CO
# 1        260  GO  201702          CO
# 2        262  GO  201703          CO
# 3        259  GO  201704          CO
# 4        260  GO  201705          CO
# ..       ...  ..     ...         ...
# 60       271  GO  202201          CO
# 61       268  GO  202202          CO
# 62       264  GO  202203          CO
# 63       264  GO  202204          CO
# 64       264  GO  202205          CO
#
# [65 rows x 4 columns]

# %%
dados = pd.concat([consumo_macroregioes.loc[consumo_macroregioes['uf']!='GO'], consumo_macroregioes_GO], axis=0).sort_values(by = 'mes').sort_values(by = ['mes', 'macroregiao', 'uf'])
dados
# Out:
#       contagem  uf macroregiao     mes
# 0          231  DF          CO  201701
# 0          260  GO          CO  201701
# 2           94  MS          CO  201701
# 3           77  MT          CO  201701
# 4           59  AL          NE  201701
# ...        ...  ..         ...     ...
# 1385       359  SC           S  202205
# 1386       182  ES          SE  202205
# 1387       288  MG          SE  202205
# 1388       283  RJ          SE  202205
# 1389       645  SP          SE  202205
#
# [1390 rows x 4 columns]

# %%
dados.to_csv(PATH + 'dados.txt', index = False)

# %%
dados = pd.read_csv(PATH + 'dados.txt', sep = ',')
dados['mes'] = dados['mes'].astype('string')
dados
# Out:
#       contagem  uf macroregiao     mes
# 0          231  DF          CO  201701
# 1          260  GO          CO  201701
# 2           94  MS          CO  201701
# 3           77  MT          CO  201701
# 4           59  AL          NE  201701
# ...        ...  ..         ...     ...
# 1385       359  SC           S  202205
# 1386       182  ES          SE  202205
# 1387       288  MG          SE  202205
# 1388       283  RJ          SE  202205
# 1389       645  SP          SE  202205
#
# [1390 rows x 4 columns]

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,15))


plot = plt.subplot(4, 1, 1)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='NE'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 2)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='SE'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 3)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='S'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 4)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='CO'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)

plt.show()

# %%
df = pd.read_csv(PATH + 'contagem_df.txt', sep = '|')
df['mes'] = df['mes'].astype('string')
df.drop(['Unnamed: 0', 'Unnamed: 3'], axis = 1, inplace=True)
df
# Out:
#     contagem     mes
# 0         10  201701
# 1         13  201702
# 2         10  201703
# 3         11  201704
# 4         11  201705
# ..       ...     ...
# 60        26  202201
# 61        28  202202
# 62        33  202203
# 63        60  202204
# 64        53  202205
#
# [65 rows x 2 columns]

# %%
fig = plt.figure(figsize=(15,5))
sns.lineplot(data=df, x="mes", y="contagem")
plt.xticks(rotation=90)
plt.show()

# %%
dados_05 = dados.loc[dados['mes']=='202205']
dados_05
# Out:
#       contagem  uf macroregiao     mes
# 1370       174  DF          CO  202205
# 1371       264  GO          CO  202205
# 1372       116  MS          CO  202205
# 1373        74  MT          CO  202205
# 1374         1  AM           N  202205
# 1375        63  AL          NE  202205
# 1376       209  BA          NE  202205
# 1377       145  CE          NE  202205
# 1378        77  PB          NE  202205
# 1379        17  PE          NE  202205
# 1380         4  PI          NE  202205
# 1381        42  RN          NE  202205
# 1382        46  SE          NE  202205
# 1383       730  PR           S  202205
# 1384       486  RS           S  202205
# 1385       359  SC           S  202205
# 1386       182  ES          SE  202205
# 1387       288  MG          SE  202205
# 1388       283  RJ          SE  202205
# 1389       645  SP          SE  202205

# %%
fig = plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace=0.17)


#### Nordeste 

plot = plt.subplot(2, 2, 1)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=dados_05.loc[dados_05['macroregiao'] == 'NE'].sort_values(by='contagem', ascending=False),
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(10+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("Nordeste")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Centro-Oeste 

plot = plt.subplot(2, 2, 2)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=dados_05.loc[dados_05['macroregiao'] == 'CO'].sort_values(by='contagem', ascending=False),
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(10+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("Centro-Oeste")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Sul

plot = plt.subplot(2, 2, 3)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=dados_05.loc[dados_05['macroregiao'] == 'S'].sort_values(by='contagem', ascending=False),
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(30+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("Sul")
plt.xlabel("")
ax.yaxis.label.set_size(20)


#### Sudeste

plot = plt.subplot(2, 2, 4)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=dados_05.loc[dados_05['macroregiao'] == 'SE'].sort_values(by='contagem', ascending=False),
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(30+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("Sudeste")
plt.xlabel("N Armários")
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)


del ax

# %%
df = pd.read_csv(PATH + 'consumos_minimos.txt', sep = '|')
df['mes'] = df['mes'].astype('string')
df.drop(['Unnamed: 0', 'Unnamed: 7'], axis = 1, inplace=True)
df
# Out:
#       contagem  valortotal  consumototal  uf     mes macroregiao
# 0           10     2286.95           0.0  DF  201701          CO
# 1           12      796.09         430.0  GO  201701          CO
# 2           28     6090.38        1150.0  MS  201701          CO
# 3            2      377.08         100.0  RO  201701           N
# 4           10      160.10         300.0  AL  201701          NE
# ...        ...         ...           ...  ..     ...         ...
# 1119        30     1097.56        1354.0  SC  202205           S
# 1120         6      233.08         350.0  ES  202205          SE
# 1121        18      812.77           0.0  MG  202205          SE
# 1122         9     1309.35         580.0  RJ  202205          SE
# 1123        16      820.29         754.0  SP  202205          SE
#
# [1124 rows x 6 columns]

# %%
df_goias = pd.read_csv(PATH + 'consumos_minimos.txt', sep = '|')
df_goias['mes'] = df_goias['mes'].astype('string')
df_goias.drop(['Unnamed: 0', 'Unnamed: 7'], axis = 1, inplace=True)
df_goias
# Out:
#       contagem  valortotal  consumototal  uf     mes macroregiao
# 0           10     2286.95           0.0  DF  201701          CO
# 1           12      796.09         430.0  GO  201701          CO
# 2           28     6090.38        1150.0  MS  201701          CO
# 3            2      377.08         100.0  RO  201701           N
# 4           10      160.10         300.0  AL  201701          NE
# ...        ...         ...           ...  ..     ...         ...
# 1119        30     1097.56        1354.0  SC  202205           S
# 1120         6      233.08         350.0  ES  202205          SE
# 1121        18      812.77           0.0  MG  202205          SE
# 1122         9     1309.35         580.0  RJ  202205          SE
# 1123        16      820.29         754.0  SP  202205          SE
#
# [1124 rows x 6 columns]

# %%
dados = pd.concat([df.loc[df['uf']!='GO'], df_goias], axis=0).sort_values(by = 'mes').sort_values(by = ['mes', 'macroregiao', 'uf'])
dados
# Out:
#       contagem  valortotal  consumototal  uf     mes macroregiao
# 0           10     2286.95           0.0  DF  201701          CO
# 0           10     2286.95           0.0  DF  201701          CO
# 1           12      796.09         430.0  GO  201701          CO
# 2           28     6090.38        1150.0  MS  201701          CO
# 2           28     6090.38        1150.0  MS  201701          CO
# ...        ...         ...           ...  ..     ...         ...
# 1121        18      812.77           0.0  MG  202205          SE
# 1122         9     1309.35         580.0  RJ  202205          SE
# 1122         9     1309.35         580.0  RJ  202205          SE
# 1123        16      820.29         754.0  SP  202205          SE
# 1123        16      820.29         754.0  SP  202205          SE
#
# [2183 rows x 6 columns]

# %%
dados.to_csv(PATH + 'dados.txt', index = False)
dados = pd.read_csv(PATH + 'dados.txt', sep = ',')
dados['mes'] = dados['mes'].astype('string')
dados
# Out:
#       contagem  valortotal  consumototal  uf     mes macroregiao
# 0           10     2286.95           0.0  DF  201701          CO
# 1           10     2286.95           0.0  DF  201701          CO
# 2           12      796.09         430.0  GO  201701          CO
# 3           28     6090.38        1150.0  MS  201701          CO
# 4           28     6090.38        1150.0  MS  201701          CO
# ...        ...         ...           ...  ..     ...         ...
# 2178        18      812.77           0.0  MG  202205          SE
# 2179         9     1309.35         580.0  RJ  202205          SE
# 2180         9     1309.35         580.0  RJ  202205          SE
# 2181        16      820.29         754.0  SP  202205          SE
# 2182        16      820.29         754.0  SP  202205          SE
#
# [2183 rows x 6 columns]

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,15))


plot = plt.subplot(4, 1, 1)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='NE'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 2)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='SE'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 3)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='S'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 4)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='CO'], x="mes", y="contagem", hue="uf", style="uf")
plt.xticks(rotation=90)

plt.show()

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,15))


plot = plt.subplot(4, 1, 1)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='NE'], x="mes", y="consumototal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 2)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='SE'], x="mes", y="consumototal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 3)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='S'], x="mes", y="consumototal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 4)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='CO'], x="mes", y="consumototal", hue="uf", style="uf")
plt.xticks(rotation=90)

plt.show()

# %%
plt.subplots_adjust(wspace=0.17)
fig = plt.figure(figsize=(15,15))


plot = plt.subplot(4, 1, 1)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='NE'], x="mes", y="valortotal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 2)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='SE'], x="mes", y="valortotal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 3)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='S'], x="mes", y="valortotal", hue="uf", style="uf")
plt.xticks(rotation=90)
plt.xlabel("")
plt.xticks("")


plot = plt.subplot(4, 1, 4)
ax = sns.lineplot(data=dados.loc[dados['macroregiao']=='CO'], x="mes", y="valortotal", hue="uf", style="uf")
plt.xticks(rotation=90)

plt.show()

# %%
df = pd.read_csv('C:/Users/talmeidar/Documents/Energia/Dados/Armarios/Cenarios_Novos/2019_a_2022_diferenca_direta_consumo_minimo_2022.txt', sep = '\t')
df
# Out:
#     contagem  uf
# 0          5  AL
# 1          1  BA
# 2          1  PE
# 3          1  CE
# 4          5  PB
# 5          4  RN
# 6          2  MT
# 7          7  GO
# 8          2  MS
# 9         26  DF
# 10         6  SP
# 11         3  ES
# 12         6  MG
# 13        15  RJ
# 14        16  PR
# 15        12  SC
# 16        23  RS

# %%
plt.figure(figsize=(25, 5))

ax = sns.barplot(x = 'uf', y = 'contagem', data = df)

plt.xticks(rotation=90, fontsize = 15)
plt.yticks(fontsize = 15)

for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + 0.3, p.get_height() + 1), fontsize = 15)
    
ax.set(xlabel='Estados', ylabel='Número de Armários')
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)

plt.show()

# %%
df = pd.read_csv('C:/Users/talmeidar/Documents/Energia/Dados/Armarios/Cenarios_Novos/aumento_2018_a_2022_diferenca_direta.txt', sep = '\t')
df
# Out:
#     contagem range_percentual  uf
# 0          1          20%-30%  BA
# 1          1          20%-30%  RN
# 2          1          20%-30%  CE
# 3          1          20%-30%  PI
# 4          3          20%-30%  MS
# 5          1          20%-30%  GO
# 6          3          20%-30%  ES
# 7          1          20%-30%  MG
# 8          5          20%-30%  RJ
# 9          5          20%-30%  PR
# 10         5          20%-30%  RS
# 11         1          31%-40%  AL
# 12         1          31%-40%  SE
# 13         1          31%-40%  CE
# 14         2          31%-40%  GO
# 15         1          31%-40%  MG
# 16         1          31%-40%  RJ
# 17         3          31%-40%  PR
# 18         2          31%-40%  SC
# 19         2          31%-40%  RS
# 20         5             41%>  AL
# 21         4             41%>  BA
# 22         2             41%>  SE
# 23         2             41%>  CE
# 24         1             41%>  PB
# 25         1             41%>  PE
# ...

# %%
plt.figure(figsize=(15, 3))

ax = sns.barplot(x = 'uf', y = 'contagem', data = df.loc[df['range_percentual'] == '20%-30%'])

plt.xticks(rotation=90, fontsize = 15)
plt.yticks(fontsize = 15)

for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + 0.3, p.get_height() + 0.1), fontsize = 15)
    
ax.set(xlabel='Estados', ylabel='Número de Armários')
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)

plt.show()

# %%
fig = plt.figure(figsize=(20,5))
plt.subplots_adjust(wspace=0.30)


#### Nordeste 

plot = plt.subplot(1, 3, 1)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '20%-30%'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(0.1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("20%-30%")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Centro-Oeste 

plot = plt.subplot(1, 3, 2)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '31%-40%'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(0.1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("31%-40%")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Sul

plot = plt.subplot(1, 3, 3)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '41%>'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(1.2+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("41%>")
plt.xlabel("")
ax.yaxis.label.set_size(20)


plt.grid(False)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)


del ax

# %%
df['contagem'].sum()
# Out:
# 227

# %%
df = pd.read_csv('C:/Users/talmeidar/Documents/Energia/Dados/Armarios/Cenarios_Novos/aumento_2021_a_2022.txt', sep = '\t')
df
# Out:
#     contagem range_percentual  uf
# 0          2          20%-30%  BA
# 1          2          20%-30%  PE
# 2          1          20%-30%  PI
# 3          2          20%-30%  PB
# 4         36          20%-30%  DF
# 5          3          20%-30%  GO
# 6          2          20%-30%  MT
# 7          1          20%-30%  MS
# 8          3          20%-30%  ES
# 9          1          20%-30%  MG
# 10         2          20%-30%  RJ
# 11         4          20%-30%  PR
# 12         5          20%-30%  SC
# 13         7          20%-30%  RS
# 14         1          31%-40%  SE
# 15        24          31%-40%  DF
# 16         1          31%-40%  MS
# 17         2          31%-40%  ES
# 18         2          31%-40%  MG
# 19         5          31%-40%  PR
# 20         2          31%-40%  SC
# 21         7          31%-40%  RS
# 22         1             41%>  AL
# 23         2             41%>  BA
# 24         5             41%>  CE
# 25         2             41%>  SE
# ...

# %%
fig = plt.figure(figsize=(20,5))
plt.subplots_adjust(wspace=0.30)


#### Nordeste 

plot = plt.subplot(1, 3, 1)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '20%-30%'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("20%-30%")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Centro-Oeste 

plot = plt.subplot(1, 3, 2)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '31%-40%'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(1+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("31%-40%")
plt.xlabel("")

ax.yaxis.label.set_size(20)

#### Sul

plot = plt.subplot(1, 3, 3)

ax = sns.barplot(
    x='contagem', 
    y='uf', 
    data=df.loc[df['range_percentual'] == '41%>'],
    palette='Set2', orient='h'
)

for p in ax.patches:
    width = p.get_width()
    plt.text(1.2+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:.0f}'.format(width),
             ha='center', va='center')

plt.grid(False)
plt.ylabel("41%>")
plt.xlabel("")
ax.yaxis.label.set_size(20)


plt.grid(False)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)


del ax
