# %%
## data
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.relativedelta import relativedelta
from unicodedata import normalize

## vis
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# contagem de aging
from collections import Counter

from IPython.display import display, HTML

## modelo
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# check xgboost version
from xgboost import XGBClassifier

## alertas
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***
# ## Coleta de dados

# %%
FILE = "/kaggle/input/datasetsnew/batdtfim500kage.csv"
dados = pd.read_csv(FILE, sep = ';', encoding = 'ISO-8859-1', engine ='python')

dados = dados.rename(columns={'a.msisdn': 'msisdn'})\
             .rename(columns={'a.imsi': 'imsi'})\
             .rename(columns={'a.tac': 'tac'})\
             .rename(columns={'a.dt_inicio': 'dt_inicio'})\
             .rename(columns={'a.dt_fim': 'dt_fim'})\
             .rename(columns={'a.aging_aparelho': 'aging_aparelho'})\
             .rename(columns={'a.cat_aparelho': 'cat_aparelho'})\
             .rename(columns={'a.trocou_aparelho': 'trocou_aparelho'})\
             .rename(columns={'a.fabricante': 'fabricante'})\
             .rename(columns={'a.modelo': 'modelo'})\
             .rename(columns={'a.imei': 'imei'})\
             .rename(columns={'a.ranking': 'ranking'})\
             .rename(columns={'a.cpfidentifier': 'cpfidentifier'})\
             .rename(columns={'a.subscriberkey': 'subscriberkey'})\
             .rename(columns={'a.customerkey': 'customerkey'})\
             .rename(columns={'a.customersubtypedesc': 'customersubtypedesc'})\
             .rename(columns={'a.subscriberstatuskey': 'subscriberstatuskey'})\
             .rename(columns={'a.offertechnology': 'offertechnology'})\
             .rename(columns={'a.citydesc': 'citydesc'})\
             .rename(columns={'a.statedesc': 'statedesc'})\
             .rename(columns={'a.subscribermainofferdesc': 'subscribermainofferdesc'})\
             .rename(columns={'a.assignedchargeamount': 'assignedchargeamount'})\
             .rename(columns={'a.fl_3g': 'fl_3g'})\
             .rename(columns={'a.fl_4g': 'fl_4g'})\
             .rename(columns={'a.fl_5g': 'fl_5g'})\
             .rename(columns={'a.dt_ano_stts': 'dt_ano_stts'})\
             .rename(columns={'a.idade': 'idade'})\

dados = dados[dados['offertechnology'] == 'PostPaid']

dados
# Out:
#                msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0       5532998068556  724235404829984  35415808  2021-02-17  2022-04-09
# 2       5555999595054  724065007509989  35175119  2021-03-31         NaN
# 5       5514997573988  724102006884141  35855882  2021-02-21  2022-03-28
# 7       5535999691624  724233610358155  35267276  2021-03-25         NaN
# 8       5592994714026  724119792517930  35729112  2021-07-16         NaN
# ...               ...              ...       ...         ...         ...
# 499974  5544991136960  724064006631425  35721410  2021-07-14         NaN
# 499984  5565999036799  724066612247984  35531751  2021-09-23         NaN
# 499994  5519981197556  724102293424867  35057056  2021-04-11         NaN
# 499995  5541992819276  724064006643479  35892323  2021-05-06         NaN
# 499998  5561982989551  724066490746154  35614110  2021-10-15         NaN
#
#         aging_aparelho  cat_aparelho  trocou_aparelho  \
# 0                   13             1                1
# 2                   18             1                0
# 5                   13             1                1
# 7                   18             1                0
# 8                   15             1                0
# ...                ...           ...              ...
# 499974              15             1                0
# 499984              12             1                0
# 499994              18             1                0
# 499995              17             1                0
# 499998              12             1                0
#
#                                      fabricante  \
# 0                                       SAMSUNG
# 2                                       SAMSUNG
# 5                                 Samsung Korea
# 7                                         APPLE
# 8                                            LG
# ...                                         ...
# 499974  Motorola Mobility LLC, a Lenovo Company
# 499984                                  SAMSUNG
# 499994                                  SAMSUNG
# 499995                            Samsung Korea
# 499998                                  SAMSUNG
#
#                                   modelo  ... offertechnology  citydesc  \
# 0          GALAXY J7 PRIME (SM-G610M DS)  ...        PostPaid       NaN
# 2       GALAXY S21 PLUS 5G (SM-G996B,DS)  ...        PostPaid       NaN
# 5                          GALAXY S20 FE  ...        PostPaid       NaN
# 7                      IPHONE 11 (A2221)  ...        PostPaid       NaN
# 8                             LM-K420BMW  ...        PostPaid       NaN
# ...                                  ...  ...             ...       ...
# 499974             MOTO E PLAY (5TH GEN)  ...        PostPaid       NaN
# 499984  GALAXY S21 PLUS 5G (SM-G996B,DS)  ...        PostPaid       NaN
# 499994  GALAXY S21 PLUS 5G (SM-G996B,DS)  ...        PostPaid       NaN
# 499995                     GALAXY A52 5G  ...        PostPaid       NaN
# 499998         GALAXY A30 (SM-A305GT,DS)  ...        PostPaid       NaN
#
#                 statedesc                        subscribermainofferdesc  \
# 0            MINAS GERAIS            LINHA ADICIONAL VIVO FAMÃLIA 150GB
# 2       RIO GRANDE DO SUL             LINHA ADICIONAL VIVO FAMILIA 100GB
# 5               SAO PAULO                     TITULAR VIVO PÃS MIG_20GB
# 7            MINAS GERAIS  LINHA ADICIONAL VIVO FAMILIA 20GB+220GB BONUS
# 8                AMAZONAS                 TITULAR VIVO POS 30GB - MENSAL
# ...                   ...                                            ...
# 499974             PARANA             LINHA ADICIONAL VIVO FAMILIA 200GB
# 499984        MATO GROSSO                     TITULAR VIVO FAMILIA 200GB
# 499994          SAO PAULO             TITULAR VIVO SELFIE GLOBOPLAY 30GB
# 499995             PARANA             LINHA ADICIONAL VIVO FAMILIA 150GB
# 499998   DISTRITO FEDERAL             TITULAR VIVO FAMILIA 60GB - MENSAL
#
#         assignedchargeamount fl_3g fl_4g fl_5g  dt_ano_stts idade
# 0                       0.00   0.0   1.0   0.0       2016.0    31
# 2                       0.00   0.0   0.0   1.0       2020.0    56
# 5                     103.16   0.0   1.0   0.0       2020.0    35
# 7                       0.00   0.0   1.0   0.0       2020.0    55
# 8                      32.11   0.0   1.0   0.0       2021.0    55
# ...                      ...   ...   ...   ...          ...   ...
# 499974                 62.99   0.0   1.0   0.0       2019.0    38
# 499984                471.99   0.0   0.0   1.0       2020.0    29
# 499994                134.99   0.0   0.0   1.0       2020.0    69
# 499995                  0.00   0.0   0.0   1.0       2020.0    63
# 499998                234.99   0.0   1.0   0.0       2019.0    51
#
# [141227 rows x 27 columns]

# %% [markdown]
# ### Limpeza dos dados

# %%
def just_check_nan(df):
    # Check NaN Pandas and Numpy
    missing_val_count_by_column = (df.isna().sum())

    columns_with_nan = missing_val_count_by_column[missing_val_count_by_column > 0]
    print('Dados com NaN:')
    print(columns_with_nan)
    print('')
    print('columns_with_nan.shape', columns_with_nan.shape)
    print('')

# %%
just_check_nan(dados)
# Out:
# Dados com NaN:
# dt_fim                     114974
# citydesc                   141227
# statedesc                      61
# subscribermainofferdesc       698
# assignedchargeamount          683
# fl_3g                          38
# fl_4g                          38
# fl_5g                          38
# dt_ano_stts                    38
# dtype: int64
#
# columns_with_nan.shape (9,)

# %%
dados_droped = dados.dropna(subset=['imsi',
                                    'statedesc', 
                                    'subscribermainofferdesc', 
                                    'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts'])\
                    .reset_index(drop=True)
# dados_droped

# %%
just_check_nan(dados_droped)
# Out:
# Dados com NaN:
# dt_fim      114552
# citydesc    140413
# dtype: int64
#
# columns_with_nan.shape (2,)

# %% [markdown]
# ### Equilibrando classes

# %%
dados_droped_0 = dados_droped[dados_droped['trocou_aparelho'] == 0].sample(frac=0.53, random_state=3)
dados_droped_1 = dados_droped[dados_droped['trocou_aparelho'] == 1]

# %%
dados_droped = pd.concat([dados_droped_0, dados_droped_1]).reset_index(drop=True).sort_values(by='msisdn', ascending=False)
dados_droped
# Out:
#               msisdn             imsi       tac   dt_inicio      dt_fim  \
# 80189  5599999778280  724119113878348  35768964  2021-05-17  2022-05-19
# 59203  5599999778280  724119113878348  35768964  2021-05-17  2022-05-19
# 78467  5599999770208  724119112384725  35767712  2021-05-04  2022-05-17
# 12464  5599999530131  724119114015020  35260709  2021-07-09         NaN
# 86032  5599999514361  724119896599952  35734809  2021-01-08  2022-02-09
# ...              ...              ...       ...         ...         ...
# 19540  5511910007006  724102008238085  35179738  2021-04-12         NaN
# 65219  5511910003326  724102090904887  35187408  2021-02-03  2022-05-02
# 29886  5511910001745  724102802140721  35188909  2021-09-21         NaN
# 22621  5511910001745  724102802140721  35188909  2021-09-21         NaN
# 68604  5511910001363  724102007216056  35470311  2021-02-19  2022-04-17
#
#        aging_aparelho  cat_aparelho  trocou_aparelho  \
# 80189              12             1                1
# 59203              12             1                1
# 78467              12             1                1
# 12464              15             1                0
# 86032              13             1                1
# ...               ...           ...              ...
# 19540              18             1                0
# 65219              14             1                1
# 29886              12             1                0
# 22621              12             1                0
# 68604              13             1                1
#
#                                     fabricante                         modelo  \
# 80189                            Samsung Korea         GALAXY NOTE20 ULTRA 5G
# 59203                            Samsung Korea         GALAXY NOTE20 ULTRA 5G
# 78467                                    APPLE      IPHONE 12 PRO MAX (A2411)
# 12464                                  SAMSUNG  GALAXY J7 PRIME (SM-G610M DS)
# 86032                                    APPLE              IPHONE XR (A1984)
# ...                                        ...                            ...
# 19540                                  SAMSUNG          GALAXY A01 (SM-A015M)
# 65219  Motorola Mobility LLC, a Lenovo Company   MOTO G (4TH GEN), AF12788145
# 29886                                 MOTOROLA     MOTOROLA MOTO G5S (XT1792)
# 22621                                 MOTOROLA     MOTOROLA MOTO G5S (XT1792)
# 68604                                  SAMSUNG      GALAXY A71 (SM-A715F,DSM)
#
#        ... offertechnology  citydesc  statedesc  \
# 80189  ...        PostPaid       NaN   MARANHAO
# 59203  ...        PostPaid       NaN   MARANHAO
# 78467  ...        PostPaid       NaN   MARANHAO
# 12464  ...        PostPaid       NaN   MARANHAO
# 86032  ...        PostPaid       NaN   MARANHAO
# ...    ...             ...       ...        ...
# 19540  ...        PostPaid       NaN  SAO PAULO
# 65219  ...        PostPaid       NaN  SAO PAULO
# 29886  ...        PostPaid       NaN  SAO PAULO
# 22621  ...        PostPaid       NaN  SAO PAULO
# 68604  ...        PostPaid       NaN  SAO PAULO
#
#                          subscribermainofferdesc  assignedchargeamount fl_3g  \
# 80189  TITULAR VIVO SELFIE - AMAZON PRIME - 20GB                109.99   0.0
# 59203  TITULAR VIVO SELFIE - AMAZON PRIME - 20GB                109.99   0.0
# 78467                     LINHA ADICIONAL VIVO V                  0.00   0.0
# 12464         LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00   0.0
# 86032         LINHA ADICIONAL VIVO FAMILIA 100GB                  0.00   0.0
# ...                                          ...                   ...   ...
# 19540    Linha Adicional Plano PÃ³s Vivo V 600GB                  0.00   0.0
# 65219               Titular INTERNET_MOVEL_100GB                112.30   0.0
# 29886         LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00   0.0
# 22621         LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00   0.0
# 68604                  TITULAR VIVO FAMILIA 60GB                235.13   0.0
#
#       fl_4g fl_5g  dt_ano_stts idade
# 80189   0.0   1.0       2020.0    63
# 59203   0.0   1.0       2020.0    63
# 78467   0.0   1.0       2020.0    29
# 12464   1.0   0.0       2017.0    30
# 86032   1.0   0.0       2018.0    60
# ...     ...   ...          ...   ...
# 19540   1.0   0.0       2020.0    48
# 65219   1.0   0.0       2016.0    48
# 29886   1.0   0.0       2017.0    36
# 22621   1.0   0.0       2017.0    36
# 68604   1.0   0.0       2019.0    60
#
# [88077 rows x 27 columns]

# %%
# checando balanço das classes
y_trocou_aparelho = dados_droped['trocou_aparelho']

c_trocou_aparelho = Counter(y_trocou_aparelho)
c_trocou_aparelho
# Out:
# Counter({1: 29060, 0: 59017})

# %%
dados_droped = dados_droped.tail(dados_droped.shape[0] -70000).reset_index(drop=True)
dados_droped['dt_ano_stts'] = dados_droped['dt_ano_stts'].astype(np.int64).reset_index(drop=True)
# dados_droped2 = dados_droped[dados_droped['trocou_aparelho'] == 1].reset_index()
dados_droped
# Out:
#               msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0      5513991038448  724102596295320  35411609  2021-02-04  2022-04-11
# 1      5513991036083  724102111954489  35645410  2021-08-15         NaN
# 2      5513991030514  724101890587888  35308810  2021-10-09         NaN
# 3      5513991024700  724102004684244  35787982  2021-07-04         NaN
# 4      5513991020962  724102293740407  86630005  2021-06-19         NaN
# ...              ...              ...       ...         ...         ...
# 18072  5511910007006  724102008238085  35179738  2021-04-12         NaN
# 18073  5511910003326  724102090904887  35187408  2021-02-03  2022-05-02
# 18074  5511910001745  724102802140721  35188909  2021-09-21         NaN
# 18075  5511910001745  724102802140721  35188909  2021-09-21         NaN
# 18076  5511910001363  724102007216056  35470311  2021-02-19  2022-04-17
#
#        aging_aparelho  cat_aparelho  trocou_aparelho  \
# 0                  14             1                1
# 1                  14             1                0
# 2                  12             1                0
# 3                  15             1                0
# 4                  16             1                0
# ...               ...           ...              ...
# 18072              18             1                0
# 18073              14             1                1
# 18074              12             1                0
# 18075              12             1                0
# 18076              13             1                1
#
#                                     fabricante                        modelo  \
# 0                                     MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 1                                        APPLE             IPHONE XR (A2105)
# 2                                        APPLE             IPHONE XR (A2105)
# 3                                        APPLE             IPHONE 11 (A2221)
# 4                                       XIAOMI          REDMI 9A (M2006C3LI)
# ...                                        ...                           ...
# 18072                                  SAMSUNG         GALAXY A01 (SM-A015M)
# 18073  Motorola Mobility LLC, a Lenovo Company  MOTO G (4TH GEN), AF12788145
# 18074                                 MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 18075                                 MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 18076                                  SAMSUNG     GALAXY A71 (SM-A715F,DSM)
#
#        ... offertechnology  citydesc  statedesc  \
# 0      ...        PostPaid       NaN  SAO PAULO
# 1      ...        PostPaid       NaN  SAO PAULO
# 2      ...        PostPaid       NaN  SAO PAULO
# 3      ...        PostPaid       NaN  SAO PAULO
# 4      ...        PostPaid       NaN  SAO PAULO
# ...    ...             ...       ...        ...
# 18072  ...        PostPaid       NaN  SAO PAULO
# 18073  ...        PostPaid       NaN  SAO PAULO
# 18074  ...        PostPaid       NaN  SAO PAULO
# 18075  ...        PostPaid       NaN  SAO PAULO
# 18076  ...        PostPaid       NaN  SAO PAULO
#
#                         subscribermainofferdesc  assignedchargeamount fl_3g  \
# 0              Titular Vivo PÃ³s FamÃ­lia 120GB                138.99   0.0
# 1      TITULAR VIVO SELFIE SPOTIFY PREMIUM 30GB                129.99   0.0
# 2            TITULAR VIVO SELFIE ESSENCIAL 20GB                101.99   0.0
# 3                    TITULAR VIVO FAMILIA 100GB                319.99   0.0
# 4                   TITULAR PLANO VIVO_POS 30GB                134.99   0.0
# ...                                         ...                   ...   ...
# 18072   Linha Adicional Plano PÃ³s Vivo V 600GB                  0.00   0.0
# 18073              Titular INTERNET_MOVEL_100GB                112.30   0.0
# 18074        LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00   0.0
# 18075        LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00   0.0
# 18076                 TITULAR VIVO FAMILIA 60GB                235.13   0.0
#
#       fl_4g fl_5g  dt_ano_stts idade
# 0       1.0   0.0         2017    58
# 1       1.0   0.0         2019    20
# 2       1.0   0.0         2018    39
# 3       1.0   0.0         2020    32
# 4       1.0   0.0         2020    61
# ...     ...   ...          ...   ...
# 18072   1.0   0.0         2020    48
# 18073   1.0   0.0         2016    48
# 18074   1.0   0.0         2017    36
# 18075   1.0   0.0         2017    36
# 18076   1.0   0.0         2019    60
#
# [18077 rows x 27 columns]

# %%
dados_droped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18077 entries, 0 to 18076
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   msisdn                   18077 non-null  int64
#  1   imsi                     18077 non-null  int64
#  2   tac                      18077 non-null  int64
#  3   dt_inicio                18077 non-null  object
#  4   dt_fim                   5068 non-null   object
#  5   aging_aparelho           18077 non-null  int64
#  6   cat_aparelho             18077 non-null  int64
#  7   trocou_aparelho          18077 non-null  int64
#  8   fabricante               18077 non-null  object
#  9   modelo                   18077 non-null  object
#  10  imei                     18077 non-null  object
#  11  ranking                  18077 non-null  int64
#  12  cpfidentifier            18077 non-null  int64
#  13  subscriberkey            18077 non-null  int64
#  14  customerkey              18077 non-null  int64
#  15  customersubtypedesc      18077 non-null  object
#  16  subscriberstatuskey      18077 non-null  object
#  17  offertechnology          18077 non-null  object
#  18  citydesc                 0 non-null      float64
#  19  statedesc                18077 non-null  object
#  20  subscribermainofferdesc  18077 non-null  object
#  21  assignedchargeamount     18077 non-null  float64
#  22  fl_3g                    18077 non-null  float64
#  23  fl_4g                    18077 non-null  float64
#  24  fl_5g                    18077 non-null  float64
#  25  dt_ano_stts              18077 non-null  int64
#  26  idade                    18077 non-null  int64
# dtypes: float64(5), int64(12), object(10)
# memory usage: 3.7+ MB

# %% [markdown]
# ***
# ### Analise individual

# %%
dados_droped['cat_aparelho'].unique()
# Out:
# array([1])

# %%
dados_droped['trocou_aparelho'].unique()
# Out:
# array([1, 0])

# %%
dados_droped['aging_aparelho'].unique()
# Out:
# array([14, 12, 15, 16, 13, 17, 18])

# %%
dados_droped['customersubtypedesc'].unique()
# Out:
# array(['Pessoa FÃ\xadsica'], dtype=object)

# %%
dados_droped['subscriberstatuskey'].unique()
# Out:
# array(['A'], dtype=object)

# %%
dados_droped['ranking'].unique()
# Out:
# array([1, 2])

# %%
dados_droped['assignedchargeamount'].unique()
# Out:
# array([ 138.99,  129.99,  101.99,  319.99,  134.99,   60.82,  109.99,
#         115.  ,    0.  ,  150.51,   94.01,  159.99,   88.99,  876.7 ,
#         127.64,  112.3 ,   98.99,  158.99,  169.99,  235.13,  299.99,
#         168.99,   92.99,  283.42,   62.99,  629.99,   48.99,  529.99,
#         590.63,  119.99,  126.98,  308.99,   14.9 ,   99.99,   64.  ,
#         103.16,  124.  ,   83.89,  106.  ,  101.1 ,  399.99,  113.92,
#         489.99,  338.99,   96.99,  318.99,  288.99,  960.7 ,  429.98,
#         107.91,   94.99,  369.89,  173.89,  124.99,  208.99,  139.99,
#          91.6 ,  121.63,   73.16,   77.2 ,  176.26,   64.01,  238.99,
#          69.99,  244.36,  117.99,  223.13,  -11.19,  189.99,  126.02,
#         840.7 ,  852.01,  132.99,   49.99, 1179.99,   44.99,  170.5 ,
#         249.99,  394.99,   80.08,   30.  ,  263.99,  239.98,  124.98,
#          60.19,  269.8 ,  329.98,  100.2 ,   66.5 ,  265.12,  886.81,
#         219.98,  179.23,   14.99,    9.99,  429.99,  167.98, 2190.98,
#         129.98,  234.99,   78.99,  229.99,   68.99,  264.  ,   19.99,
#        1068.99,  112.27,  291.76,  362.38,  268.96,  632.71,   86.88,
#         491.98,   29.9 ,  283.99,  323.56,  154.98,  114.36,   56.52,
#         319.98,  269.98,  255.12,  294.99,  220.42,  115.23,   98.46,
#          77.43,  255.38,  137.63,  188.89, 1299.99,   80.81,  159.66,
#         187.99,  149.99, 1188.99,   76.  ,  104.99,  179.98,   82.99,
#         171.6 ,  519.98,  277.01,  144.98,  559.98,   43.99,   87.8 ,
#         179.99,  189.98,   41.41,   73.17,   95.02,   84.  ,  113.89,
#         110.  ,  426.89,   79.38,  137.89,  856.48,  527.99,  139.98,
#         178.99,  247.99,   61.14,  551.98,  164.99,  190.09,  218.89,
#          76.84,   71.38,  154.99,  199.98,   37.32,  896.92,  108.99,
#         285.03,  162.29,  249.98,   74.8 ,  141.75,   39.99,  162.98,
#          87.99,  137.7 ,   48.57,  148.99,  172.29,  210.5 ,   64.49,
#          88.5 ,  135.37,  295.12,  317.99,  -31.49,  151.98,  143.99,
#         132.48,   84.9 ,   94.2 ,  189.9 ,  818.08,  259.26,  339.98,
#         259.98,  583.51,  237.99,  -32.19,  489.98,   95.7 ,   38.57,
#         122.29,  193.99,   65.34,  214.  ,  252.92,  -49.69,  144.99,
#         115.97,  136.  ,   49.9 ,  144.9 ,  519.89,  972.01,  114.99,
#          87.19,  343.41,  120.04,  147.63,  250.78,  404.89,  114.  ,
#         459.98,  149.89,  941.38,  264.36,   39.9 ,  142.89,  108.98,
#          85.3 ,  163.99,   93.89,  193.89,   52.68,  362.37,   94.6 ,
#          29.99,  270.12,  128.98, 1174.99,  111.78,  146.02,  -18.89,
#         169.84,   71.15,  194.98,   59.99,  358.89,  285.12,  111.98,
#         159.98,  153.89,  152.98,   49.  ,  110.07,  114.98,   32.01,
#         121.98,   95.21,  119.98,   86.34,  207.3 ,  101.51,  128.99,
#          56.34,   89.99,   41.14,  352.96,  118.99,  185.62,  272.92,
#         208.08,   82.8 ,  126.67,  174.99,  153.64,   75.  ,  179.51,
#          63.89,   96.4 ,   48.41,  368.98,   31.82,   50.3 ,  357.76,
#         105.99,  100.61,  140.34,  211.61,  128.89,   65.7 ])

# %%
dados_droped['fl_3g'].equals(dados_droped['fl_4g'])
# Out:
# False

# %%
dados_droped['fl_3g'].equals(dados_droped['fl_5g'])
# Out:
# False

# %%
dados_droped['fl_4g'].equals(dados_droped['fl_5g'])
# Out:
# False

# %%
dados_droped['trocou_aparelho'].unique()
# Out:
# array([1, 0])

# %%
dados_droped['idade'].unique()
# Out:
# array([ 58,  20,  39,  32,  61,  66,  54,  43,  33,  52,  31,  59,  41,
#         29,  27,  45,  28,  67,  42,  22,  36,  40,  37,  60,  56,  49,
#         62,  70,  34,  69,  48,  38,  46,  50,  35,  55,  93,  71,  72,
#         64,  26,  51,  68,  47,  63,  53,  57,  44,  25,  30,  83,  65,
#         24,  74,  73,  80,  79,  78,  82,  75,  21,  76,  86,  89,  77,
#         87,  23,  81,  19,  84,  88, 122,   2,  90,  85,  92, 150,   0,
#        146,   1,  12,  18, 101])

# %% [markdown]
# ***
# ## Exploração dos dados

# %% [markdown]
# ### seleção de features

# %%
# define features
X_ta = dados_droped[['fabricante', 'modelo', 'ranking', 'aging_aparelho', 
                     'offertechnology', 
                     'statedesc', 'subscribermainofferdesc', 'assignedchargeamount', 
                     'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']]
X_ta
# Out:
#                                     fabricante                        modelo  \
# 0                                     MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 1                                        APPLE             IPHONE XR (A2105)
# 2                                        APPLE             IPHONE XR (A2105)
# 3                                        APPLE             IPHONE 11 (A2221)
# 4                                       XIAOMI          REDMI 9A (M2006C3LI)
# ...                                        ...                           ...
# 18072                                  SAMSUNG         GALAXY A01 (SM-A015M)
# 18073  Motorola Mobility LLC, a Lenovo Company  MOTO G (4TH GEN), AF12788145
# 18074                                 MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 18075                                 MOTOROLA    MOTOROLA MOTO G5S (XT1792)
# 18076                                  SAMSUNG     GALAXY A71 (SM-A715F,DSM)
#
#        ranking  aging_aparelho offertechnology  statedesc  \
# 0            1              14        PostPaid  SAO PAULO
# 1            1              14        PostPaid  SAO PAULO
# 2            1              12        PostPaid  SAO PAULO
# 3            1              15        PostPaid  SAO PAULO
# 4            1              16        PostPaid  SAO PAULO
# ...        ...             ...             ...        ...
# 18072        1              18        PostPaid  SAO PAULO
# 18073        1              14        PostPaid  SAO PAULO
# 18074        1              12        PostPaid  SAO PAULO
# 18075        1              12        PostPaid  SAO PAULO
# 18076        1              13        PostPaid  SAO PAULO
#
#                         subscribermainofferdesc  assignedchargeamount  fl_3g  \
# 0              Titular Vivo PÃ³s FamÃ­lia 120GB                138.99    0.0
# 1      TITULAR VIVO SELFIE SPOTIFY PREMIUM 30GB                129.99    0.0
# 2            TITULAR VIVO SELFIE ESSENCIAL 20GB                101.99    0.0
# 3                    TITULAR VIVO FAMILIA 100GB                319.99    0.0
# 4                   TITULAR PLANO VIVO_POS 30GB                134.99    0.0
# ...                                         ...                   ...    ...
# 18072   Linha Adicional Plano PÃ³s Vivo V 600GB                  0.00    0.0
# 18073              Titular INTERNET_MOVEL_100GB                112.30    0.0
# 18074        LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00    0.0
# 18075        LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00    0.0
# 18076                 TITULAR VIVO FAMILIA 60GB                235.13    0.0
#
#        fl_4g  fl_5g  dt_ano_stts  idade
# 0        1.0    0.0         2017     58
# 1        1.0    0.0         2019     20
# 2        1.0    0.0         2018     39
# 3        1.0    0.0         2020     32
# 4        1.0    0.0         2020     61
# ...      ...    ...          ...    ...
# 18072    1.0    0.0         2020     48
# 18073    1.0    0.0         2016     48
# 18074    1.0    0.0         2017     36
# 18075    1.0    0.0         2017     36
# 18076    1.0    0.0         2019     60
#
# [18077 rows x 13 columns]

# %%
X_ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18077 entries, 0 to 18076
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fabricante               18077 non-null  object
#  1   modelo                   18077 non-null  object
#  2   ranking                  18077 non-null  int64
#  3   aging_aparelho           18077 non-null  int64
#  4   offertechnology          18077 non-null  object
#  5   statedesc                18077 non-null  object
#  6   subscribermainofferdesc  18077 non-null  object
#  7   assignedchargeamount     18077 non-null  float64
#  8   fl_3g                    18077 non-null  float64
#  9   fl_4g                    18077 non-null  float64
#  10  fl_5g                    18077 non-null  float64
#  11  dt_ano_stts              18077 non-null  int64
#  12  idade                    18077 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s_ta = (X_ta.dtypes == 'object')
object_cols_ta = list(s_ta[s_ta].index)
print("Categorical variables: ", len(object_cols_ta))
print(object_cols_ta)
# Out:
# Categorical variables:  5
# ['fabricante', 'modelo', 'offertechnology', 'statedesc', 'subscribermainofferdesc']

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols_ta = [cname for cname in X_ta.columns if X_ta[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols_ta))
print(numerical_cols_ta)
# Out:
# Numerical variables:  8
# ['ranking', 'aging_aparelho', 'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']

# %% [markdown]
# ***
# ## Mostrando a correlação entre os dados numéricos

# %%
corr_trocou_aparelho = dados_droped[['fabricante', 'modelo',
                                     'ranking', 'aging_aparelho',
                                     'offertechnology', 
                                     'statedesc', 'subscribermainofferdesc',
                                     'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                                     'dt_ano_stts', 'idade', 'trocou_aparelho']]

# %%
corr = corr_trocou_aparelho.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
dados_droped['mes_jan'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-01') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-01')

dados_droped['mes_fev'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-02') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-02')

dados_droped['mes_mar'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-03') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-03')

dados_droped['mes_abr'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-04') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-04')

dados_droped['mes_mai'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-05') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-05')

dados_droped['mes_jun'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-06') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-06')

dados_droped['mes_jul'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-07') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-07')  
                                                
dados_droped['mes_ago'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-08') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-08')

dados_droped['mes_set'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-09') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-09')

dados_droped['mes_out'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-10') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-10')

dados_droped['mes_nov'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-11') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-11')

dados_droped['mes_dez'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-12') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-12')

# %%
corr_meses_troca = dados_droped[['mes_jan', 'mes_fev', 'mes_mar', 'mes_abr', 
								 'mes_mai', 'mes_jun', 'mes_jul', 'mes_ago', 
								 'mes_set', 'mes_out', 'mes_nov', 'mes_dez', 'trocou_aparelho']]

# %%
corr_Test = corr_meses_troca.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr_Test, xticklabels = corr_Test.columns, yticklabels = corr_Test.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target trocou_aparelho

# %%
def plot_feature_freq(df, feature, qt_cat):
    labels, counts = np.unique(df[feature].dropna(), return_counts=True)

    # ordena pelas mais frequentes
    order = np.argsort(counts)[::-1]
    labels, counts = labels[order], counts[order]

    g = sns.barplot(labels[:qt_cat], counts[:qt_cat])
    g.set_xticklabels(labels[:qt_cat], rotation=90)
    
    return g

# %%
# define target
y_trocou_aparelho = dados_droped['trocou_aparelho']

c_trocou_aparelho = Counter(y_trocou_aparelho)
c_trocou_aparelho
# Out:
# Counter({1: 5819, 0: 12258})

# %%
# # calculo da proporção da base
# estimate = c_trocou_aparelho[0] / c_trocou_aparelho[1]
# estimate

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(dados_droped, 'trocou_aparelho', len(dados_droped['trocou_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Modelagem trocou_aparelho

# %%
# Dividindo as features em dados de treino e teste
X_train_ta, X_val_ta, y_train_ta, y_val_ta = train_test_split(X_ta, 
                                                              y_trocou_aparelho, 
                                                              test_size=0.5, 
                                                              random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer_ta = Pipeline([
                                     ('scaler', StandardScaler())
                                    ])

# Pré-processamento para Dados Categóricos
categorical_transformer_ta = Pipeline([
                                       ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                      ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor_ta = ColumnTransformer(transformers=[
                                                  ('num', numerical_transformer_ta, numerical_cols_ta),
                                                  ('cat', categorical_transformer_ta, object_cols_ta)
                                                 ], n_jobs=-1)

pipeline_ta = Pipeline(steps=[
                              ('preprocessor', preprocessor_ta),
                              ('smote', SMOTE(random_state=42, n_jobs=-1)),
#                               ('model', RandomForestClassifier(random_state=2048))
                              ('model', GradientBoostingClassifier(random_state=2048))
#                               ('model', XGBClassifier(scale_pos_weight=estimate, random_state=2048))
                             ])

# Preprocessing of training data, fit model 
pipeline_ta.fit(X_train_ta, y_train_ta)

# Predictions
# preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds_ta = pipeline_ta.predict(X_val_ta)

# %%
c_train_ta = Counter(y_train_ta)
c_train_ta
# Out:
# Counter({0: 6145, 1: 2893})

# %%
c_val_ta = Counter(y_val_ta)
c_val_ta
# Out:
# Counter({1: 2926, 0: 6113})

# %%
c_preds_ta = Counter(preds_ta)
c_preds_ta
# Out:
# Counter({1: 3945, 0: 5094})

# %% [markdown]
# ***
# ## Métricas

# %%
print(classification_report(y_val_ta, preds_ta))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      6113
#            1       0.50      0.67      0.57      2926
#
#     accuracy                           0.67      9039
#    macro avg       0.65      0.67      0.66      9039
# weighted avg       0.71      0.67      0.68      9039

# %%
cm_df_ta = pd.DataFrame(confusion_matrix(y_val_ta, preds_ta),
                     index = sorted(Counter(y_val_ta)),
                     columns = sorted(Counter(preds_ta)))
cm_df_ta
# Out:
#       0     1
# 0  4134  1979
# 1   960  1966

# %%
# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline_ta,
        X_val_ta,
        y_val_ta,
        display_labels=['Não Trocou', 'Trocou'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[4134 1979]
#  [ 960 1966]]
# Normalized confusion matrix
# [[0.6762637  0.3237363 ]
#  [0.32809296 0.67190704]]

# %% [markdown]
# ## Captação dos clientes que foram previstos como Propensos a Fazer uma Compra

# %%
X_val_ta['trocou_aparelho'] = y_val_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho', len(X_val_ta['trocou_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %%
X_val_ta['trocou_aparelho_previsto'] = preds_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho_previsto', len(X_val_ta['trocou_aparelho_previsto'].unique()))
# Out:
# <AxesSubplot:>

# %%
X_val_ta['cpfidentifier'] = dados_droped['cpfidentifier']
# X_val_ta

# %%
X_val_ta['dt_inicio'] = dados_droped['dt_inicio']
# X_val_ta

# %%
X_val_ta['dt_fim'] = dados_droped['dt_fim']
X_val_ta
# Out:
#                 fabricante                               modelo  ranking  \
# 2736               SAMSUNG  GALAXY GRAND PRIME DUOS (SM-G532MT)        1
# 9312               SAMSUNG             GALAXY S10 (SM-G973F,DS)        1
# 13957               HUAWEI                               FC612E        1
# 4590         Samsung Korea                           GALAXY S20        1
# 15890  LG Electronics Inc.                           LM-K410BMW        1
# ...                    ...                                  ...      ...
# 8170         Samsung Korea                      GALAXY A01 CORE        1
# 11917              SAMSUNG            GALAXY A71 (SM-A715F,DSM)        1
# 12486  LG Electronics Inc.                                 K40S        1
# 13159                APPLE            IPHONE 12 PRO MAX (A2411)        1
# 10014        Samsung Korea                           GALAXY S20        1
#
#        aging_aparelho offertechnology  statedesc  \
# 2736               14        PostPaid  SAO PAULO
# 9312               15        PostPaid  SAO PAULO
# 13957              13        PostPaid  SAO PAULO
# 4590               18        PostPaid  SAO PAULO
# 15890              18        PostPaid  SAO PAULO
# ...               ...             ...        ...
# 8170               15        PostPaid  SAO PAULO
# 11917              13        PostPaid  SAO PAULO
# 12486              16        PostPaid  SAO PAULO
# 13159              12        PostPaid  SAO PAULO
# 10014              18        PostPaid  SAO PAULO
#
#                              subscribermainofferdesc  assignedchargeamount  \
# 2736        Linha Adicional Vivo PÃ³s FamÃ­lia 300GB                  0.00
# 9312           TITULAR VIVO FAMILIA 10GB+110GB BONUS                150.51
# 13957                         Titular Vivo PÃ³s 50GB                 78.99
# 4590        Linha Adicional Vivo PÃ³s FamÃ­lia 180GB                 62.99
# 15890  LINHA ADICIONAL VIVO FAMILIA 20GB+220GB BONUS                  0.00
# ...                                              ...                   ...
# 8170        Linha Adicional Vivo PÃ³s FamÃ­lia 180GB                  0.00
# 11917                       TITULAR BASICO FUNCIONAL                  0.00
# 12486                          TITULAR VIVO_POS 30GB                127.64
# 13159                                TITULAR VIVO V                 876.70
# 10014                TITULAR VIVO SELFIE BASICO 16GB                 92.99
#
#        fl_3g  fl_4g  fl_5g  dt_ano_stts  idade  trocou_aparelho  \
# 2736     0.0    1.0    0.0         2017     69                1
# 9312     0.0    1.0    0.0         2018     32                0
# 13957    1.0    0.0    0.0         2010     46                0
# 4590     0.0    1.0    0.0         2019     32                0
# 15890    0.0    1.0    0.0         2019     68                0
# ...      ...    ...    ...          ...    ...              ...
# 8170     0.0    1.0    0.0         2020     36                0
# 11917    0.0    1.0    0.0         2019     34                1
# 12486    0.0    1.0    0.0         2019     36                0
# 13159    0.0    0.0    1.0         2020     37                0
# 10014    0.0    1.0    0.0         2019     47                0
#
#        trocou_aparelho_previsto  cpfidentifier   dt_inicio      dt_fim
# 2736                          1    53600487868  2020-12-24  2022-03-09
# 9312                          1    39758735829  2021-07-12         NaN
# 13957                         1    24767407800  2021-09-05         NaN
# 4590                          1    40056003870  2021-04-06         NaN
# 15890                         0    59219890887  2021-04-10         NaN
# ...                         ...            ...         ...         ...
# 8170                          0    34975536897  2021-07-19         NaN
# 11917                         1    35884562870  2021-02-03  2022-04-02
# 12486                         1    35254199881  2021-06-07         NaN
# 13159                         1    22795161877  2021-10-19         NaN
# 10014                         1    18031683824  2021-03-27         NaN
#
# [9039 rows x 18 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Separando as bases para outro modelo

# %%
base_to_pred_month = X_val_ta[X_val_ta['trocou_aparelho_previsto'] == 1].reset_index(drop=True)
base_to_pred_month
# Out:
#                fabricante                               modelo  ranking  \
# 0                 SAMSUNG  GALAXY GRAND PRIME DUOS (SM-G532MT)        1
# 1                 SAMSUNG             GALAXY S10 (SM-G973F,DS)        1
# 2                  HUAWEI                               FC612E        1
# 3           Samsung Korea                           GALAXY S20        1
# 4                 SAMSUNG             GALAXY S20 FE (SM-G780F)        2
# ...                   ...                                  ...      ...
# 3940                APPLE                     IPHONE 7 (A1778)        1
# 3941              SAMSUNG            GALAXY A71 (SM-A715F,DSM)        1
# 3942  LG Electronics Inc.                                 K40S        1
# 3943                APPLE            IPHONE 12 PRO MAX (A2411)        1
# 3944        Samsung Korea                           GALAXY S20        1
#
#       aging_aparelho offertechnology  statedesc  \
# 0                 14        PostPaid  SAO PAULO
# 1                 15        PostPaid  SAO PAULO
# 2                 13        PostPaid  SAO PAULO
# 3                 18        PostPaid  SAO PAULO
# 4                 17        PostPaid  SAO PAULO
# ...              ...             ...        ...
# 3940              14        PostPaid  SAO PAULO
# 3941              13        PostPaid  SAO PAULO
# 3942              16        PostPaid  SAO PAULO
# 3943              12        PostPaid  SAO PAULO
# 3944              18        PostPaid  SAO PAULO
#
#                        subscribermainofferdesc  assignedchargeamount  fl_3g  \
# 0     Linha Adicional Vivo PÃ³s FamÃ­lia 300GB                  0.00    0.0
# 1        TITULAR VIVO FAMILIA 10GB+110GB BONUS                150.51    0.0
# 2                       Titular Vivo PÃ³s 50GB                 78.99    1.0
# 3     Linha Adicional Vivo PÃ³s FamÃ­lia 180GB                 62.99    0.0
# 4        TITULAR VIVO FAMILIA 10GB+110GB BONUS                159.99    0.0
# ...                                        ...                   ...    ...
# 3940     TITULAR VIVO FAMILIA 10GB+110GB BONUS                159.99    0.0
# 3941                  TITULAR BASICO FUNCIONAL                  0.00    0.0
# 3942                     TITULAR VIVO_POS 30GB                127.64    0.0
# 3943                           TITULAR VIVO V                 876.70    0.0
# 3944           TITULAR VIVO SELFIE BASICO 16GB                 92.99    0.0
#
#       fl_4g  fl_5g  dt_ano_stts  idade  trocou_aparelho  \
# 0       1.0    0.0         2017     69                1
# 1       1.0    0.0         2018     32                0
# 2       0.0    0.0         2010     46                0
# 3       1.0    0.0         2019     32                0
# 4       1.0    0.0         2020     93                1
# ...     ...    ...          ...    ...              ...
# 3940    1.0    0.0         2018     57                0
# 3941    1.0    0.0         2019     34                1
# 3942    1.0    0.0         2019     36                0
# 3943    0.0    1.0         2020     37                0
# 3944    1.0    0.0         2019     47                0
#
#       trocou_aparelho_previsto  cpfidentifier   dt_inicio      dt_fim
# 0                            1    53600487868  2020-12-24  2022-03-09
# 1                            1    39758735829  2021-07-12         NaN
# 2                            1    24767407800  2021-09-05         NaN
# 3                            1    40056003870  2021-04-06         NaN
# 4                            1    25079382856  2021-05-12         NaN
# ...                        ...            ...         ...         ...
# 3940                         1     8785141801  2021-07-30         NaN
# 3941                         1    35884562870  2021-02-03  2022-04-02
# 3942                         1    35254199881  2021-06-07         NaN
# 3943                         1    22795161877  2021-10-19         NaN
# 3944                         1    18031683824  2021-03-27         NaN
#
# [3945 rows x 18 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target aging_aparelho

# %%
# define target
y = base_to_pred_month['aging_aparelho']

# %%
# contagem de aging
from collections import Counter

c = Counter(y)
c
# Out:
# Counter({14: 645, 15: 578, 13: 598, 18: 494, 17: 522, 16: 464, 12: 644})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(base_to_pred_month, 'aging_aparelho', len(base_to_pred_month['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Definicão das features

# %%
# define features
X = base_to_pred_month[['fabricante', 'modelo',
                        'ranking',
                        'offertechnology', 
                        'statedesc', 'subscribermainofferdesc',
                        'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                        'dt_ano_stts', 'idade']]
X
# Out:
#                fabricante                               modelo  ranking  \
# 0                 SAMSUNG  GALAXY GRAND PRIME DUOS (SM-G532MT)        1
# 1                 SAMSUNG             GALAXY S10 (SM-G973F,DS)        1
# 2                  HUAWEI                               FC612E        1
# 3           Samsung Korea                           GALAXY S20        1
# 4                 SAMSUNG             GALAXY S20 FE (SM-G780F)        2
# ...                   ...                                  ...      ...
# 3940                APPLE                     IPHONE 7 (A1778)        1
# 3941              SAMSUNG            GALAXY A71 (SM-A715F,DSM)        1
# 3942  LG Electronics Inc.                                 K40S        1
# 3943                APPLE            IPHONE 12 PRO MAX (A2411)        1
# 3944        Samsung Korea                           GALAXY S20        1
#
#      offertechnology  statedesc                   subscribermainofferdesc  \
# 0           PostPaid  SAO PAULO  Linha Adicional Vivo PÃ³s FamÃ­lia 300GB
# 1           PostPaid  SAO PAULO     TITULAR VIVO FAMILIA 10GB+110GB BONUS
# 2           PostPaid  SAO PAULO                    Titular Vivo PÃ³s 50GB
# 3           PostPaid  SAO PAULO  Linha Adicional Vivo PÃ³s FamÃ­lia 180GB
# 4           PostPaid  SAO PAULO     TITULAR VIVO FAMILIA 10GB+110GB BONUS
# ...              ...        ...                                       ...
# 3940        PostPaid  SAO PAULO     TITULAR VIVO FAMILIA 10GB+110GB BONUS
# 3941        PostPaid  SAO PAULO                  TITULAR BASICO FUNCIONAL
# 3942        PostPaid  SAO PAULO                     TITULAR VIVO_POS 30GB
# 3943        PostPaid  SAO PAULO                           TITULAR VIVO V
# 3944        PostPaid  SAO PAULO           TITULAR VIVO SELFIE BASICO 16GB
#
#       assignedchargeamount  fl_3g  fl_4g  fl_5g  dt_ano_stts  idade
# 0                     0.00    0.0    1.0    0.0         2017     69
# 1                   150.51    0.0    1.0    0.0         2018     32
# 2                    78.99    1.0    0.0    0.0         2010     46
# 3                    62.99    0.0    1.0    0.0         2019     32
# 4                   159.99    0.0    1.0    0.0         2020     93
# ...                    ...    ...    ...    ...          ...    ...
# 3940                159.99    0.0    1.0    0.0         2018     57
# 3941                  0.00    0.0    1.0    0.0         2019     34
# 3942                127.64    0.0    1.0    0.0         2019     36
# 3943                876.70    0.0    0.0    1.0         2020     37
# 3944                 92.99    0.0    1.0    0.0         2019     47
#
# [3945 rows x 12 columns]

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s = (X.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables: ", len(object_cols))
print(object_cols)
# Out:
# Categorical variables:  5
# ['fabricante', 'modelo', 'offertechnology', 'statedesc', 'subscribermainofferdesc']

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols))
print(numerical_cols)
# Out:
# Numerical variables:  7
# ['ranking', 'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']

# %% [markdown]
# ***
# ## Mostrando a correlação entre os dados numéricos

# %%
corr_mes_previsao = base_to_pred_month[['fabricante', 'modelo',
                                        'ranking',
                                        'offertechnology', 
                                        'statedesc', 'subscribermainofferdesc',
                                        'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                                        'dt_ano_stts', 'idade', 'aging_aparelho']]

# %%
corr2 = corr_mes_previsao.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr2, xticklabels = corr2.columns, yticklabels = corr2.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Modelagem

# %%
# Dividindo as features em dados de treino e teste - 70% para dados de treinamento e 30% para dados de teste
X_train, X_val, y_train, y_val = train_test_split(X, 
                                                  y, 
                                                  test_size=0.5, 
                                                  random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer = Pipeline([
                                  ('scaler', StandardScaler())
                                 ])

# Pré-processamento para Dados Categóricos
categorical_transformer = Pipeline([
                                    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                   ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor = ColumnTransformer(transformers=[
                                                ('num', numerical_transformer, numerical_cols),
                                                ('cat', categorical_transformer, object_cols)
                                              ], n_jobs=-1)

pipeline = Pipeline(steps=[
                            ('preprocessor', preprocessor),
#                             ('smote', SMOTE(random_state=42, n_jobs=-1)),
                            ('model', RandomForestClassifier(random_state=2048))
#                             ('model', GradientBoostingClassifier(random_state=2048))
#                             ('model', XGBClassifier(scale_pos_weight=estimate, random_state=2048))
                          ])

# Preprocessing of training data, fit model 
pipeline.fit(X_train, y_train)

# Predictions
#preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds = pipeline.predict(X_val)

# %%
c_train = Counter(y_train)
c_train
# Out:
# Counter({17: 254, 13: 319, 15: 284, 14: 302, 18: 248, 12: 333, 16: 232})

# %%
c_val = Counter(y_val)
c_val
# Out:
# Counter({12: 311, 13: 279, 18: 246, 14: 343, 16: 232, 17: 268, 15: 294})

# %%
c_preds = Counter(preds)
c_preds
# Out:
# Counter({13: 358, 12: 387, 14: 292, 18: 204, 17: 245, 16: 190, 15: 297})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(base_to_pred_month, 'aging_aparelho', len(base_to_pred_month['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Métricas

# %%
print(classification_report(y_val, preds))
# Out:
#               precision    recall  f1-score   support
#
#           12       0.20      0.25      0.23       311
#           13       0.19      0.24      0.21       279
#           14       0.21      0.18      0.20       343
#           15       0.19      0.19      0.19       294
#           16       0.18      0.15      0.16       232
#           17       0.22      0.20      0.21       268
#           18       0.16      0.13      0.15       246
#
#     accuracy                           0.20      1973
#    macro avg       0.19      0.19      0.19      1973
# weighted avg       0.19      0.20      0.19      1973

# %%
cm_df = pd.DataFrame(confusion_matrix(y_val, preds),
                     index = sorted(Counter(y_val)),
                     columns = sorted(Counter(preds)))
cm_df
# Out:
#     12  13  14  15  16  17  18
# 12  79  72  43  50  19  22  26
# 13  47  67  48  52  14  26  25
# 14  72  58  62  50  24  47  30
# 15  67  42  40  57  35  33  20
# 16  34  42  24  31  34  28  39
# 17  44  40  37  26  37  53  31
# 18  44  37  38  31  27  36  33

# %% [markdown]
# ## Plot non-normalized confusion matrix

# %%
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline,
        X_val,
        y_val,
        display_labels=['12', '13', '14', '15', '16', '17', '18'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[79 72 43 50 19 22 26]
#  [47 67 48 52 14 26 25]
#  [72 58 62 50 24 47 30]
#  [67 42 40 57 35 33 20]
#  [34 42 24 31 34 28 39]
#  [44 40 37 26 37 53 31]
#  [44 37 38 31 27 36 33]]
# Normalized confusion matrix
# [[0.25401929 0.23151125 0.13826367 0.1607717  0.06109325 0.07073955
#   0.08360129]
#  [0.16845878 0.24014337 0.17204301 0.18637993 0.05017921 0.09318996
#   0.08960573]
#  [0.20991254 0.16909621 0.18075802 0.14577259 0.06997085 0.13702624
#   0.08746356]
#  [0.22789116 0.14285714 0.13605442 0.19387755 0.11904762 0.1122449
#   0.06802721]
#  [0.14655172 0.18103448 0.10344828 0.13362069 0.14655172 0.12068966
#   0.16810345]
#  [0.1641791  0.14925373 0.1380597  0.09701493 0.1380597  0.19776119
#   0.11567164]
#  [0.17886179 0.1504065  0.15447154 0.12601626 0.1097561  0.14634146
#   0.13414634]]

# %% [markdown]
# ***
# ## Mesclando resultados com tabela

# %% [markdown]
# ### Com a base de validação

# %%
X_val['aging_aparelho'] = y_val
# X_val

# %%
X_val['previsto'] = preds
# X_val

# %%
X_val['cpfidentifier'] = base_to_pred_month['cpfidentifier']
# X_val

# %%
X_val['dt_inicio'] = base_to_pred_month['dt_inicio']
# X_val

# %%
X_val['dt_fim'] = base_to_pred_month['dt_fim']
# X_val

# %% [markdown]
# ## Calculando data prevista

# %%
X_val['dt_fim_previsto'] = ((pd.to_datetime(X_val['dt_inicio']).dt.to_period('M')) + X_val['previsto'])
X_val
# Out:
#                                    fabricante                         modelo  \
# 92                                    SAMSUNG  GALAXY J7 PRIME (SM-G610M DS)
# 2166                                       LG                           G360
# 1118                                    APPLE               IPHONE 8 (A1905)
# 658                                    XIAOMI          MI 9T PRO (M1903F11G)
# 3753  Motorola Mobility LLC, a Lenovo Company             DEEN, MOTOROLA ONE
# ...                                       ...                            ...
# 2313                                    APPLE          IPHONE 8 PLUS (A1897)
# 2471                                    APPLE              IPHONE 11 (A2221)
# 1355                                  SAMSUNG       GALAXY A22 (SM-A225F,DS)
# 49                                    SAMSUNG  GALAXY J7 PRIME (SM-G610M DS)
# 413                                    XIAOMI       POCOPHONE F1 (M1805E10A)
#
#       ranking offertechnology  statedesc  \
# 92          1        PostPaid  SAO PAULO
# 2166        1        PostPaid  SAO PAULO
# 1118        1        PostPaid  SAO PAULO
# 658         1        PostPaid  SAO PAULO
# 3753        1        PostPaid  SAO PAULO
# ...       ...             ...        ...
# 2313        1        PostPaid  SAO PAULO
# 2471        1        PostPaid  SAO PAULO
# 1355        2        PostPaid  SAO PAULO
# 49          1        PostPaid  SAO PAULO
# 413         1        PostPaid  SAO PAULO
#
#                                 subscribermainofferdesc  assignedchargeamount  \
# 92                   LINHA ADICIONAL VIVO FAMILIA 200GB                  0.00
# 2166                LINHA ADICIONAL VIVO FAMILIA 200GB_                  0.00
# 1118                         TITULAR VIVO FAMILIA 100GB                259.26
# 658            Linha Adicional Vivo PÃ³s FamÃ­lia 180GB                  0.00
# 3753  LINHA ADICIONAL VIVO FAMILIA 10GB PLN+110GB BONUS                  0.00
# ...                                                 ...                   ...
# 2313                              TITULAR VIVO_POS 30GB                134.99
# 2471                   Titular Vivo PÃ³s FamÃ­lia 120GB                138.99
# 1355                             Titular Vivo PÃ³s 20GB                 48.99
# 49                   LINHA ADICIONAL VIVO FAMILIA 100GB                  0.00
# 413                TITULAR VIVO POS 7GB PLN+28GB BONUS                  86.88
#
#       fl_3g  fl_4g  fl_5g  dt_ano_stts  idade  aging_aparelho  previsto  \
# 92      0.0    1.0    0.0         2016     55              12        13
# 2166    0.0    0.0    0.0         2016     44              13        12
# 1118    0.0    1.0    0.0         2018     46              12        13
# 658     0.0    1.0    0.0         2019     59              18        14
# 3753    0.0    1.0    0.0         2018     23              18        18
# ...     ...    ...    ...          ...    ...             ...       ...
# 2313    0.0    1.0    0.0         2017     32              18        16
# 2471    0.0    1.0    0.0         2019     34              14        15
# 1355    0.0    1.0    0.0         2021     50              12        12
# 49      0.0    1.0    0.0         2017     51              13        17
# 413     0.0    1.0    0.0         2018     39              16        18
#
#       cpfidentifier   dt_inicio      dt_fim dt_fim_previsto
# 92      10225608839  2021-09-25         NaN         2022-10
# 2166    25515874846  2021-03-24  2022-05-23         2022-03
# 1118    18587749854  2021-05-09  2022-05-12         2022-06
# 658      3467754856  2020-10-16  2022-05-07         2021-12
# 3753    49313342880  2020-08-24  2022-03-12         2022-02
# ...             ...         ...         ...             ...
# 2313    38460578860  2021-03-23         NaN         2022-07
# 2471    37054408888  2021-02-24  2022-05-09         2022-05
# 1355    14027778847  2021-10-11         NaN         2022-10
# 49      17659303830  2021-08-30         NaN         2023-01
# 413     34005989845  2021-01-30  2022-06-03         2022-07
#
# [1973 rows x 18 columns]

# %%
c_preds
# Out:
# Counter({13: 358, 12: 387, 14: 292, 18: 204, 17: 245, 16: 190, 15: 297})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val, 'aging_aparelho', len(X_val['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val, 'previsto', len(X_val['previsto'].unique()))
# Out:
# <AxesSubplot:>
