# %%
## data
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.relativedelta import relativedelta
from unicodedata import normalize

## vis
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# contagem de aging
from collections import Counter

from IPython.display import display, HTML

## modelo
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# check xgboost version
from xgboost import XGBClassifier

## alertas
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***
# ## Coleta de dados

# %%
FILE = "/kaggle/input/datasetsnew/batdtfim500kage.csv"
dados = pd.read_csv(FILE, sep = ';', encoding = 'ISO-8859-1', engine ='python')

dados = dados.rename(columns={'a.msisdn': 'msisdn'})\
             .rename(columns={'a.imsi': 'imsi'})\
             .rename(columns={'a.tac': 'tac'})\
             .rename(columns={'a.dt_inicio': 'dt_inicio'})\
             .rename(columns={'a.dt_fim': 'dt_fim'})\
             .rename(columns={'a.aging_aparelho': 'aging_aparelho'})\
             .rename(columns={'a.cat_aparelho': 'cat_aparelho'})\
             .rename(columns={'a.trocou_aparelho': 'trocou_aparelho'})\
             .rename(columns={'a.fabricante': 'fabricante'})\
             .rename(columns={'a.modelo': 'modelo'})\
             .rename(columns={'a.imei': 'imei'})\
             .rename(columns={'a.ranking': 'ranking'})\
             .rename(columns={'a.cpfidentifier': 'cpfidentifier'})\
             .rename(columns={'a.subscriberkey': 'subscriberkey'})\
             .rename(columns={'a.customerkey': 'customerkey'})\
             .rename(columns={'a.customersubtypedesc': 'customersubtypedesc'})\
             .rename(columns={'a.subscriberstatuskey': 'subscriberstatuskey'})\
             .rename(columns={'a.offertechnology': 'offertechnology'})\
             .rename(columns={'a.citydesc': 'citydesc'})\
             .rename(columns={'a.statedesc': 'statedesc'})\
             .rename(columns={'a.subscribermainofferdesc': 'subscribermainofferdesc'})\
             .rename(columns={'a.assignedchargeamount': 'assignedchargeamount'})\
             .rename(columns={'a.fl_3g': 'fl_3g'})\
             .rename(columns={'a.fl_4g': 'fl_4g'})\
             .rename(columns={'a.fl_5g': 'fl_5g'})\
             .rename(columns={'a.dt_ano_stts': 'dt_ano_stts'})\
             .rename(columns={'a.idade': 'idade'})\

dados = dados[dados['offertechnology'] == 'Controle']

dados
# Out:
#                msisdn             imsi       tac   dt_inicio dt_fim  \
# 1       5521988674638  724112005547717  35690411  2021-05-29    NaN
# 3       5527997623734  724113001405241  35991710  2021-05-29    NaN
# 4       5567996046665  724066795495313  35613011  2021-07-23    NaN
# 6       5511997089585  724101993173553  35188909  2021-08-04    NaN
# 9       5592991404472  724119791658359  35447511  2021-10-11    NaN
# ...               ...              ...       ...         ...    ...
# 499992  5519997894130  724102008047199  35078434  2021-10-07    NaN
# 499993  5564996056038  724066637403568  35634209  2021-06-28    NaN
# 499996  5511941319852  724102190782505  35092033  2021-03-25    NaN
# 499997  5518996551019  724101993846396  35690411  2021-09-03    NaN
# 499999  5593991436563  724119390690544  35378310  2021-04-29    NaN
#
#         aging_aparelho  cat_aparelho  trocou_aparelho  \
# 1                   16             1                0
# 3                   16             1                0
# 4                   14             1                0
# 6                   14             1                0
# 9                   12             1                0
# ...                ...           ...              ...
# 499992              12             1                0
# 499993              15             1                0
# 499996              18             1                0
# 499997              13             1                0
# 499999              17             1                0
#
#                                      fabricante  \
# 1       Motorola Mobility LLC, a Lenovo Company
# 3                    Multilaser Industrial S.A.
# 4                                       SAMSUNG
# 6                                      MOTOROLA
# 9                                 Samsung Korea
# ...                                         ...
# 499992                            Samsung Korea
# 499993                                  SAMSUNG
# 499996  Motorola Mobility LLC, a Lenovo Company
# 499997  Motorola Mobility LLC, a Lenovo Company
# 499999                                  SAMSUNG
#
#                                     modelo  ... offertechnology  citydesc  \
# 1                                 ODESSA20  ...        Controle       NaN
# 3                         MULTILASER F PRO  ...        Controle       NaN
# 4                 GALAXY A01 (SM-A015M,DS)  ...        Controle       NaN
# 6               MOTOROLA MOTO G5S (XT1792)  ...        Controle       NaN
# 9                              GALAXY A10S  ...        Controle       NaN
# ...                                    ...  ...             ...       ...
# 499992                      GALAXY A32 LTE  ...        Controle       NaN
# 499993  GALAXY J5 PRIME DUOS (SM-G570M DS)  ...        Controle       NaN
# 499996                             GUAM+20  ...        Controle       NaN
# 499997                            ODESSA20  ...        Controle       NaN
# 499999        GALAXY J2 CORE (SM-J260M,DS)  ...        Controle       NaN
#
#                  statedesc       subscribermainofferdesc  \
# 1           RIO DE JANEIRO  VIVO CTRL DIGITAL_11GB ILIM_
# 3           ESPIRITO SANTO        VIVO CONTROLE DIG-7GB_
# 4       MATO GROSSO DO SUL          VIVO CONTROLE 4GB IV
# 6                SAO PAULO            VIVO CONTROLE 7GB_
# 9                 AMAZONAS          VIVO CONTROLE 4GB II
# ...                    ...                           ...
# 499992           SAO PAULO                           NaN
# 499993        MINAS GERAIS         VIVO CONTROLE 6GB III
# 499996           SAO PAULO            VIVO CONTROLE 7GB_
# 499997           SAO PAULO             VIVO CONTROLE 4GB
# 499999                PARA         VIVO CONTROLE 6GB III
#
#         assignedchargeamount fl_3g fl_4g fl_5g  dt_ano_stts idade
# 1                      67.14   0.0   1.0   0.0       2020.0    83
# 3                      52.88   0.0   1.0   0.0       2019.0    65
# 4                      37.49   0.0   1.0   0.0       2020.0    48
# 6                      53.35   0.0   1.0   0.0       2017.0    61
# 9                      34.99   0.0   1.0   0.0       2019.0    45
# ...                      ...   ...   ...   ...          ...   ...
# 499992                   NaN   0.0   1.0   0.0       2020.0    63
# 499993                 45.99   0.0   1.0   0.0       2018.0    45
# 499996                 53.35   0.0   1.0   0.0       2020.0    50
# 499997                 37.61   0.0   1.0   0.0       2020.0    58
# 499999                 45.99   0.0   1.0   0.0       2018.0    59
#
# [358773 rows x 27 columns]

# %% [markdown]
# ### Limpeza dos dados

# %%
def just_check_nan(df):
    # Check NaN Pandas and Numpy
    missing_val_count_by_column = (df.isna().sum())

    columns_with_nan = missing_val_count_by_column[missing_val_count_by_column > 0]
    print('Dados com NaN:')
    print(columns_with_nan)
    print('')
    print('columns_with_nan.shape', columns_with_nan.shape)
    print('')

# %%
just_check_nan(dados)
# Out:
# Dados com NaN:
# dt_fim                     286200
# citydesc                   358773
# statedesc                      10
# subscribermainofferdesc     36099
# assignedchargeamount        36036
# fl_3g                          69
# fl_4g                          69
# fl_5g                          69
# dt_ano_stts                    69
# dtype: int64
#
# columns_with_nan.shape (9,)

# %%
dados_droped = dados.dropna(subset=['imsi',
                                    'statedesc', 
                                    'subscribermainofferdesc', 
                                    'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts'])\
                    .reset_index(drop=True)
# dados_droped

# %%
just_check_nan(dados_droped)
# Out:
# Dados com NaN:
# dt_fim      253164
# citydesc    322562
# dtype: int64
#
# columns_with_nan.shape (2,)

# %% [markdown]
# ### Equilibrando classes

# %%
dados_droped_0 = dados_droped[dados_droped['trocou_aparelho'] == 0].sample(frac=0.53, random_state=3)
dados_droped_1 = dados_droped[dados_droped['trocou_aparelho'] == 1]

# %%
dados_droped = pd.concat([dados_droped_0, dados_droped_1]).reset_index(drop=True).sort_values(by='msisdn', ascending=False)
dados_droped
# Out:
#                msisdn             imsi       tac   dt_inicio      dt_fim  \
# 99933   5599999844114  724119896659201  35194123  2021-04-30         NaN
# 33090   5599999019207  724119896575781  86193705  2021-09-20         NaN
# 166948  5599992381199  724119897221361  35305511  2021-05-05  2022-06-20
# 102489  5599992317613  724119898130758  35992599  2021-10-19         NaN
# 141384  5599992316296  724119895474064  35695408  2021-02-26  2022-04-20
# ...               ...              ...       ...         ...         ...
# 141770  5511910006348  724102802378897  35690311  2021-02-12  2022-03-03
# 188413  5511910005533  724102902203195  35690708  2020-12-29  2022-05-05
# 136418  5511910004670  724102802008236  35293009  2020-12-18  2022-05-08
# 103468  5511910003293  724102007432614  35175910  2021-08-02         NaN
# 67325   5511910001951  724101891084880  35606715  2021-07-25         NaN
#
#         aging_aparelho  cat_aparelho  trocou_aparelho  \
# 99933               17             1                0
# 33090               13             1                0
# 166948              13             1                1
# 102489              12             1                0
# 141384              13             1                1
# ...                ...           ...              ...
# 141770              12             1                1
# 188413              16             1                1
# 136418              16             1                1
# 103468              14             1                0
# 67325               14             1                0
#
#                                      fabricante  \
# 99933                                     APPLE
# 33090                                    XIAOMI
# 166948                                    APPLE
# 102489  Motorola Mobility LLC, a Lenovo Company
# 141384                                  SAMSUNG
# ...                                         ...
# 141770  Motorola Mobility LLC, a Lenovo Company
# 188413                                  SAMSUNG
# 136418                                  SAMSUNG
# 103468                                  SAMSUNG
# 67325                             Samsung Korea
#
#                                        modelo  ... offertechnology  citydesc  \
# 99933                       IPHONE 11 (A2221)  ...        Controle       NaN
# 33090                    POCO M3 (M2010J19CG)  ...        Controle       NaN
# 166948                      IPHONE 12 (A2403)  ...        Controle       NaN
# 102489                                MALTA20  ...        Controle       NaN
# 141384  GALAXY GRAND PRIME DUOS (SM-G532M DS)  ...        Controle       NaN
# ...                                       ...  ...             ...       ...
# 141770                             MOTO E(6)S  ...        Controle       NaN
# 188413                GALAXY A5 (SM-A520F DS)  ...        Controle       NaN
# 136418    GALAXY GRAND PRIME DUOS (SM-G532MT)  ...        Controle       NaN
# 103468              GALAXY J6 PLUS (SM-J610F)  ...        Controle       NaN
# 67325                              GALAXY A02  ...        Controle       NaN
#
#                  statedesc       subscribermainofferdesc  \
# 99933             MARANHAO    VIVO CONTROLE 11GB - ANUAL
# 33090             MARANHAO             VIVO CONTROLE 4GB
# 166948  MATO GROSSO DO SUL             VIVO CONTROLE 8GB
# 102489            MARANHAO  VIVO CTRL DIGITAL-11GB ILIM_
# 141384            MARANHAO          VIVO CONTROLE 4GB IV
# ...                    ...                           ...
# 141770           SAO PAULO       CONTROLE VANTAGENS 10GB
# 188413           SAO PAULO           VIVO CONTROLE 9GB I
# 136418           SAO PAULO             VIVO CONTROLE 4GB
# 103468           SAO PAULO          VIVO CONTROLE 11GB I
# 67325            SAO PAULO      VIVO CONTROLE 5GB II PLN
#
#         assignedchargeamount fl_3g fl_4g fl_5g  dt_ano_stts idade
# 99933                  66.20   0.0   1.0   0.0       2020.0    52
# 33090                  36.86   0.0   1.0   0.0       2020.0    39
# 166948                 90.99   0.0   0.0   1.0       2020.0    33
# 102489                 66.20   0.0   1.0   0.0       2020.0    72
# 141384                 32.49   0.0   1.0   0.0       2016.0    56
# ...                      ...   ...   ...   ...          ...   ...
# 141770                 64.99   0.0   1.0   0.0       2020.0    69
# 188413                 57.01   0.0   1.0   0.0       2016.0    61
# 136418                 37.61   0.0   1.0   0.0       2017.0    82
# 103468                 72.60   0.0   1.0   0.0       2018.0    42
# 67325                  34.99   0.0   1.0   0.0       2020.0    64
#
# [205899 rows x 27 columns]

# %%
# checando balanço das classes
y_trocou_aparelho = dados_droped['trocou_aparelho']

c_trocou_aparelho = Counter(y_trocou_aparelho)
c_trocou_aparelho
# Out:
# Counter({0: 131556, 1: 74343})

# %%
dados_droped = dados_droped.tail(dados_droped.shape[0] -70000).reset_index(drop=True)
dados_droped['dt_ano_stts'] = dados_droped['dt_ano_stts'].astype(np.int64).reset_index(drop=True)
# dados_droped2 = dados_droped[dados_droped['trocou_aparelho'] == 1].reset_index()
dados_droped
# Out:
#                msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0       5551981384422  724065191556454  35823453  2021-09-12         NaN
# 1       5551981375542  724065191731792  35847409  2021-02-26  2022-06-09
# 2       5551981373908  724065191729020  35551411  2021-05-28         NaN
# 3       5551981369498  724065303306695  35396026  2021-10-02         NaN
# 4       5551981369393  724065007477780  35501510  2020-11-26  2022-02-21
# ...               ...              ...       ...         ...         ...
# 135894  5511910006348  724102802378897  35690311  2021-02-12  2022-03-03
# 135895  5511910005533  724102902203195  35690708  2020-12-29  2022-05-05
# 135896  5511910004670  724102802008236  35293009  2020-12-18  2022-05-08
# 135897  5511910003293  724102007432614  35175910  2021-08-02         NaN
# 135898  5511910001951  724101891084880  35606715  2021-07-25         NaN
#
#         aging_aparelho  cat_aparelho  trocou_aparelho  \
# 0                   13             1                0
# 1                   15             1                1
# 2                   16             1                0
# 3                   12             1                0
# 4                   14             1                1
# ...                ...           ...              ...
# 135894              12             1                1
# 135895              16             1                1
# 135896              16             1                1
# 135897              14             1                0
# 135898              14             1                0
#
#                                      fabricante  \
# 0       Motorola Mobility LLC, a Lenovo Company
# 1                                       SAMSUNG
# 2                                 Samsung Korea
# 3                                 Samsung Korea
# 4                                       SAMSUNG
# ...                                         ...
# 135894  Motorola Mobility LLC, a Lenovo Company
# 135895                                  SAMSUNG
# 135896                                  SAMSUNG
# 135897                                  SAMSUNG
# 135898                            Samsung Korea
#
#                                      modelo  ... offertechnology  citydesc  \
# 0                               CAPRIPLUS21  ...        Controle       NaN
# 1                  GALAXY J6 (SM-J600GT DS)  ...        Controle       NaN
# 2                                GALAXY A11  ...        Controle       NaN
# 3                         GALAXY S20 FE LTE  ...        Controle       NaN
# 4                 GALAXY S10E (SM-G970F,DS)  ...        Controle       NaN
# ...                                     ...  ...             ...       ...
# 135894                           MOTO E(6)S  ...        Controle       NaN
# 135895              GALAXY A5 (SM-A520F DS)  ...        Controle       NaN
# 135896  GALAXY GRAND PRIME DUOS (SM-G532MT)  ...        Controle       NaN
# 135897            GALAXY J6 PLUS (SM-J610F)  ...        Controle       NaN
# 135898                           GALAXY A02  ...        Controle       NaN
#
#                 statedesc     subscribermainofferdesc  assignedchargeamount  \
# 0       RIO GRANDE DO SUL     CONTROLE VANTAGENS 10GB                 64.99
# 1       RIO GRANDE DO SUL  VIVO CONTROLE 11GB - ANUAL                 72.03
# 2       RIO GRANDE DO SUL        VIVO CONTROLE 11GB I                 71.99
# 3       RIO GRANDE DO SUL       VIVO CONTROLE 6GB III                 45.99
# 4       RIO GRANDE DO SUL         VIVO CONTROLE 9GB I                 56.49
# ...                   ...                         ...                   ...
# 135894          SAO PAULO     CONTROLE VANTAGENS 10GB                 64.99
# 135895          SAO PAULO         VIVO CONTROLE 9GB I                 57.01
# 135896          SAO PAULO           VIVO CONTROLE 4GB                 37.61
# 135897          SAO PAULO        VIVO CONTROLE 11GB I                 72.60
# 135898          SAO PAULO    VIVO CONTROLE 5GB II PLN                 34.99
#
#        fl_3g fl_4g fl_5g  dt_ano_stts idade
# 0        0.0   1.0   0.0         2020    57
# 1        0.0   1.0   0.0         2018    39
# 2        0.0   1.0   0.0         2020    36
# 3        0.0   1.0   0.0         2021    44
# 4        0.0   1.0   0.0         2018    60
# ...      ...   ...   ...          ...   ...
# 135894   0.0   1.0   0.0         2020    69
# 135895   0.0   1.0   0.0         2016    61
# 135896   0.0   1.0   0.0         2017    82
# 135897   0.0   1.0   0.0         2018    42
# 135898   0.0   1.0   0.0         2020    64
#
# [135899 rows x 27 columns]

# %%
dados_droped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135899 entries, 0 to 135898
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   msisdn                   135899 non-null  int64
#  1   imsi                     135899 non-null  int64
#  2   tac                      135899 non-null  int64
#  3   dt_inicio                135899 non-null  object
#  4   dt_fim                   44710 non-null   object
#  5   aging_aparelho           135899 non-null  int64
#  6   cat_aparelho             135899 non-null  int64
#  7   trocou_aparelho          135899 non-null  int64
#  8   fabricante               135899 non-null  object
#  9   modelo                   135899 non-null  object
#  10  imei                     135899 non-null  object
#  11  ranking                  135899 non-null  int64
#  12  cpfidentifier            135899 non-null  int64
#  13  subscriberkey            135899 non-null  int64
#  14  customerkey              135899 non-null  int64
#  15  customersubtypedesc      135899 non-null  object
#  16  subscriberstatuskey      135899 non-null  object
#  17  offertechnology          135899 non-null  object
#  18  citydesc                 0 non-null       float64
#  19  statedesc                135899 non-null  object
#  20  subscribermainofferdesc  135899 non-null  object
#  21  assignedchargeamount     135899 non-null  float64
#  22  fl_3g                    135899 non-null  float64
#  23  fl_4g                    135899 non-null  float64
#  24  fl_5g                    135899 non-null  float64
#  25  dt_ano_stts              135899 non-null  int64
#  26  idade                    135899 non-null  int64
# dtypes: float64(5), int64(12), object(10)
# memory usage: 28.0+ MB

# %% [markdown]
# ***
# ### Analise individual

# %%
dados_droped['cat_aparelho'].unique()
# Out:
# array([1])

# %%
dados_droped['trocou_aparelho'].unique()
# Out:
# array([0, 1])

# %%
dados_droped['aging_aparelho'].unique()
# Out:
# array([13, 15, 16, 12, 14, 17, 18])

# %%
dados_droped['customersubtypedesc'].unique()
# Out:
# array(['Pessoa FÃ\xadsica'], dtype=object)

# %%
dados_droped['subscriberstatuskey'].unique()
# Out:
# array(['A'], dtype=object)

# %%
dados_droped['ranking'].unique()
# Out:
# array([1, 2])

# %%
dados_droped['assignedchargeamount'].unique()
# Out:
# array([ 64.99,  72.03,  71.99,  45.99,  56.49,  57.88,  67.03,  50.99,
#         52.88,  61.99,  44.99,  76.99,  61.49,  54.99,  86.99,  56.99,
#         59.99,  41.82,  89.97,  37.31,  95.99,  36.99,  86.26,  73.99,
#         37.49,  68.99,  22.99,  32.49,  26.99,  41.99,  55.99,  32.59,
#         66.99,  27.49,  46.99,  39.99,  85.36,  42.31,  69.99,  60.99,
#         81.26,  64.32,  50.59,  90.99,  46.82,  27.99,  40.65,  17.99,
#         51.99,  34.99,  77.89,  65.99,  31.99,  52.49,  29.99,  44.02,
#        115.99,  67.39,  71.43,  57.4 ,  85.99,  43.84,  66.89, 106.89,
#         55.59, 107.98,  46.97,  78.6 ,  49.99,  80.36,  91.99,  32.31,
#         69.89,  48.84,  20.3 ,  45.65,  24.8 ,  66.43,  48.99,  60.53,
#         75.89,  76.38,  67.88,  65.53,  36.6 ,  43.99,  51.4 ,  42.1 ,
#        108.04,  81.99,  54.68,  80.59,  36.82,  78.99,  51.97,  79.02,
#        120.99,  54.32,  49.3 ,  48.4 ,  94.97,  80.89,  82.21,  50.65,
#         34.63,  37.59,  27.8 ,  85.59,  80.99,  32.99,  52.31,  83.6 ,
#         31.6 ,  76.49,  74.99,  47.88,  29.63,  62.4 ,  55.53,  49.68,
#         79.58,  85.89,  80.98,  84.99,  43.49,  61.5 ,  86.5 ,  65.09,
#         54.73,  51.27,  78.15,  70.09,  45.59,  59.73,  58.  ,  75.12,
#         40.59,  36.26,  31.66,  56.27,  62.49,  49.34,  44.34,  53.99,
#         64.26,  45.34,  87.61,  49.73,  38.95,  41.26,  45.01,  63.  ,
#         55.6 ,  48.47,  75.99,  91.01,  83.15,  35.59,  84.02,  71.89,
#         52.58,  75.32,  93.99,  47.61,  47.49,  77.08,  78.78,  56.26,
#         43.95,  69.26,  68.98,  68.85,  31.26,  24.07,  80.32,  53.47,
#         91.81,  43.47,  66.27,  46.27,  95.89,  39.95,  29.8 ,  98.98,
#         36.66,  82.39,  66.34,  36.93,  41.39,  55.87,  40.05,  60.87,
#         25.3 ,  56.76,  46.39,  57.31,  63.67,  36.39,  48.92,  32.26,
#         71.34,  43.41,  45.05,  59.63,  80.47,  41.93,  55.4 ,  49.84,
#         31.93,  44.4 ,  65.66,  84.58,  47.31,  46.28,  53.38,  48.95,
#         19.99,  89.14,  46.4 , 106.94,  24.99,  36.49,  85.47,  54.84,
#         84.7 ,  72.1 ,  75.87,  29.74,  44.84,  39.13,  40.99,  58.67,
#         82.44,  37.92,  77.44,  49.4 ,  77.1 ,  37.26,  61.34,  64.63,
#         43.59,  61.89,  51.38,  78.33,  38.41,  64.3 ,  34.93,  83.98,
#         39.39,  27.26,  56.93,  81.  ,  48.41,  92.46,  29.2 ,  66.83,
#         86.  ,  70.66,  35.05,  91.29,  72.31,  66.3 ,  34.2 ,  51.93,
#         24.74,  41.28,  81.34,  45.19,  88.48,  53.95,  89.46,  58.27,
#         42.99,  67.31, 111.94,  79.7 ,  61.76,  70.99, 100.99,  50.19,
#        105.89,   0.  ,  56.3 ,  42.19,  86.89, 101.13,  51.28,  71.62,
#         56.39,  79.99,  61.39,  88.99,  75.33,  74.89,  62.3 ,  50.87,
#         32.8 ,  95.98,  71.29,  99.89,  48.59,  47.6 , 104.98,  51.6 ,
#         68.75,  89.39,  64.87,  96.26,  39.51,  35.31,  81.3 ,  27.59,
#         41.97,  42.6 ,  38.49,  35.4 ,  39.82,  73.98,  51.98,  62.03,
#         47.1 ,  44.68,  73.18,  53.81,  81.5 ,  37.03,  53.67,  44.51,
#         68.48,  97.98,  46.6 , 113.04, 103.89,  52.77,  51.44, 106.99,
#         91.89,  35.65,  84.89,  67.27, 105.99,  56.82,  96.93,  60.01,
#         51.52,  48.81,  67.14,  55.01,  65.4 ,  40.78,  56.52,  62.78,
#         45.78,  72.14,  41.42,  52.4 ,  97.99,  36.42,  47.99,  70.4 ,
#        118.99,  79.37,  63.99,  62.63,  83.5 ,  89.73,  78.5 ,  45.32,
#         60.14,  58.4 ,  43.68,  57.99,  64.6 , 109.98,  31.81,  78.47,
#         35.78,  60.4 ,  67.78,  39.22,  57.39,  46.52,  38.01,  64.39,
#         62.99,  57.63,  85.98,  63.4 ,  47.94,  43.81,  50.32,  24.23,
#         31.42,  42.98,  70.6 ,  38.62,  40.32,  87.99, 105.42,  90.89,
#         36.81,  69.6 ,  84.37,  48.68,  37.13,  44.22,  79.13,  67.  ,
#         64.4 ,  56.42, 130.98,  71.77,  52.99,  38.68,  85.4 ,  91.36,
#         40.62,  26.81, 101.72,  40.09,  47.7 ,  53.4 ,  95.3 ,  39.81,
#         59.6 ,  80.4 ,  71.52,  94.73,  21.99,  94.89,  65.14,  63.51,
#         45.42,  64.52,  75.83,  50.01,  43.62,  69.98,  51.42,  89.89,
#         80.83,  55.98, 102.3 ,  49.81,  82.98,  52.94,  79.32,  46.55,
#         42.13,  84.32,  70.91,  40.42, 123.99,  66.52,  34.42,  41.83,
#         61.98,  33.41,  47.4 ,  87.22,  53.35,  57.01,  62.01,  32.87,
#         37.61,  67.6 ,  42.61,  72.6 ,  58.35,  47.55,  51.21,  47.19,
#         64.85,  44.2 ,  81.91,  40.4 ,  57.92,  83.22,  61.27,  39.2 ,
#         41.14,  52.55,  49.2 ,  67.07,  90.66,  56.21,  37.19,  32.61,
#         37.87,  50.29,  93.9 ,  95.66,  86.91, 118.25,  79.59,  25.42,
#        108.95,  46.14, 120.94,  59.54,  47.01,  72.07,  48.35,  90.15,
#         64.01,  79.56,  38.96,  65.34,  85.9 ,  45.29, 108.25,  88.22,
#         81.32,  42.62,  27.87,  62.6 ,  69.91,  46.21,  32.6 ,  79.07,
#         68.35,  35.61,  69.07,  62.92,  30.42,  44.48,  49.39,  81.89,
#         52.01, 102.65,  53.41,  44.39,  55.29, 128.89,  58.98,  57.19,
#         52.92,  92.99,  52.61,  46.03,  74.07,  73.26,  47.87,  84.56,
#         72.01,  63.2 ,  51.03,  57.61, 110.89,  66.4 ,  82.6 ,  86.32,
#         57.89,  95.15,  62.19,  69.85, 115.89,  39.8 ,  73.35,  72.98,
#         87.6 ,  35.3 ,  72.74,  47.8 , 127.98,  77.01,  44.81,  69.  ,
#         30.  ,  77.73,  76.84,  97.09, 113.95, 120.98,  42.55, 102.5 ,
#         78.98, 135.9 ,  57.34,  20.59, 135.89,  59.55,  52.19,  35.  ,
#         83.25,  59.4 ,  67.74,  47.62,  56.98,  49.6 ,  90.9 ])

# %%
dados_droped['fl_3g'].equals(dados_droped['fl_4g'])
# Out:
# False

# %%
dados_droped['fl_3g'].equals(dados_droped['fl_5g'])
# Out:
# False

# %%
dados_droped['fl_4g'].equals(dados_droped['fl_5g'])
# Out:
# False

# %%
dados_droped['trocou_aparelho'].unique()
# Out:
# array([0, 1])

# %%
dados_droped['idade'].unique()
# Out:
# array([ 57,  39,  36,  44,  60,  76,  56,  38,  67,  32,  54,  31,  58,
#         42,  47,  35,  50,  63,  69,  75,  62,  45,  55,  53,  64,  40,
#         48,  68,  24,  65,  41,  30,  33,  43,  23,  52,  21,  27,  22,
#         59,  28,  61,  46,  37,  20,  26,  49,  34,  66,  29,  19,  74,
#         25,  79,  51,  80,  70,  71,  81,  77,  83,  78,  93,  84,  72,
#         18,  73,  91,  82,  88,   1,  85, 122, 102,  86,  87,  92,  94,
#         89,   2,   4,  90,  96,  11,  17, 111,  16,  95])

# %% [markdown]
# ***
# ## Exploração dos dados

# %% [markdown]
# ### seleção de features

# %%
# define features
X_ta = dados_droped[['fabricante', 'modelo', 'ranking', 'aging_aparelho', 
                     'offertechnology', 
                     'statedesc', 'subscribermainofferdesc', 'assignedchargeamount', 
                     'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']]
X_ta
# Out:
#                                      fabricante  \
# 0       Motorola Mobility LLC, a Lenovo Company
# 1                                       SAMSUNG
# 2                                 Samsung Korea
# 3                                 Samsung Korea
# 4                                       SAMSUNG
# ...                                         ...
# 135894  Motorola Mobility LLC, a Lenovo Company
# 135895                                  SAMSUNG
# 135896                                  SAMSUNG
# 135897                                  SAMSUNG
# 135898                            Samsung Korea
#
#                                      modelo  ranking  aging_aparelho  \
# 0                               CAPRIPLUS21        1              13
# 1                  GALAXY J6 (SM-J600GT DS)        1              15
# 2                                GALAXY A11        1              16
# 3                         GALAXY S20 FE LTE        1              12
# 4                 GALAXY S10E (SM-G970F,DS)        1              14
# ...                                     ...      ...             ...
# 135894                           MOTO E(6)S        1              12
# 135895              GALAXY A5 (SM-A520F DS)        1              16
# 135896  GALAXY GRAND PRIME DUOS (SM-G532MT)        1              16
# 135897            GALAXY J6 PLUS (SM-J610F)        1              14
# 135898                           GALAXY A02        1              14
#
#        offertechnology          statedesc     subscribermainofferdesc  \
# 0             Controle  RIO GRANDE DO SUL     CONTROLE VANTAGENS 10GB
# 1             Controle  RIO GRANDE DO SUL  VIVO CONTROLE 11GB - ANUAL
# 2             Controle  RIO GRANDE DO SUL        VIVO CONTROLE 11GB I
# 3             Controle  RIO GRANDE DO SUL       VIVO CONTROLE 6GB III
# 4             Controle  RIO GRANDE DO SUL         VIVO CONTROLE 9GB I
# ...                ...                ...                         ...
# 135894        Controle          SAO PAULO     CONTROLE VANTAGENS 10GB
# 135895        Controle          SAO PAULO         VIVO CONTROLE 9GB I
# 135896        Controle          SAO PAULO           VIVO CONTROLE 4GB
# 135897        Controle          SAO PAULO        VIVO CONTROLE 11GB I
# 135898        Controle          SAO PAULO    VIVO CONTROLE 5GB II PLN
#
#         assignedchargeamount  fl_3g  fl_4g  fl_5g  dt_ano_stts  idade
# 0                      64.99    0.0    1.0    0.0         2020     57
# 1                      72.03    0.0    1.0    0.0         2018     39
# 2                      71.99    0.0    1.0    0.0         2020     36
# 3                      45.99    0.0    1.0    0.0         2021     44
# 4                      56.49    0.0    1.0    0.0         2018     60
# ...                      ...    ...    ...    ...          ...    ...
# 135894                 64.99    0.0    1.0    0.0         2020     69
# 135895                 57.01    0.0    1.0    0.0         2016     61
# 135896                 37.61    0.0    1.0    0.0         2017     82
# 135897                 72.60    0.0    1.0    0.0         2018     42
# 135898                 34.99    0.0    1.0    0.0         2020     64
#
# [135899 rows x 13 columns]

# %%
X_ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135899 entries, 0 to 135898
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   fabricante               135899 non-null  object
#  1   modelo                   135899 non-null  object
#  2   ranking                  135899 non-null  int64
#  3   aging_aparelho           135899 non-null  int64
#  4   offertechnology          135899 non-null  object
#  5   statedesc                135899 non-null  object
#  6   subscribermainofferdesc  135899 non-null  object
#  7   assignedchargeamount     135899 non-null  float64
#  8   fl_3g                    135899 non-null  float64
#  9   fl_4g                    135899 non-null  float64
#  10  fl_5g                    135899 non-null  float64
#  11  dt_ano_stts              135899 non-null  int64
#  12  idade                    135899 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 13.5+ MB

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s_ta = (X_ta.dtypes == 'object')
object_cols_ta = list(s_ta[s_ta].index)
print("Categorical variables: ", len(object_cols_ta))
print(object_cols_ta)
# Out:
# Categorical variables:  5
# ['fabricante', 'modelo', 'offertechnology', 'statedesc', 'subscribermainofferdesc']

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols_ta = [cname for cname in X_ta.columns if X_ta[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols_ta))
print(numerical_cols_ta)
# Out:
# Numerical variables:  8
# ['ranking', 'aging_aparelho', 'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']

# %% [markdown]
# ***
# ## Mostrando a correlação entre os dados numéricos

# %%
corr_trocou_aparelho = dados_droped[['fabricante', 'modelo',
                                     'ranking', 'aging_aparelho',
                                     'offertechnology', 
                                     'statedesc', 'subscribermainofferdesc',
                                     'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                                     'dt_ano_stts', 'idade', 'trocou_aparelho']]

# %%
corr = corr_trocou_aparelho.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
dados_droped['mes_jan'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-01') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-01')

dados_droped['mes_fev'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-02') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-02')

dados_droped['mes_mar'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-03') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-03')

dados_droped['mes_abr'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-04') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-04')

dados_droped['mes_mai'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-05') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-05')

dados_droped['mes_jun'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-06') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-06')

dados_droped['mes_jul'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-07') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-07')  
                                                
dados_droped['mes_ago'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-08') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-08')

dados_droped['mes_set'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-09') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-09')

dados_droped['mes_out'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-10') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-10')

dados_droped['mes_nov'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-11') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-11')

dados_droped['mes_dez'] = (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2020-12') | \
                          (pd.to_datetime(dados_droped['dt_inicio']).dt.to_period('M') == '2021-12')

# %%
corr_meses_troca = dados_droped[['mes_jan', 'mes_fev', 'mes_mar', 'mes_abr', 
								 'mes_mai', 'mes_jun', 'mes_jul', 'mes_ago', 
								 'mes_set', 'mes_out', 'mes_nov', 'mes_dez', 'trocou_aparelho']]

# %%
corr_Test = corr_meses_troca.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr_Test, xticklabels = corr_Test.columns, yticklabels = corr_Test.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target trocou_aparelho

# %%
def plot_feature_freq(df, feature, qt_cat):
    labels, counts = np.unique(df[feature].dropna(), return_counts=True)

    # ordena pelas mais frequentes
    order = np.argsort(counts)[::-1]
    labels, counts = labels[order], counts[order]

    g = sns.barplot(labels[:qt_cat], counts[:qt_cat])
    g.set_xticklabels(labels[:qt_cat], rotation=90)
    
    return g

# %%
# define target
y_trocou_aparelho = dados_droped['trocou_aparelho']

c_trocou_aparelho = Counter(y_trocou_aparelho)
c_trocou_aparelho
# Out:
# Counter({0: 87786, 1: 48113})

# %%
# # calculo da proporção da base
# estimate = c_trocou_aparelho[0] / c_trocou_aparelho[1]
# estimate

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(dados_droped, 'trocou_aparelho', len(dados_droped['trocou_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Modelagem trocou_aparelho

# %%
# Dividindo as features em dados de treino e teste
X_train_ta, X_val_ta, y_train_ta, y_val_ta = train_test_split(X_ta, 
                                                              y_trocou_aparelho, 
                                                              test_size=0.5, 
                                                              random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer_ta = Pipeline([
                                     ('scaler', StandardScaler())
                                    ])

# Pré-processamento para Dados Categóricos
categorical_transformer_ta = Pipeline([
                                       ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                      ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor_ta = ColumnTransformer(transformers=[
                                                  ('num', numerical_transformer_ta, numerical_cols_ta),
                                                  ('cat', categorical_transformer_ta, object_cols_ta)
                                                 ], n_jobs=-1)

pipeline_ta = Pipeline(steps=[
                              ('preprocessor', preprocessor_ta),
                              ('smote', SMOTE(random_state=42, n_jobs=-1)),
#                               ('model', RandomForestClassifier(random_state=2048))
                              ('model', GradientBoostingClassifier(random_state=2048))
#                               ('model', XGBClassifier(scale_pos_weight=estimate, random_state=2048))
                             ])

# Preprocessing of training data, fit model 
pipeline_ta.fit(X_train_ta, y_train_ta)

# Predictions
# preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds_ta = pipeline_ta.predict(X_val_ta)

# %%
c_train_ta = Counter(y_train_ta)
c_train_ta
# Out:
# Counter({1: 24114, 0: 43835})

# %%
c_val_ta = Counter(y_val_ta)
c_val_ta
# Out:
# Counter({0: 43951, 1: 23999})

# %%
c_preds_ta = Counter(preds_ta)
c_preds_ta
# Out:
# Counter({1: 32269, 0: 35681})

# %% [markdown]
# ***
# ## Métricas

# %%
print(classification_report(y_val_ta, preds_ta))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.64      0.71     43951
#            1       0.52      0.69      0.59     23999
#
#     accuracy                           0.66     67950
#    macro avg       0.65      0.67      0.65     67950
# weighted avg       0.70      0.66      0.67     67950

# %%
cm_df_ta = pd.DataFrame(confusion_matrix(y_val_ta, preds_ta),
                     index = sorted(Counter(y_val_ta)),
                     columns = sorted(Counter(preds_ta)))
cm_df_ta
# Out:
#        0      1
# 0  28323  15628
# 1   7358  16641

# %%
# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline_ta,
        X_val_ta,
        y_val_ta,
        display_labels=['Não Trocou', 'Trocou'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[28323 15628]
#  [ 7358 16641]]
# Normalized confusion matrix
# [[0.6444222  0.3555778 ]
#  [0.30659611 0.69340389]]

# %% [markdown]
# ## Captação dos clientes que foram previstos como Propensos a Fazer uma Compra

# %%
X_val_ta['trocou_aparelho'] = y_val_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho', len(X_val_ta['trocou_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %%
X_val_ta['trocou_aparelho_previsto'] = preds_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho_previsto', len(X_val_ta['trocou_aparelho_previsto'].unique()))
# Out:
# <AxesSubplot:>

# %%
X_val_ta['cpfidentifier'] = dados_droped['cpfidentifier']
# X_val_ta

# %%
X_val_ta['dt_inicio'] = dados_droped['dt_inicio']
# X_val_ta

# %%
X_val_ta['dt_fim'] = dados_droped['dt_fim']
X_val_ta
# Out:
#                                      fabricante                        modelo  \
# 48027                                        LG                          P698
# 132424                                 MOTOROLA      MOTO G7 POWER (XT1955-1)
# 15334                             Samsung Korea                    GALAXY A11
# 96535                                        LG                    LM-K420BMW
# 52090                             Samsung Korea                   GALAXY A02S
# ...                                         ...                           ...
# 37323   Motorola Mobility LLC, a Lenovo Company                         MALTA
# 89972                                   SAMSUNG  GALAXY J2 CORE (SM-J260M,DS)
# 7688    Motorola Mobility LLC, a Lenovo Company         MOTO E PLAY (5TH GEN)
# 69531                                     NOKIA                          3200
# 39280                                   SAMSUNG     GALAXY A51 (SM-A515F,DSN)
#
#         ranking  aging_aparelho offertechnology       statedesc  \
# 48027         1              15        Controle  ESPIRITO SANTO
# 132424        1              15        Controle       SAO PAULO
# 15334         1              15        Controle    MINAS GERAIS
# 96535         1              16        Controle       SAO PAULO
# 52090         1              15        Controle  ESPIRITO SANTO
# ...         ...             ...             ...             ...
# 37323         1              13        Controle    MINAS GERAIS
# 89972         1              14        Controle       SAO PAULO
# 7688          1              15        Controle          PARANA
# 69531         1              12        Controle  RIO DE JANEIRO
# 39280         1              17        Controle    MINAS GERAIS
#
#              subscribermainofferdesc  assignedchargeamount  fl_3g  fl_4g  \
# 48027    VIVO CONTROLE 11GB - MENSAL                 66.43    1.0    0.0
# 132424           VIVO CONTROLE 9GB I                 57.01    0.0    1.0
# 15334   VIVO CTRL DIGITAL-11GB ILIM_                 66.34    0.0    1.0
# 96535            VIVO CONTROLE 9GB I                 57.01    0.0    1.0
# 52090           VIVO CONTROLE 4GB IV                 32.49    0.0    1.0
# ...                              ...                   ...    ...    ...
# 37323     VIVO CONTROLE 14GB - ANUAL                 91.99    0.0    1.0
# 89972           VIVO CONTROLE 8GB II                 55.99    0.0    1.0
# 7688            VIVO CONTROLE 5GB IV                 36.99    0.0    1.0
# 69531     VIVO CONTROLE 7GB - MENSAL                 51.52    0.0    1.0
# 39280    VIVO CONTROLE 11GB - ANUAL_                 66.34    0.0    1.0
#
#         fl_5g  dt_ano_stts  idade  trocou_aparelho  trocou_aparelho_previsto  \
# 48027     0.0         2011     71                0                         1
# 132424    0.0         2018     45                0                         1
# 15334     0.0         2020     34                1                         0
# 96535     0.0         2021     51                0                         0
# 52090     0.0         2020     67                0                         0
# ...       ...          ...    ...              ...                       ...
# 37323     0.0         2020     58                0                         0
# 89972     0.0         2018     64                0                         0
# 7688      0.0         2018     43                1                         1
# 69531     0.0         2018     68                0                         0
# 39280     0.0         2020     50                0                         0
#
#         cpfidentifier   dt_inicio      dt_fim
# 48027      6083144710  2021-07-13         NaN
# 132424    26804630807  2021-07-02         NaN
# 15334      9524687607  2020-10-16  2022-02-14
# 96535     12256123812  2021-06-01         NaN
# 52090      1533766789  2021-06-29         NaN
# ...               ...         ...         ...
# 37323     50685686604  2021-09-05         NaN
# 89972     62831780810  2021-08-05         NaN
# 7688       2111091936  2021-02-03  2022-05-17
# 69531     82319251715  2021-10-16         NaN
# 39280     96910097653  2021-04-21         NaN
#
# [67950 rows x 18 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Separando as bases para outro modelo

# %%
base_to_pred_month = X_val_ta[X_val_ta['trocou_aparelho_previsto'] == 1].reset_index(drop=True)
base_to_pred_month
# Out:
#                                     fabricante                        modelo  \
# 0                                           LG                          P698
# 1                                     MOTOROLA      MOTO G7 POWER (XT1955-1)
# 2                                Samsung Korea                   GALAXY A21S
# 3                                      SAMSUNG  GALAXY J2 CORE (SM-J260M,DS)
# 4                                      SAMSUNG     GALAXY A30S (SM-A307G,DS)
# ...                                        ...                           ...
# 32264                            Samsung Korea                    GALAXY A10
# 32265                                   XIAOMI           REDMI 7 (M1810F6LG)
# 32266                                  SAMSUNG  GALAXY J5 DUOS (SM-J500M DS)
# 32267                                  SAMSUNG  GALAXY J1 MINI (SM-J105B DL)
# 32268  Motorola Mobility LLC, a Lenovo Company         MOTO E PLAY (5TH GEN)
#
#        ranking  aging_aparelho offertechnology          statedesc  \
# 0            1              15        Controle     ESPIRITO SANTO
# 1            1              15        Controle          SAO PAULO
# 2            1              12        Controle       MINAS GERAIS
# 3            1              18        Controle  RIO GRANDE DO SUL
# 4            1              14        Controle     RIO DE JANEIRO
# ...        ...             ...             ...                ...
# 32264        1              13        Controle          SAO PAULO
# 32265        1              12        Controle       MINAS GERAIS
# 32266        1              14        Controle          SAO PAULO
# 32267        1              15        Controle       MINAS GERAIS
# 32268        1              15        Controle             PARANA
#
#                 subscribermainofferdesc  assignedchargeamount  fl_3g  fl_4g  \
# 0           VIVO CONTROLE 11GB - MENSAL                 66.43    1.0    0.0
# 1                   VIVO CONTROLE 9GB I                 57.01    0.0    1.0
# 2                  VIVO CONTROLE 5GB IV                 36.99    0.0    1.0
# 3              VIVO CONTROLE 7GB_ANUAL_                 51.52    0.0    1.0
# 4                 VIVO CONTROLE 6GB III                 50.99    0.0    1.0
# ...                                 ...                   ...    ...    ...
# 32264              VIVO CONTROLE 4GB IV                 32.49    0.0    1.0
# 32265              VIVO CONTROLE 11GB I                 71.99    0.0    1.0
# 32266       VIVO CONTROLE 11GB - MENSAL                 76.99    0.0    1.0
# 32267  VIVO CONTROLE 10GB PLN I - ANUAL                 59.63    1.0    0.0
# 32268              VIVO CONTROLE 5GB IV                 36.99    0.0    1.0
#
#        fl_5g  dt_ano_stts  idade  trocou_aparelho  trocou_aparelho_previsto  \
# 0        0.0         2011     71                0                         1
# 1        0.0         2018     45                0                         1
# 2        0.0         2020     50                0                         1
# 3        0.0         2018     33                1                         1
# 4        0.0         2019     41                0                         1
# ...      ...          ...    ...              ...                       ...
# 32264    0.0         2019     29                0                         1
# 32265    0.0         2019     45                0                         1
# 32266    0.0         2016     70                1                         1
# 32267    0.0         2016     55                1                         1
# 32268    0.0         2018     43                1                         1
#
#        cpfidentifier   dt_inicio      dt_fim
# 0         6083144710  2021-07-13         NaN
# 1        26804630807  2021-07-02         NaN
# 2         2730451641  2021-09-25         NaN
# 3        38660885821  2020-08-04  2022-02-11
# 4         5294300702  2021-08-03         NaN
# ...              ...         ...         ...
# 32264    41968173862  2021-08-30         NaN
# 32265     8407318680  2021-10-07         NaN
# 32266    85579718853  2021-03-05  2022-05-14
# 32267    60991089634  2021-02-19  2022-05-21
# 32268     2111091936  2021-02-03  2022-05-17
#
# [32269 rows x 18 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target aging_aparelho

# %%
# define target
y = base_to_pred_month['aging_aparelho']

# %%
# contagem de aging
from collections import Counter

c = Counter(y)
c
# Out:
# Counter({15: 4531, 12: 5924, 18: 3835, 14: 4612, 17: 4028, 16: 3976, 13: 5363})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(base_to_pred_month, 'aging_aparelho', len(base_to_pred_month['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Definicão das features

# %%
# define features
X = base_to_pred_month[['fabricante', 'modelo',
                        'ranking',
                        'offertechnology', 
                        'statedesc', 'subscribermainofferdesc',
                        'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                        'dt_ano_stts', 'idade']]
X
# Out:
#                                     fabricante                        modelo  \
# 0                                           LG                          P698
# 1                                     MOTOROLA      MOTO G7 POWER (XT1955-1)
# 2                                Samsung Korea                   GALAXY A21S
# 3                                      SAMSUNG  GALAXY J2 CORE (SM-J260M,DS)
# 4                                      SAMSUNG     GALAXY A30S (SM-A307G,DS)
# ...                                        ...                           ...
# 32264                            Samsung Korea                    GALAXY A10
# 32265                                   XIAOMI           REDMI 7 (M1810F6LG)
# 32266                                  SAMSUNG  GALAXY J5 DUOS (SM-J500M DS)
# 32267                                  SAMSUNG  GALAXY J1 MINI (SM-J105B DL)
# 32268  Motorola Mobility LLC, a Lenovo Company         MOTO E PLAY (5TH GEN)
#
#        ranking offertechnology          statedesc  \
# 0            1        Controle     ESPIRITO SANTO
# 1            1        Controle          SAO PAULO
# 2            1        Controle       MINAS GERAIS
# 3            1        Controle  RIO GRANDE DO SUL
# 4            1        Controle     RIO DE JANEIRO
# ...        ...             ...                ...
# 32264        1        Controle          SAO PAULO
# 32265        1        Controle       MINAS GERAIS
# 32266        1        Controle          SAO PAULO
# 32267        1        Controle       MINAS GERAIS
# 32268        1        Controle             PARANA
#
#                 subscribermainofferdesc  assignedchargeamount  fl_3g  fl_4g  \
# 0           VIVO CONTROLE 11GB - MENSAL                 66.43    1.0    0.0
# 1                   VIVO CONTROLE 9GB I                 57.01    0.0    1.0
# 2                  VIVO CONTROLE 5GB IV                 36.99    0.0    1.0
# 3              VIVO CONTROLE 7GB_ANUAL_                 51.52    0.0    1.0
# 4                 VIVO CONTROLE 6GB III                 50.99    0.0    1.0
# ...                                 ...                   ...    ...    ...
# 32264              VIVO CONTROLE 4GB IV                 32.49    0.0    1.0
# 32265              VIVO CONTROLE 11GB I                 71.99    0.0    1.0
# 32266       VIVO CONTROLE 11GB - MENSAL                 76.99    0.0    1.0
# 32267  VIVO CONTROLE 10GB PLN I - ANUAL                 59.63    1.0    0.0
# 32268              VIVO CONTROLE 5GB IV                 36.99    0.0    1.0
#
#        fl_5g  dt_ano_stts  idade
# 0        0.0         2011     71
# 1        0.0         2018     45
# 2        0.0         2020     50
# 3        0.0         2018     33
# 4        0.0         2019     41
# ...      ...          ...    ...
# 32264    0.0         2019     29
# 32265    0.0         2019     45
# 32266    0.0         2016     70
# 32267    0.0         2016     55
# 32268    0.0         2018     43
#
# [32269 rows x 12 columns]

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s = (X.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables: ", len(object_cols))
print(object_cols)
# Out:
# Categorical variables:  5
# ['fabricante', 'modelo', 'offertechnology', 'statedesc', 'subscribermainofferdesc']

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols))
print(numerical_cols)
# Out:
# Numerical variables:  7
# ['ranking', 'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade']

# %% [markdown]
# ***
# ## Mostrando a correlação entre os dados numéricos

# %%
corr_mes_previsao = base_to_pred_month[['fabricante', 'modelo',
                                        'ranking',
                                        'offertechnology', 
                                        'statedesc', 'subscribermainofferdesc',
                                        'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g',
                                        'dt_ano_stts', 'idade', 'aging_aparelho']]

# %%
corr2 = corr_mes_previsao.corr()

fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(corr2, xticklabels = corr2.columns, yticklabels = corr2.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Modelagem

# %%
# Dividindo as features em dados de treino e teste - 70% para dados de treinamento e 30% para dados de teste
X_train, X_val, y_train, y_val = train_test_split(X, 
                                                  y, 
                                                  test_size=0.5, 
                                                  random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer = Pipeline([
                                  ('scaler', StandardScaler())
                                 ])

# Pré-processamento para Dados Categóricos
categorical_transformer = Pipeline([
                                    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                   ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor = ColumnTransformer(transformers=[
                                                ('num', numerical_transformer, numerical_cols),
                                                ('cat', categorical_transformer, object_cols)
                                              ], n_jobs=-1)

pipeline = Pipeline(steps=[
                            ('preprocessor', preprocessor),
#                             ('smote', SMOTE(random_state=42, n_jobs=-1)),
                            ('model', RandomForestClassifier(random_state=2048))
#                             ('model', GradientBoostingClassifier(random_state=2048))
#                             ('model', XGBClassifier(scale_pos_weight=estimate, random_state=2048))
                          ])

# Preprocessing of training data, fit model 
pipeline.fit(X_train, y_train)

# Predictions
#preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds = pipeline.predict(X_val)

# %%
c_train = Counter(y_train)
c_train
# Out:
# Counter({17: 2011, 12: 3030, 13: 2635, 14: 2314, 18: 1888, 16: 2005, 15: 2251})

# %%
c_val = Counter(y_val)
c_val
# Out:
# Counter({18: 1947, 12: 2894, 13: 2728, 14: 2298, 16: 1971, 15: 2280, 17: 2017})

# %%
c_preds = Counter(preds)
c_preds
# Out:
# Counter({13: 2880, 14: 2221, 12: 3917, 16: 1651, 15: 2178, 17: 1683, 18: 1605})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(base_to_pred_month, 'aging_aparelho', len(base_to_pred_month['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***
# ## Métricas

# %%
print(classification_report(y_val, preds))
# Out:
#               precision    recall  f1-score   support
#
#           12       0.21      0.28      0.24      2894
#           13       0.19      0.20      0.20      2728
#           14       0.18      0.17      0.18      2298
#           15       0.18      0.17      0.17      2280
#           16       0.13      0.11      0.12      1971
#           17       0.18      0.15      0.16      2017
#           18       0.18      0.15      0.16      1947
#
#     accuracy                           0.18     16135
#    macro avg       0.18      0.18      0.18     16135
# weighted avg       0.18      0.18      0.18     16135

# %%
cm_df = pd.DataFrame(confusion_matrix(y_val, preds),
                     index = sorted(Counter(y_val)),
                     columns = sorted(Counter(preds)))
cm_df
# Out:
#      12   13   14   15   16   17   18
# 12  818  570  355  373  296  228  254
# 13  684  557  362  361  256  246  262
# 14  521  400  401  308  220  245  203
# 15  560  371  306  383  238  221  201
# 16  451  350  251  268  221  228  202
# 17  442  322  284  252  217  305  195
# 18  441  310  262  233  203  210  288

# %% [markdown]
# ## Plot non-normalized confusion matrix

# %%
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline,
        X_val,
        y_val,
        display_labels=['12', '13', '14', '15', '16', '17', '18'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[818 570 355 373 296 228 254]
#  [684 557 362 361 256 246 262]
#  [521 400 401 308 220 245 203]
#  [560 371 306 383 238 221 201]
#  [451 350 251 268 221 228 202]
#  [442 322 284 252 217 305 195]
#  [441 310 262 233 203 210 288]]
# Normalized confusion matrix
# [[0.28265377 0.19695923 0.12266759 0.12888735 0.10228058 0.07878369
#   0.0877678 ]
#  [0.25073314 0.20417889 0.13269795 0.13233138 0.09384164 0.09017595
#   0.09604106]
#  [0.22671889 0.1740644  0.17449956 0.13402959 0.09573542 0.10661445
#   0.08833768]
#  [0.24561404 0.1627193  0.13421053 0.16798246 0.10438596 0.09692982
#   0.08815789]
#  [0.22881786 0.17757484 0.12734652 0.13597159 0.11212582 0.11567732
#   0.10248605]
#  [0.21913733 0.15964303 0.14080317 0.12493803 0.10758552 0.15121468
#   0.09667824]
#  [0.22650231 0.15921931 0.134566   0.11967129 0.10426297 0.10785824
#   0.14791988]]

# %% [markdown]
# ***
# ## Mesclando resultados com tabela

# %% [markdown]
# ### Com a base de validação

# %%
X_val['aging_aparelho'] = y_val
# X_val

# %%
X_val['previsto'] = preds
# X_val

# %%
X_val['cpfidentifier'] = base_to_pred_month['cpfidentifier']
# X_val

# %%
X_val['dt_inicio'] = base_to_pred_month['dt_inicio']
# X_val

# %%
X_val['dt_fim'] = base_to_pred_month['dt_fim']
# X_val

# %% [markdown]
# ## Calculando data prevista

# %%
X_val['dt_fim_previsto'] = ((pd.to_datetime(X_val['dt_inicio']).dt.to_period('M')) + X_val['previsto'])
X_val
# Out:
#           fabricante                              modelo  ranking  \
# 5834           APPLE       IPHONE 6S PLUS TD-LTE (A1687)        1
# 18621          APPLE              IPHONE 6 LTE-A (A1549)        1
# 8431         SAMSUNG            GALAXY J6 (SM-J600GT DS)        1
# 18913        SAMSUNG       GALAXY J7 PRIME (SM-G610M DS)        1
# 23332         XIAOMI                     MI 9 (M1902F1G)        1
# ...              ...                                 ...      ...
# 17909        SAMSUNG  GALAXY J5 PRIME DUOS (SM-G570M DS)        1
# 2155         SAMSUNG              GALAXY A20S (SM-A207M)        1
# 8043   Samsung Korea                          GALAXY A10        1
# 13483       MOTOROLA            MOTO G7 POWER (XT1955-1)        1
# 14810        SAMSUNG        GALAXY J1 DUOS (SM-J120H DS)        1
#
#       offertechnology     statedesc     subscribermainofferdesc  \
# 5834         Controle  MINAS GERAIS    VIVO CONTROLE 7GB_ANUAL_
# 18621        Controle     SAO PAULO          VIVO CONTROLE 7GB_
# 8431         Controle     SAO PAULO        VIVO CONTROLE 5GB IV
# 18913        Controle  MINAS GERAIS  VIVO CONTROLE 7GB - MENSAL
# 23332        Controle        PARANA          VIVO CONTROLE 7GB_
# ...               ...           ...                         ...
# 17909        Controle     SAO PAULO    VIVO CONTROLE 7GB_ANUAL_
# 2155         Controle  MINAS GERAIS        VIVO CONTROLE 4GB IV
# 8043         Controle     SAO PAULO     VIVO CONTROLE-9GB ILIM_
# 13483        Controle     SAO PAULO      VIVO CONTROLE DIG-7GB_
# 14810        Controle  MINAS GERAIS    VIVO CONTROLE 5GB II PLN
#
#        assignedchargeamount  fl_3g  fl_4g  fl_5g  dt_ano_stts  idade  \
# 5834                  52.31    0.0    1.0    0.0         2015     68
# 18621                 58.35    0.0    1.0    0.0         2015     28
# 8431                  36.99    0.0    1.0    0.0         2018     63
# 18913                 56.99    0.0    1.0    0.0         2017     57
# 23332                 56.27    0.0    1.0    0.0         2019     49
# ...                     ...    ...    ...    ...          ...    ...
# 17909                 53.35    0.0    1.0    0.0         2017     43
# 2155                  32.49    0.0    1.0    0.0         2019     82
# 8043                  61.27    0.0    1.0    0.0         2019     41
# 13483                 53.35    0.0    1.0    0.0         2018     28
# 14810                 31.99    1.0    0.0    0.0         2015     63
#
#        aging_aparelho  previsto  cpfidentifier   dt_inicio      dt_fim  \
# 5834               18        13    18603955620  2021-03-28         NaN
# 18621              12        14    44279490880  2021-04-05  2022-04-17
# 8431               12        12     1544868847  2021-09-29         NaN
# 18913              18        16    58678115653  2021-04-05         NaN
# 23332              18        16    48928097134  2021-04-09         NaN
# ...               ...       ...            ...         ...         ...
# 17909              12        13    28252424899  2021-10-20         NaN
# 2155               15        13    71225480400  2021-07-02         NaN
# 8043               18        12    22522666860  2021-04-13         NaN
# 13483              14        12    34654620842  2021-01-07  2022-03-27
# 14810              13        13     1587629674  2021-09-19         NaN
#
#       dt_fim_previsto
# 5834          2022-04
# 18621         2022-06
# 8431          2022-09
# 18913         2022-08
# 23332         2022-08
# ...               ...
# 17909         2022-11
# 2155          2022-08
# 8043          2022-04
# 13483         2022-01
# 14810         2022-10
#
# [16135 rows x 18 columns]

# %%
c_preds
# Out:
# Counter({13: 2880, 14: 2221, 12: 3917, 16: 1651, 15: 2178, 17: 1683, 18: 1605})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val, 'aging_aparelho', len(X_val['aging_aparelho'].unique()))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val, 'previsto', len(X_val['previsto'].unique()))
# Out:
# <AxesSubplot:>
