# %%
## data
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.relativedelta import relativedelta
from unicodedata import normalize

## vis
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# contagem de aging
from collections import Counter

from IPython.display import display, HTML

## modelo
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve
from sklearn.metrics import average_precision_score, mean_absolute_error, roc_curve, auc, roc_auc_score
from scikitplot.metrics import plot_roc
from sklearn.model_selection import cross_val_score

# check xgboost version
from xgboost import XGBClassifier, XGBRegressor

import dill as pickle

## alertas
import warnings
warnings.filterwarnings("ignore")

# %%
# %pip install xgboost==1.5.0

# %% [markdown]
# ***
# ### Funções

# %%
def aucur(y_test, preds):
    # calculate AUC
    aucur = roc_auc_score(y_test, preds)
    print('AUC: %.3f' % aucur)

    # calculate roc curve
    fpr, tpr, thresholds = roc_curve(y_test, preds)

    # plot no skill
    plt.plot([0, 1], [0, 1], linestyle='--')
    # plot the roc curve for the model
    plt.plot(fpr, tpr, marker='.')
    # show the plot
    plt.show()

# %%
def just_check_nan(df):
    # Check NaN Pandas and Numpy
    missing_val_count_by_column = (df.isna().sum())

    columns_with_nan = missing_val_count_by_column[missing_val_count_by_column > 0]
    print('Dados com NaN:')
    print(columns_with_nan)
    print('')
    print('columns_with_nan.shape', columns_with_nan.shape)
    print('')

# %%
def plot_feature_freq(df, feature):
    labels, counts = np.unique(df[feature].dropna(), return_counts=True)
    total = counts[0] + counts[1]
    plt.figure(figsize=(10, 7))
    ax = sns.barplot(x=labels, y=(counts/total)*100, data = df)
    ax2 = sns.barplot(x=labels, y=counts, data = df)

    for p in ax.patches:
        ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x() + 0.3, p.get_height()+0.6), rotation = 0)

#     ax.set(xlabel='Trocou', ylabel='Porcentagem')
    ax.xaxis.label.set_size(20)
    ax.yaxis.label.set_size(20)
    plt.show()

# %%
def plot_feature_freq_mes(df, feature):
    labels, counts = np.unique(df[feature].dropna(), return_counts=True)
    total = counts[0] + counts[1] + counts[2] + counts[3] + counts[4] + counts[5] + counts[6]
    plt.figure(figsize=(10, 7))
    ax = sns.barplot(x=labels, y=(counts/total)*100, data = df)
    ax2 = sns.barplot(x=labels, y=counts, data = df)

    for p in ax.patches:
        ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x() + 0.3, p.get_height()+0.6), rotation = 0)

#     ax.set(xlabel='Trocou', ylabel='Porcentagem')
    ax.xaxis.label.set_size(20)
    ax.yaxis.label.set_size(20)
    plt.show()

# %% [markdown]
# ***
# ## Coleta de dados

# %%
FILE = "/kaggle/input/bigdata/batdtfim_full.csv"

# %%
client_chunks = []
dados_teste = pd.read_csv(FILE, sep = ";", 
                          header = 0, 
                          index_col = False, 
                          names = None, 
                          low_memory = False, 
                          chunksize = 10**5)

# %%
for chunk in dados_teste:

    new_clients = pd.DataFrame(chunk)

    # filter data chunk with frac percentage
#     new_clients = new_clients.sample(frac = 0.5)
    new_clients = new_clients.drop_duplicates()

    # saves to list
    client_chunks.append(new_clients)

dados = pd.concat(client_chunks).reset_index(drop = True)

# %%
# FILE = "/kaggle/input/datasetsnew/batdtfim500kage.csv"
# dados = pd.read_csv(FILE, sep = ';', encoding = 'ISO-8859-1', engine ='python')

dados = dados.rename(columns={'a.msisdn': 'msisdn'})\
             .rename(columns={'a.imsi': 'imsi'})\
             .rename(columns={'a.tac': 'tac'})\
             .rename(columns={'a.dt_inicio': 'dt_inicio'})\
             .rename(columns={'a.dt_fim': 'dt_fim'})\
             .rename(columns={'a.aging_aparelho': 'aging_aparelho'})\
             .rename(columns={'a.cat_aparelho': 'cat_aparelho'})\
             .rename(columns={'a.trocou_aparelho': 'trocou_aparelho'})\
             .rename(columns={'a.fabricante': 'fabricante'})\
             .rename(columns={'a.modelo': 'modelo'})\
             .rename(columns={'a.imei': 'imei'})\
             .rename(columns={'a.ranking': 'ranking'})\
             .rename(columns={'a.cpfidentifier': 'cpfidentifier'})\
             .rename(columns={'a.subscriberkey': 'subscriberkey'})\
             .rename(columns={'a.customerkey': 'customerkey'})\
             .rename(columns={'a.customersubtypedesc': 'customersubtypedesc'})\
             .rename(columns={'a.subscriberstatuskey': 'subscriberstatuskey'})\
             .rename(columns={'a.offertechnology': 'offertechnology'})\
             .rename(columns={'a.citydesc': 'citydesc'})\
             .rename(columns={'a.statedesc': 'statedesc'})\
             .rename(columns={'a.subscribermainofferdesc': 'subscribermainofferdesc'})\
             .rename(columns={'a.assignedchargeamount': 'assignedchargeamount'})\
             .rename(columns={'a.fl_3g': 'fl_3g'})\
             .rename(columns={'a.fl_4g': 'fl_4g'})\
             .rename(columns={'a.fl_5g': 'fl_5g'})\
             .rename(columns={'a.dt_ano_stts': 'dt_ano_stts'})\
             .rename(columns={'a.idade': 'idade'})\
             .rename(columns={'a.avg_msisdn': 'avg_msisdn'})\
             .rename(columns={'a.avg_cpf': 'avg_cpf'})\

dados
# Out:
#                 msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0        5511910001022  724102007034575  35501610  2020-12-29  2022-02-12
# 1        5511910005207  724101993391706  35658611  2021-04-20         NaN
# 2        5511910005218  724102090675583  35462311  2020-12-17  2022-03-24
# 3        5511910010851  724100500592447  86135502  2021-10-16         NaN
# 4        5511910011500  724102091149832  35583108  2021-03-24  2022-04-19
# ...                ...              ...       ...         ...         ...
# 7909329  5599992311385  724119815091378  35570711  2021-06-24         NaN
# 7909330  5599992316211  724119891126964  35997108  2021-01-11  2022-04-26
# 7909331  5599992316415  724119892026372  86717405  2021-04-30         NaN
# 7909332  5599996511912  724119107272077  35304309  2020-11-19  2022-03-05
# 7909333  5599999843834  724119895707385  35947609  2021-08-11         NaN
#
#          aging_aparelho  cat_aparelho  trocou_aparelho  \
# 0                    13             1                1
# 1                    18             1                0
# 2                    15             1                1
# 3                    12             1                0
# 4                    12             1                1
# ...                 ...           ...              ...
# 7909329              15             1                0
# 7909330              15             1                1
# 7909331              17             1                0
# 7909332              15             1                1
# 7909333              14             1                0
#
#                                              fabricante  \
# 0                                               SAMSUNG
# 1                                                    LG
# 2                                         Samsung Korea
# 3        Shenzhen Gionee Communication Equipment Co Ltd
# 4                                                 APPLE
# ...                                                 ...
# 7909329                                         SAMSUNG
# 7909330                                         SAMSUNG
# 7909331                                          XIAOMI
# 7909332                                           APPLE
# 7909333                                         SAMSUNG
#
#                             modelo  ...  statedesc  \
# 0        GALAXY S10E (SM-G970F,DS)  ...  SAO PAULO
# 1                       LM-K420BMW  ...  SAO PAULO
# 2                      GALAXY A10S  ...  SAO PAULO
# 3                      GIONEE M100  ...  SAO PAULO
# 4                 IPHONE 7 (A1660)  ...  SAO PAULO
# ...                            ...  ...        ...
# 7909329  GALAXY A51 (SM-A515F,DSN)  ...   MARANHAO
# 7909330  GALAXY J7 NEO (SM-J701MT)  ...   MARANHAO
# 7909331       REDMI 9A (M2006C3LG)  ...   MARANHAO
# 7909332           IPHONE X (A1901)  ...   MARANHAO
# 7909333   GALAXY J6 (SM-J600GT DS)  ...   MARANHAO
#
#                                    subscribermainofferdesc  \
# 0            LINHA ADICIONAL VIVO FAMILIA 20GB+220GB BONUS
# 1                                       VIVO CONTROLE 7GB_
# 2                                        VIVO CONTROLE 4GB
# 3                                   VIVO CONTROLE DIG-7GB_
# 4        LINHA ADICIONAL VIVO FAMILIA 10GB PLN+110GB BONUS
# ...                                                    ...
# 7909329                                 VIVO CONTROLE 7GB_
# 7909330                       VIVO CTRL DIGITAL-11GB ILIM_
# 7909331                                 VIVO CONTROLE 7GB_
# 7909332                                    TITULAR VIVO V
# 7909333                          VIVO CONTROLE DIGITAL 9GB
#
#          assignedchargeamount  fl_3g  fl_4g fl_5g dt_ano_stts idade  \
# 0                        0.00    0.0    1.0   0.0      2018.0  54.0
# 1                       53.35    0.0    1.0   0.0      2020.0  35.0
# 2                       37.61    0.0    1.0   0.0      2019.0  43.0
# 3                       53.35    0.0    0.0   0.0      2013.0  80.0
# 4                        0.00    0.0    1.0   0.0      2016.0  62.0
# ...                       ...    ...    ...   ...         ...   ...
# 7909329                 52.19    0.0    1.0   0.0      2020.0  41.0
# 7909330                 66.20    0.0    1.0   0.0      2017.0  43.0
# 7909331                 52.19    0.0    1.0   0.0      2020.0  34.0
# 7909332               1179.99    0.0    1.0   0.0      2017.0  40.0
# 7909333                 68.99    0.0    1.0   0.0      2018.0  53.0
#
#          avg_msisdn avg_cpf
# 0              13.0    13.0
# 1               0.0     0.0
# 2              15.0    15.0
# 3               0.0     0.0
# 4               0.0     6.5
# ...             ...     ...
# 7909329        17.0    17.0
# 7909330        15.0    15.0
# 7909331         0.0     0.0
# 7909332        15.0    15.0
# 7909333         0.0     0.0
#
# [7909334 rows x 29 columns]

# %% [markdown]
# ### Limpeza dos dados

# %%
just_check_nan(dados)
# Out:
# Dados com NaN:
# imsi                             1
# dt_fim                     6634955
# citydesc                   7909334
# statedesc                      580
# subscribermainofferdesc      13811
# assignedchargeamount         12354
# fl_3g                         1587
# fl_4g                         1587
# fl_5g                         1587
# dt_ano_stts                   1587
# idade                            3
# dtype: int64
#
# columns_with_nan.shape (11,)

# %%
dados_droped = dados.dropna(subset=['imsi',
                                         'statedesc', 
                                         'subscribermainofferdesc', 
                                         'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade'])\
                    .reset_index(drop=True)
# dados_droped

# %%
just_check_nan(dados_droped)
# Out:
# Dados com NaN:
# dt_fim      6620112
# citydesc    7892676
# dtype: int64
#
# columns_with_nan.shape (2,)

# %% [markdown]
# ### Equilibrando classes

# %%
dados_droped_0 = dados_droped[dados_droped['trocou_aparelho'] == 0].sample(frac=0.40, random_state=3)
dados_droped_1 = dados_droped[dados_droped['trocou_aparelho'] == 1]

# %%
dados_droped = pd.concat([dados_droped_0, dados_droped_1]).reset_index(drop=True).sort_values(by='msisdn', ascending=False)
dados_droped
# Out:
#                 msisdn             imsi       tac   dt_inicio      dt_fim  \
# 840454   5599999896182  724119112725652  35299710  2021-04-17         NaN
# 436271   5599999895337  724119897499129  35686411  2021-06-17         NaN
# 932924   5599999893979  724119891736125  35444089  2021-08-14         NaN
# 1139129  5599999893093  724119893248935  35900309  2021-09-16         NaN
# 3236070  5599999891775  724119892858749  86814005  2021-03-25  2022-06-07
# ...                ...              ...       ...         ...         ...
# 3320787  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 3009656  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 2981192  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 3236071  5511910000068  724102900228343  35634809  2021-01-14  2022-03-09
# 674762   5511910000062  724102902358054  35861910  2021-07-08         NaN
#
#          aging_aparelho  cat_aparelho  trocou_aparelho           fabricante  \
# 840454               18             1                0              SAMSUNG
# 436271               16             1                0                APPLE
# 932924               14             1                0                APPLE
# 1139129              13             1                0        HMD Global Oy
# 3236070              14             1                1               XIAOMI
# ...                 ...           ...              ...                  ...
# 3320787              15             1                1        Samsung Korea
# 3009656              15             1                1        Samsung Korea
# 2981192              15             1                1        Samsung Korea
# 3236071              13             1                1              SAMSUNG
# 674762               15             1                0  LG Electronics Inc.
#
#                                      modelo  ...  statedesc  \
# 840454            GALAXY J6 PLUS (SM-J610F)  ...   MARANHAO
# 436271                    IPHONE 11 (A2111)  ...   MARANHAO
# 932924            IPHONE 12 PRO MAX (A2342)  ...   MARANHAO
# 1139129                             TA-1333  ...   MARANHAO
# 3236070            POCO X3 NFC (M2007J20CT)  ...   MARANHAO
# ...                                     ...  ...        ...
# 3320787                       GALAXY S20 FE  ...  SAO PAULO
# 3009656                       GALAXY S20 FE  ...  SAO PAULO
# 2981192                       GALAXY S20 FE  ...  SAO PAULO
# 3236071  GALAXY J5 PRIME DUOS (SM-G570M DS)  ...  SAO PAULO
# 674762                                 K50S  ...  SAO PAULO
#
#                              subscribermainofferdesc  assignedchargeamount  \
# 840454                    TITULAR VIVO FAMILIA 100GB                299.99
# 436271                             VIVO CONTROLE 4GB                 36.86
# 932924   LINHA ADICIONAL VIVO FAMILIA 150GB - MENSAL                  0.00
# 1139129                 VIVO CTRL DIGITAL-11GB ILIM_                 66.20
# 3236070                   VIVO CONTROLE 11GB - ANUAL                 66.20
# ...                                              ...                   ...
# 3320787                       LINHA ADICIONAL VIVO V                  0.00
# 3009656                       LINHA ADICIONAL VIVO V                  0.00
# 2981192                       LINHA ADICIONAL VIVO V                  0.00
# 3236071                          VIVO CONTROLE 9GB I                 57.01
# 674762                             VIVO CONTROLE 4GB                 42.61
#
#          fl_3g  fl_4g fl_5g dt_ano_stts idade  avg_msisdn avg_cpf
# 840454     0.0    1.0   0.0      2018.0  43.0         0.0     0.0
# 436271     0.0    1.0   0.0      2020.0  29.0         0.0     0.0
# 932924     0.0    0.0   1.0      2021.0  64.0         0.0     0.0
# 1139129    0.0    1.0   0.0      2020.0  44.0         0.0     0.0
# 3236070    0.0    1.0   0.0      2020.0  48.0         0.0    14.0
# ...        ...    ...   ...         ...   ...         ...     ...
# 3320787    0.0    1.0   0.0      2020.0  42.0        15.0    14.5
# 3009656    0.0    1.0   0.0      2020.0  42.0         0.0    14.5
# 2981192    0.0    1.0   0.0      2020.0  42.0        14.0    14.5
# 3236071    0.0    1.0   0.0      2018.0  43.0         6.5     6.5
# 674762     0.0    1.0   0.0      2019.0  49.0         0.0     0.0
#
# [3972991 rows x 29 columns]

# %%
dados_droped = dados_droped.tail(dados_droped.shape[0] -5500000).reset_index(drop=True)
dados_droped['dt_ano_stts'] = dados_droped['dt_ano_stts'].astype(np.int64).reset_index(drop=True)
dados_droped['idade'] = np.asarray(dados_droped['idade'], dtype = 'int16')
dados_droped['fl_3g'] = np.asarray(dados_droped['fl_3g'], dtype = 'int8')
dados_droped['fl_4g'] = np.asarray(dados_droped['fl_4g'], dtype = 'int8')
dados_droped['fl_5g'] = np.asarray(dados_droped['fl_5g'], dtype = 'int8')
dados_droped
# Out:
#                 msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0        5543996327299  724064191621628  35614110  2021-06-21         NaN
# 1        5543996326700  724064004871663  35282311  2021-03-27         NaN
# 2        5543996326700  724064004871663  35282311  2021-03-27         NaN
# 3        5543996326700  724064004871663  35282311  2021-03-27         NaN
# 4        5543996326700  724064004871663  35282311  2021-03-27         NaN
# ...                ...              ...       ...         ...         ...
# 2445977  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 2445978  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 2445979  5511910000251  724102900236484  35912453  2020-12-21  2022-04-12
# 2445980  5511910000068  724102900228343  35634809  2021-01-14  2022-03-09
# 2445981  5511910000062  724102902358054  35861910  2021-07-08         NaN
#
#          aging_aparelho  cat_aparelho  trocou_aparelho           fabricante  \
# 0                    15             1                0              SAMSUNG
# 1                    18             1                0                APPLE
# 2                    18             1                0                APPLE
# 3                    18             1                0                APPLE
# 4                    18             1                0                APPLE
# ...                 ...           ...              ...                  ...
# 2445977              15             1                1        Samsung Korea
# 2445978              15             1                1        Samsung Korea
# 2445979              15             1                1        Samsung Korea
# 2445980              13             1                1              SAMSUNG
# 2445981              15             1                0  LG Electronics Inc.
#
#                                      modelo  ...  statedesc  \
# 0                 GALAXY A30 (SM-A305GT,DS)  ...     PARANA
# 1                     IPHONE 11 PRO (A2215)  ...     PARANA
# 2                     IPHONE 11 PRO (A2215)  ...     PARANA
# 3                     IPHONE 11 PRO (A2215)  ...     PARANA
# 4                     IPHONE 11 PRO (A2215)  ...     PARANA
# ...                                     ...  ...        ...
# 2445977                       GALAXY S20 FE  ...  SAO PAULO
# 2445978                       GALAXY S20 FE  ...  SAO PAULO
# 2445979                       GALAXY S20 FE  ...  SAO PAULO
# 2445980  GALAXY J5 PRIME DUOS (SM-G570M DS)  ...  SAO PAULO
# 2445981                                K50S  ...  SAO PAULO
#
#          subscribermainofferdesc  assignedchargeamount  fl_3g  fl_4g fl_5g  \
# 0             VIVO CONTROLE 7GB_                 56.27      0      1     0
# 1                TITULAR VIVO V                 876.70      0      1     0
# 2                TITULAR VIVO V                 876.70      0      1     0
# 3                TITULAR VIVO V                 876.70      0      1     0
# 4                TITULAR VIVO V                 876.70      0      1     0
# ...                          ...                   ...    ...    ...   ...
# 2445977   LINHA ADICIONAL VIVO V                  0.00      0      1     0
# 2445978   LINHA ADICIONAL VIVO V                  0.00      0      1     0
# 2445979   LINHA ADICIONAL VIVO V                  0.00      0      1     0
# 2445980      VIVO CONTROLE 9GB I                 57.01      0      1     0
# 2445981        VIVO CONTROLE 4GB                 42.61      0      1     0
#
#         dt_ano_stts idade  avg_msisdn avg_cpf
# 0              2019    36         0.0    0.00
# 1              2019    28        12.0   17.29
# 2              2019    28         0.0   17.29
# 3              2019    28        63.0   17.29
# 4              2019    28        26.0   17.29
# ...             ...   ...         ...     ...
# 2445977        2020    42        15.0   14.50
# 2445978        2020    42         0.0   14.50
# 2445979        2020    42        14.0   14.50
# 2445980        2018    43         6.5    6.50
# 2445981        2019    49         0.0    0.00
#
# [2445982 rows x 29 columns]

# %%
# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(dados_droped, 'trocou_aparelho')

# %%
dados_droped['dt_ano_stts'].unique()
# Out:
# array([2019, 2020, 2018, 2017, 2021, 2016, 2010, 2015, 2014, 2011, 2013,
#        2012, 2007, 2001, 2009, 2008, 2006, 2003, 2005, 2004, 1999, 2022])

# %% [markdown]
# ***
# ## Exploração dos dados

# %% [markdown]
# ### seleção de features

# %%
# define features
X_ta = dados_droped[['avg_cpf', 'ranking', 'avg_msisdn', 'aging_aparelho']]

# X_ta = dados_droped[['fabricante', 'ranking', 'aging_aparelho', 
#                      'avg_msisdn', 'avg_cpf',
#                      'dt_ano_stts']]

X_ta
# Out:
#          avg_cpf  ranking  avg_msisdn  aging_aparelho
# 0           0.00        1         0.0              15
# 1          17.29        1        12.0              18
# 2          17.29        1         0.0              18
# 3          17.29        1        63.0              18
# 4          17.29        1        26.0              18
# ...          ...      ...         ...             ...
# 2445977    14.50        1        15.0              15
# 2445978    14.50        1         0.0              15
# 2445979    14.50        1        14.0              15
# 2445980     6.50        1         6.5              13
# 2445981     0.00        1         0.0              15
#
# [2445982 rows x 4 columns]

# %%
X_ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2445982 entries, 0 to 2445981
# Data columns (total 4 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   avg_cpf         float64
#  1   ranking         int64
#  2   avg_msisdn      float64
#  3   aging_aparelho  int64
# dtypes: float64(2), int64(2)
# memory usage: 74.6 MB

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s_ta = (X_ta.dtypes == 'object')
object_cols_ta = list(s_ta[s_ta].index)
print("Categorical variables: ", len(object_cols_ta))
print(object_cols_ta)
# Out:
# Categorical variables:  0
# []

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols_ta = [cname for cname in X_ta.columns if X_ta[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols_ta))
print(numerical_cols_ta)
# Out:
# Numerical variables:  4
# ['avg_cpf', 'ranking', 'avg_msisdn', 'aging_aparelho']

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target trocou_aparelho

# %%
# define target
y_trocou_aparelho = dados_droped['trocou_aparelho']

c_trocou_aparelho = Counter(y_trocou_aparelho)
c_trocou_aparelho
# Out:
# Counter({0: 1615157, 1: 830825})

# %%
# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(dados_droped, 'trocou_aparelho')

# %% [markdown]
# ***
# ## Modelagem trocou_aparelho

# %%
# Dividindo as features em dados de treino e teste
X_train_ta, X_val_ta, y_train_ta, y_val_ta = train_test_split(X_ta, 
                                                              y_trocou_aparelho, 
                                                              test_size=0.5, 
                                                              random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer_ta = Pipeline([
                                     ('scaler', StandardScaler())
                                    ])

# Pré-processamento para Dados Categóricos
categorical_transformer_ta = Pipeline([
                                       ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                      ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor_ta = ColumnTransformer(transformers=[
                                                  ('num', numerical_transformer_ta, numerical_cols_ta),
                                                  ('cat', categorical_transformer_ta, object_cols_ta)
                                                 ], n_jobs=-1)

pipeline_ta = Pipeline(steps=[
                              ('preprocessor', preprocessor_ta),
                              ('smote', SMOTE(random_state=42, n_jobs=-1)),
                              ('model', XGBClassifier(random_state=2048, n_jobs=-1))
                             ])

# Preprocessing of training data, fit model 
pipeline_ta.fit(X_train_ta, y_train_ta)

# Predictions
# preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds_ta = pipeline_ta.predict(X_val_ta)
# Out:
# [14:30:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ### Save Model

# %%
# Use pickle to save model for next usage.
filename = 'model_trocou_aparelho.pk'
with open('./'+filename, 'wb') as file:
    pickle.dump(pipeline_ta, file)

# %%
train_yhat_ta = pipeline_ta.predict(X_train_ta)
train_acc_ta = accuracy_score(y_train_ta, train_yhat_ta)
print('Training Acuracy:', train_acc_ta)
val_acc_ta = accuracy_score(y_val_ta, preds_ta)
print('Validation Acuracy:', val_acc_ta)
# Out:
# Training Acuracy: 0.9662761214105419
# Validation Acuracy: 0.9657168368369023

# %%
c_train_ta = Counter(y_train_ta)
c_train_ta
# Out:
# Counter({1: 414776, 0: 808215})

# %%
c_val_ta = Counter(y_val_ta)
c_val_ta
# Out:
# Counter({0: 806942, 1: 416049})

# %%
c_preds_ta = Counter(preds_ta)
c_preds_ta
# Out:
# Counter({0: 785096, 1: 437895})

# %% [markdown]
# ***
# ## Métricas

# %%
aucur(y_val_ta, preds_ta)
# Out:
# AUC: 0.968

# %%
# # Multiply by -1 since sklearn calculates *negative* MAE
# scores = -1 * cross_val_score(pipeline_ta, X_val_ta, y_val_ta,
#                               cv=5, n_jobs=-1, verbose=2,
#                               scoring='f1')

# print("MAE scores:\n", scores)

# %%
print(classification_report(y_val_ta, preds_ta))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97    806942
#            1       0.93      0.98      0.95    416049
#
#     accuracy                           0.97   1222991
#    macro avg       0.96      0.97      0.96   1222991
# weighted avg       0.97      0.97      0.97   1222991

# %%
cm_df_ta = pd.DataFrame(confusion_matrix(y_val_ta, preds_ta),
                     index = sorted(Counter(y_val_ta)),
                     columns = sorted(Counter(preds_ta)))
cm_df_ta
# Out:
#         0       1
# 0  775055   31887
# 1   10041  406008

# %%
# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline_ta,
        X_val_ta,
        y_val_ta,
        display_labels=['Não Trocou', 'Trocou'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[775055  31887]
#  [ 10041 406008]]
# Normalized confusion matrix
# [[0.96048415 0.03951585]
#  [0.02413418 0.97586582]]

# %% [markdown]
# ***
# ***
# ***
# ### Testes com outros dados

# %%
FILE_teste = "/kaggle/input/datasetsnew/pca_tem_clientes_iphone_aging.csv"

# %%
client_chunks_teste = []
dados_teste2 = pd.read_csv(FILE_teste, sep = ";", 
                          header = 0, 
                          index_col = False, 
                          names = None, 
                          low_memory = False, 
                          chunksize = 10**5)

# %%
for chunk2 in dados_teste2:

    new_clients2 = pd.DataFrame(chunk2)

    # filter data chunk with frac percentage
    new_clients2 = new_clients2.sample(frac = 0.7)
    new_clients2 = new_clients2.drop_duplicates()

    # saves to list
    client_chunks_teste.append(new_clients2)

dados_val = pd.concat(client_chunks_teste).reset_index(drop = True)

# %%
dados_val = dados_val.rename(columns={'a.msisdn': 'msisdn'})\
                     .rename(columns={'a.imsi': 'imsi'})\
                     .rename(columns={'a.tac': 'tac'})\
                     .rename(columns={'a.dt_inicio': 'dt_inicio'})\
                     .rename(columns={'a.dt_fim': 'dt_fim'})\
                     .rename(columns={'a.aging_aparelho': 'aging_aparelho'})\
                     .rename(columns={'a.cat_aparelho': 'cat_aparelho'})\
                     .rename(columns={'a.trocou_aparelho': 'trocou_aparelho'})\
                     .rename(columns={'a.fabricante': 'fabricante'})\
                     .rename(columns={'a.modelo': 'modelo'})\
                     .rename(columns={'a.imei': 'imei'})\
                     .rename(columns={'a.ranking': 'ranking'})\
                     .rename(columns={'a.cpfidentifier': 'cpfidentifier'})\
                     .rename(columns={'a.subscriberkey': 'subscriberkey'})\
                     .rename(columns={'a.customerkey': 'customerkey'})\
                     .rename(columns={'a.customersubtypedesc': 'customersubtypedesc'})\
                     .rename(columns={'a.subscriberstatuskey': 'subscriberstatuskey'})\
                     .rename(columns={'a.offertechnology': 'offertechnology'})\
                     .rename(columns={'a.citydesc': 'citydesc'})\
                     .rename(columns={'a.statedesc': 'statedesc'})\
                     .rename(columns={'a.subscribermainofferdesc': 'subscribermainofferdesc'})\
                     .rename(columns={'a.assignedchargeamount': 'assignedchargeamount'})\
                     .rename(columns={'a.fl_3g': 'fl_3g'})\
                     .rename(columns={'a.fl_4g': 'fl_4g'})\
                     .rename(columns={'a.fl_5g': 'fl_5g'})\
                     .rename(columns={'a.dt_ano_stts': 'dt_ano_stts'})\
                     .rename(columns={'a.age': 'idade'})\
                     .rename(columns={'a.avg_msisdn': 'avg_msisdn'})\
                     .rename(columns={'a.avg_cpf': 'avg_cpf'})\
        #              .drop_duplicates().reset_index(drop=True)

dados_val
# Out:
#                msisdn             imsi       tac   dt_inicio      dt_fim  \
# 0       5513982272371  724102802341890  35025226  2021-07-03         NaN
# 1       5514998191787  724101991881703  35707683  2021-08-09         NaN
# 2       5521972041797  724112090115917  35030822  2021-05-01         NaN
# 3       5537998353480  724233766005165  35288411  2021-10-12         NaN
# 4       5516996374699  724100502236966  35682811  2021-06-11         NaN
# ...               ...              ...       ...         ...         ...
# 778701  5535998882006  724233610349506  35482609  2021-01-27  2022-05-07
# 778702  5564996000401  724066590206012  35660410  2021-05-04         NaN
# 778703  5517996055950  724102016672734  35913033  2021-03-31         NaN
# 778704  5551998381594  724065010714713  35570833  2021-07-23         NaN
# 778705  5571999668658  724117007009669  35052207  2021-07-24         NaN
#
#         aging_aparelho  cat_aparelho  trocou_aparelho fabricante  \
# 0                   15             1                0      APPLE
# 1                   14             1                0      APPLE
# 2                   17             1                0      APPLE
# 3                   12             1                0      APPLE
# 4                   16             1                0      APPLE
# ...                ...           ...              ...        ...
# 778701              15             1                1      APPLE
# 778702              17             1                0      APPLE
# 778703              18             1                0      APPLE
# 778704              14             1                0      APPLE
# 778705              14             1                0      APPLE
#
#                        modelo  ... assignedchargeamount  fl_3g  fl_4g  fl_5g  \
# 0           IPHONE SE (A2296)  ...                60.99      0      1      0
# 1           IPHONE 12 (A2403)  ...                72.60      0      0      1
# 2           IPHONE 11 (A2221)  ...                86.99      0      1      0
# 3           IPHONE XR (A2105)  ...                60.99      0      1      0
# 4           IPHONE XR (A2105)  ...                32.49      0      1      0
# ...                       ...  ...                  ...    ...    ...    ...
# 778701       IPHONE 7 (A1778)  ...                95.99      0      1      0
# 778702       IPHONE 7 (A1778)  ...               489.99      0      1      0
# 778703      IPHONE 11 (A2221)  ...                50.99      0      1      0
# 778704      IPHONE 11 (A2221)  ...                56.99      0      1      0
# 778705  IPHONE 12 PRO (A2341)  ...                55.99      0      0      1
#
#         dt_ano_stts idade avg_msisdn avg_cpf  a.peso_aparelho  \
# 0              2020    22        0.0     0.0             2296
# 1              2020    27        0.0     0.0             2403
# 2              2020    44        0.0     0.0             2221
# 3              2019    33        0.0     0.0             2105
# 4              2020    49        0.0     0.0             2105
# ...             ...   ...        ...     ...              ...
# 778701         2018    30       15.0    15.0             1778
# 778702         2019    42        0.0    13.0             1778
# 778703         2020    51        0.0     0.0             2221
# 778704         2021    26        0.0     0.0             2221
# 778705         2020    48        0.0     0.0             2341
#
#        a.update_software
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 778701                 0
# 778702                 0
# 778703                 1
# 778704                 1
# 778705                 1
#
# [778706 rows x 31 columns]

# %%
dados_outros_anos = dados_val[dados_val['dt_ano_stts'] != 2020]
dados_outros_anos['dt_ano_stts'].unique()
# Out:
# array([2019, 2016, 2018, 2017, 2015, 2021, 2014, 2013, 2012, 2011, 2010,
#        2009, 2008])

# %%
# dados_outros_anos = dados[dados['dt_ano_stts'] != 2020]
# dados_outros_anos['dt_ano_stts'].unique()

# %%
# just_check_nan(dados_outros_anos)
just_check_nan(dados_outros_anos)
# Out:
# Dados com NaN:
# dt_fim                     443982
# citydesc                   509542
# statedesc                      39
# subscribermainofferdesc      1303
# assignedchargeamount         1252
# dtype: int64
#
# columns_with_nan.shape (5,)

# %%
dados_val = dados_outros_anos.dropna(subset=['imsi',
                                             'statedesc', 
                                             'subscribermainofferdesc', 
                                             'assignedchargeamount', 'fl_3g', 'fl_4g', 'fl_5g', 'dt_ano_stts', 'idade'])\
                             .reset_index(drop=True)
# dados_droped

# %%
just_check_nan(dados_val)
# Out:
# Dados com NaN:
# dt_fim      442721
# citydesc    508149
# dtype: int64
#
# columns_with_nan.shape (2,)

# %%
# dados_val = dados_val.tail(dados_val.shape[0] -3000000).reset_index(drop=True)
dados_val['dt_ano_stts'] = dados_val['dt_ano_stts'].astype(np.int64).reset_index(drop=True)
dados_val['idade'] = np.asarray(dados_val['idade'], dtype = 'int16')
dados_val['fl_3g'] = np.asarray(dados_val['fl_3g'], dtype = 'int8')
dados_val['fl_4g'] = np.asarray(dados_val['fl_4g'], dtype = 'int8')
dados_val['fl_5g'] = np.asarray(dados_val['fl_5g'], dtype = 'int8')

# %%
# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(dados_val, 'trocou_aparelho')

# %%
X_teste = dados_val.drop('trocou_aparelho', axis=1)

y_teste = dados_val['trocou_aparelho']

# %%
preds_val = pipeline_ta.predict(X_teste)
preds_val
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
aucur(y_teste, preds_val)
# Out:
# AUC: 0.985

# %%
print(classification_report(y_teste, preds_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    442721
#            1       0.86      0.99      0.92     65428
#
#     accuracy                           0.98    508149
#    macro avg       0.93      0.98      0.95    508149
# weighted avg       0.98      0.98      0.98    508149

# %%
# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline_ta,
        X_teste,
        y_teste,
        display_labels=['Não Trocou', 'Trocou'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[431767  10954]
#  [   364  65064]]
# Normalized confusion matrix
# [[0.97525755 0.02474245]
#  [0.00556337 0.99443663]]

# %% [markdown]
# ***
# ***
# ***
# ## Captação dos clientes que foram previstos como Propensos a Fazer uma Compra

# %% [markdown]
# Base Original

# %%
X_val_ta['trocou_aparelho'] = y_val_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho')

# %% [markdown]
# Base Prevista

# %%
X_val_ta['trocou_aparelho_previsto'] = preds_ta
# X_val_ta

# %%
plt.figure(figsize=(8, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq(X_val_ta, 'trocou_aparelho_previsto')

# %%
X_val_ta['cpfidentifier'] = dados_droped['cpfidentifier']
# X_val_ta

# %%
X_val_ta['dt_inicio'] = dados_droped['dt_inicio']
# X_val_ta

# %%
X_val_ta['dt_fim'] = dados_droped['dt_fim']
X_val_ta['modelo'] = dados_droped['modelo']
X_val_ta['fabricante'] = dados_droped['fabricante']
X_val_ta['subscribermainofferdesc'] = dados_droped['subscribermainofferdesc']
X_val_ta['assignedchargeamount'] = dados_droped['assignedchargeamount']
X_val_ta['offertechnology'] = dados_droped['offertechnology']
X_val_ta['statedesc'] = dados_droped['statedesc']
X_val_ta['fl_3g'] = dados_droped['fl_3g']
X_val_ta['fl_4g'] = dados_droped['fl_4g']
X_val_ta['fl_5g'] = dados_droped['fl_5g']
X_val_ta['idade'] = dados_droped['idade']
X_val_ta['avg_msisdn'] = dados_droped['avg_msisdn']
X_val_ta['avg_cpf'] = dados_droped['avg_cpf']

X_val_ta
# Out:
#          avg_cpf  ranking  avg_msisdn  aging_aparelho  trocou_aparelho  \
# 971667      0.00        1         0.0              12                0
# 353521     11.00        1        14.0              14                1
# 859428      0.00        2         0.0              17                1
# 243443     10.67        1         8.0              16                1
# 814676      0.00        1         0.0              15                0
# ...          ...      ...         ...             ...              ...
# 1738834    22.00        1        22.0              16                0
# 949527      0.00        1         0.0              16                0
# 49944       0.00        1         0.0              16                0
# 1673440     0.00        1         0.0              15                0
# 2183829     0.00        1         0.0              17                0
#
#          trocou_aparelho_previsto  cpfidentifier   dt_inicio      dt_fim  \
# 971667                          0    10844133701  2021-09-26         NaN
# 353521                          1    39219712687  2020-12-30  2022-03-29
# 859428                          1    98605194715  2021-05-04         NaN
# 243443                          1     6884367652  2020-11-14  2022-04-13
# 814676                          0    15854209721  2021-07-09         NaN
# ...                           ...            ...         ...         ...
# 1738834                         0    18054353880  2021-05-31         NaN
# 949527                          0    14228421776  2021-05-24         NaN
# 49944                           0     7623820907  2021-06-19         NaN
# 1673440                         0     2944886851  2021-07-02         NaN
# 2183829                         0    17992860888  2021-05-12         NaN
#
#                                modelo  \
# 971667            REDMI 8 (M1908C3IG)
# 353521   GALAXY J5 2017 (SM-J530G DS)
# 859428       GALAXY S20 FE (SM-G780F)
# 243443       REDMI NOTE 8 (M1908C3JG)
# 814676                     L9 (5159J)
# ...                               ...
# 1738834                     NAIROBI20
# 949527                  REDMI NOTE 10
# 49944               K10 2017 (M250DS)
# 1673440  GALAXY J2 CORE (SM-J260M,DS)
# 2183829                   GALAXY A10S
#
#                                       fabricante subscribermainofferdesc  \
# 971667                                    XIAOMI    VIVO CONTROLE 11GB I
# 353521                                   SAMSUNG     VIVO CONTROLE 9GB I
# 859428                                   SAMSUNG   TITULAR VIVO_POS 30GB
# 243443                                    XIAOMI      VIVO CONTROLE 7GB_
# 814676                                       TCL   VIVO CONTROLE 6GB III
# ...                                          ...                     ...
# 1738834  Motorola Mobility LLC, a Lenovo Company      VIVO CONTROLE 7GB_
# 949527              Xiaomi Communications Co Ltd    VIVO CONTROLE 4GB IV
# 49944                                         LG    VIVO CONTROLE 4GB IV
# 1673440                                  SAMSUNG    VIVO CONTROLE 4GB IV
# 2183829                            Samsung Korea    VIVO CONTROLE 5GB II
#
#          assignedchargeamount offertechnology       statedesc  fl_3g  fl_4g  \
# 971667                  71.99        Controle  RIO DE JANEIRO      0      1
# 353521                  55.87        Controle    MINAS GERAIS      0      1
# 859428                 134.99        PostPaid  ESPIRITO SANTO      0      1
# 243443                  52.31        Controle    MINAS GERAIS      0      1
# 814676                  45.99        Controle  ESPIRITO SANTO      0      1
# ...                       ...             ...             ...    ...    ...
# 1738834                 53.35        Controle       SAO PAULO      0      1
# 949527                  32.49        Controle  RIO DE JANEIRO      0      1
# 49944                   34.99        Controle          PARANA      0      1
# 1673440                 32.49        Controle       SAO PAULO      0      1
# 2183829                 42.19        Controle       SAO PAULO      0      1
#
#          fl_5g  idade
# 971667       0     37
# 353521       0     60
# 859428       0     85
# 243443       0     37
# 814676       0     26
# ...        ...    ...
# 1738834      0     45
# 949527       0     22
# 49944        0     31
# 1673440      0     64
# 2183829      0     59
#
# [1222991 rows x 19 columns]

# %%
train_yhat_ta = pipeline_ta.predict(X_train_ta)
train_acc_ta = accuracy_score(y_train_ta, train_yhat_ta)
print('Training Acuracy:', train_acc_ta)
val_acc_ta = accuracy_score(y_val_ta, preds_ta)
print('Validation Acuracy:', val_acc_ta)
teste_acc_ta = accuracy_score(y_teste, preds_val)
print('Test Acuracy:', teste_acc_ta)
# Out:
# Training Acuracy: 0.9662761214105419
# Validation Acuracy: 0.9657168368369023
# Test Acuracy: 0.9777270052681398

# %% [markdown]
# ***
# ***
# ***
# ## Separando as bases para outro modelo

# %%
base_to_pred_month = X_val_ta[X_val_ta['trocou_aparelho_previsto'] == 1].reset_index(drop=True)
base_to_pred_month
# Out:
#         avg_cpf  ranking  avg_msisdn  aging_aparelho  trocou_aparelho  \
# 0         11.00        1        14.0              14                1
# 1          0.00        2         0.0              17                1
# 2         10.67        1         8.0              16                1
# 3         16.00        1        16.0              16                1
# 4         16.00        1         0.0              16                1
# ...         ...      ...         ...             ...              ...
# 437890    18.00        1        18.0              18                1
# 437891    16.00        1         0.0              16                1
# 437892     0.00        2         0.0              13                1
# 437893     0.00        2         0.0              16                1
# 437894    18.00        1        18.0              18                1
#
#         trocou_aparelho_previsto  cpfidentifier   dt_inicio      dt_fim  \
# 0                              1    39219712687  2020-12-30  2022-03-29
# 1                              1    98605194715  2021-05-04         NaN
# 2                              1     6884367652  2020-11-14  2022-04-13
# 3                              1    14101775729  2021-02-03  2022-06-13
# 4                              1    25447682827  2020-11-19  2022-03-23
# ...                          ...            ...         ...         ...
# 437890                         1      597215618  2020-10-17  2022-04-26
# 437891                         1    82951667604  2021-01-05  2022-05-29
# 437892                         1     4050899965  2021-09-11         NaN
# 437893                         1      292066694  2021-06-18         NaN
# 437894                         1    93706766949  2020-11-12  2022-05-12
#
#                                    modelo  \
# 0            GALAXY J5 2017 (SM-J530G DS)
# 1                GALAXY S20 FE (SM-G780F)
# 2                REDMI NOTE 8 (M1908C3JG)
# 3                                 GUAM+20
# 4       GALAXY ON7 REFRESH (SM-G611MT DS)
# ...                                   ...
# 437890                            LG-A275
# 437891                         GALAXY A11
# 437892           GALAXY A22 (SM-A225F,DS)
# 437893                           SGH-N105
# 437894          GALAXY A71 (SM-A715F,DSM)
#
#                                      fabricante  \
# 0                                       SAMSUNG
# 1                                       SAMSUNG
# 2                                        XIAOMI
# 3       Motorola Mobility LLC, a Lenovo Company
# 4                                       SAMSUNG
# ...                                         ...
# 437890                                       LG
# 437891                            Samsung Korea
# 437892                                  SAMSUNG
# 437893                                  SAMSUNG
# 437894                                  SAMSUNG
#
#                        subscribermainofferdesc  assignedchargeamount  \
# 0                          VIVO CONTROLE 9GB I                 55.87
# 1                        TITULAR VIVO_POS 30GB                134.99
# 2                           VIVO CONTROLE 7GB_                 52.31
# 3                           VIVO CONTROLE 7GB_                 51.52
# 4                           VIVO CONTROLE 7GB_                 61.99
# ...                                        ...                   ...
# 437890                      VIVO CONTROLE 7GB_                 52.31
# 437891                   VIVO CONTROLE 6GB III                 50.99
# 437892                       VIVO CONTROLE 4GB                 36.26
# 437893  Linha Adicional Vivo Pós Família 180GB                  0.00
# 437894             VIVO CONTROLE 8GB I - ANUAL                 78.15
#
#        offertechnology       statedesc  fl_3g  fl_4g  fl_5g  idade
# 0             Controle    MINAS GERAIS      0      1      0     60
# 1             PostPaid  ESPIRITO SANTO      0      1      0     85
# 2             Controle    MINAS GERAIS      0      1      0     37
# 3             Controle  RIO DE JANEIRO      0      1      0     23
# 4             Controle       SAO PAULO      0      1      0     45
# ...                ...             ...    ...    ...    ...    ...
# 437890        Controle    MINAS GERAIS      0      0      0     73
# 437891        Controle    MINAS GERAIS      0      1      0     60
# 437892        Controle          PARANA      0      1      0     40
# 437893        PostPaid    MINAS GERAIS      0      1      0     48
# 437894        Controle          PARANA      0      1      0     44
#
# [437895 rows x 19 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Definição do Target aging_aparelho

# %%
# define target
y = base_to_pred_month['aging_aparelho']

# %%
# contagem de aging
from collections import Counter

c = Counter(y)
c
# Out:
# Counter({14: 64160,
#          17: 56437,
#          16: 58970,
#          13: 68478,
#          18: 51971,
#          15: 61086,
#          12: 76793})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq_mes(base_to_pred_month, 'aging_aparelho')

# %% [markdown]
# ### Definicão das features

# %%
# define features
X = base_to_pred_month[['ranking', 'avg_msisdn', 'avg_cpf', 'assignedchargeamount']]

# X = base_to_pred_month[['fabricante', 'ranking', 'modelo', 'avg_msisdn', 'avg_cpf',
#                         'assignedchargeamount']]

X
# Out:
#         ranking  avg_msisdn  avg_cpf  assignedchargeamount
# 0             1        14.0    11.00                 55.87
# 1             2         0.0     0.00                134.99
# 2             1         8.0    10.67                 52.31
# 3             1        16.0    16.00                 51.52
# 4             1         0.0    16.00                 61.99
# ...         ...         ...      ...                   ...
# 437890        1        18.0    18.00                 52.31
# 437891        1         0.0    16.00                 50.99
# 437892        2         0.0     0.00                 36.26
# 437893        2         0.0     0.00                  0.00
# 437894        1        18.0    18.00                 78.15
#
# [437895 rows x 4 columns]

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s = (X.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables: ", len(object_cols))
print(object_cols)
# Out:
# Categorical variables:  0
# []

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols))
print(numerical_cols)
# Out:
# Numerical variables:  4
# ['ranking', 'avg_msisdn', 'avg_cpf', 'assignedchargeamount']

# %% [markdown]
# ***
# ## Modelagem

# %%
# Dividindo as features em dados de treino e teste - 70% para dados de treinamento e 30% para dados de teste
X_train, X_val, y_train, y_val = train_test_split(X, 
                                                  y, 
                                                  test_size=0.5, 
                                                  random_state = 2048)

# Pré-processamento para Dados Numéricos
numerical_transformer = Pipeline([
                                  ('scaler', StandardScaler())
                                 ])

# Pré-processamento para Dados Categóricos
categorical_transformer = Pipeline([
                                    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                   ])

# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor = ColumnTransformer(transformers=[
                                                ('num', numerical_transformer, numerical_cols),
                                                ('cat', categorical_transformer, object_cols)
                                              ], n_jobs=-1)

pipeline = Pipeline(steps=[
                            ('preprocessor', preprocessor),
                            ('smote', SMOTE(random_state=42, n_jobs=-1)),   # equilibrar
                            ('model', XGBClassifier(random_state=2048, n_jobs=-1))
                          ])

# Preprocessing of training data, fit model 
pipeline.fit(X_train, y_train)

# Predictions
#preds = np.asarray(pipeline.predict(X_val), dtype = 'int')
preds = pipeline.predict(X_val)
# Out:
# [14:32:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ### Save Model

# %%
# Use pickle to save model for next usage.
filename2 = 'model_aging.pk'
with open('./'+filename2, 'wb') as file:
    pickle.dump(pipeline, file)

# %%
c_train = Counter(y_train)
c_train
# Out:
# Counter({14: 32055,
#          12: 38234,
#          16: 29451,
#          13: 34412,
#          18: 25904,
#          15: 30673,
#          17: 28218})

# %%
c_val = Counter(y_val)
c_val
# Out:
# Counter({16: 29519,
#          13: 34066,
#          18: 26067,
#          14: 32105,
#          12: 38559,
#          17: 28219,
#          15: 30413})

# %%
c_preds = Counter(preds)
c_preds
# Out:
# Counter({13: 30850,
#          18: 27450,
#          14: 30508,
#          15: 28989,
#          12: 42322,
#          16: 28804,
#          17: 30025})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq_mes(base_to_pred_month, 'aging_aparelho')

# %% [markdown]
# ***
# ## Métricas

# %%
# # Multiply by -1 since sklearn calculates *negative* MAE
# scores = -1 * cross_val_score(pipeline, X_val, y_val,
#                               cv=5, n_jobs=-1, verbose=2,
#                               scoring='f1')

# print("MAE scores:\n", scores)

# %%
y_probas = pipeline.predict_proba(X_val)
plot_roc(y_val, y_probas, plot_micro = False, plot_macro = False, figsize = (8, 8))
plt.show()

# %%
print(classification_report(y_val, preds))
# Out:
#               precision    recall  f1-score   support
#
#           12       0.76      0.84      0.80     38559
#           13       0.85      0.77      0.81     34066
#           14       0.83      0.79      0.81     32105
#           15       0.83      0.79      0.81     30413
#           16       0.81      0.79      0.80     29519
#           17       0.75      0.80      0.78     28219
#           18       0.80      0.84      0.82     26067
#
#     accuracy                           0.80    218948
#    macro avg       0.81      0.80      0.80    218948
# weighted avg       0.81      0.80      0.80    218948

# %%
cm_df = pd.DataFrame(confusion_matrix(y_val, preds),
                     index = sorted(Counter(y_val)),
                     columns = sorted(Counter(preds)))
cm_df
# Out:
#        12     13     14     15     16     17     18
# 12  32288   1822   1250    809    573   1079    738
# 13   2923  26243   1653   1068    550    970    659
# 14   1641    713  25290   1311   1432   1120    598
# 15   1338    563    831  24084   1610   1311    676
# 16   1230    537    620    726  23391   1880   1135
# 17   1566    539    456    593    706  22658   1701
# 18   1336    433    408    398    542   1007  21943

# %% [markdown]
# ## Plot non-normalized confusion matrix

# %%
y.unique()
# Out:
# array([14, 17, 16, 13, 18, 15, 12])

# %%
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline,
        X_val,
        y_val,
        display_labels=y.unique(),
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(25, 25))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[32288  1822  1250   809   573  1079   738]
#  [ 2923 26243  1653  1068   550   970   659]
#  [ 1641   713 25290  1311  1432  1120   598]
#  [ 1338   563   831 24084  1610  1311   676]
#  [ 1230   537   620   726 23391  1880  1135]
#  [ 1566   539   456   593   706 22658  1701]
#  [ 1336   433   408   398   542  1007 21943]]
# Normalized confusion matrix
# [[0.83736611 0.04725226 0.03241785 0.02098083 0.01486034 0.02798309
#   0.0191395 ]
#  [0.08580403 0.77035754 0.04852345 0.03135091 0.01614513 0.02847414
#   0.0193448 ]
#  [0.05111353 0.02220838 0.78772777 0.04083476 0.04460364 0.03488553
#   0.01862638]
#  [0.04399434 0.01851182 0.02732384 0.7918982  0.05293789 0.04310657
#   0.02222734]
#  [0.04166808 0.01819167 0.02100342 0.02459433 0.79240489 0.06368779
#   0.03844981]
#  [0.05549452 0.01910061 0.01615933 0.02101421 0.0250186  0.80293419
#   0.06027854]
#  [0.05125254 0.01661104 0.01565197 0.01526835 0.02079257 0.03863122
#   0.8417923 ]]

# %% [markdown]
# ***
# ## Mesclando resultados com tabela

# %% [markdown]
# ### Com a base de validação

# %%
X_val['aging_aparelho'] = y_val
# X_val

# %%
X_val['previsto'] = preds
# X_val

# %%
X_val['cpfidentifier'] = base_to_pred_month['cpfidentifier']
# X_val

# %%
X_val['dt_inicio'] = base_to_pred_month['dt_inicio']
# X_val

# %%
X_val['dt_fim'] = base_to_pred_month['dt_fim']
# X_val

# %% [markdown]
# ## Calculando data prevista

# %%
X_val['dt_fim_previsto'] = ((pd.to_datetime(X_val['dt_inicio']).dt.to_period('M')) + X_val['previsto'])
X_val
# Out:
#         ranking  avg_msisdn  avg_cpf  assignedchargeamount  aging_aparelho  \
# 86914         2         0.0     0.00                109.99              16
# 183006        1         9.5    10.75                  0.00              16
# 100058        1         7.0     7.00                 32.49              13
# 3778          1         0.0    13.00                 60.87              13
# 337396        1        18.0    18.00                 67.60              18
# ...         ...         ...      ...                   ...             ...
# 274403        1         9.0     9.00                 51.52              17
# 209141        1        17.0    20.50                235.13              17
# 66643         1        18.0    18.00                 60.99              18
# 20819         1         7.5    14.25                 51.52              15
# 96680         1        15.0    15.00                 37.49              15
#
#         previsto  cpfidentifier   dt_inicio      dt_fim dt_fim_previsto
# 86914         13     1176345818  2021-06-06         NaN         2022-07
# 183006        18    98508571704  2020-10-04  2022-02-24         2022-04
# 100058        14    30314834800  2021-03-04  2022-04-06         2022-05
# 3778          13    93040474634  2021-02-06  2022-04-01         2022-03
# 337396        18    37996781826  2020-08-10  2022-02-17         2022-02
# ...          ...            ...         ...         ...             ...
# 274403        18    91182964753  2020-09-02  2022-02-08         2022-03
# 209141        17    14276010896  2021-01-14  2022-06-18         2022-06
# 66643         18    10931927714  2020-11-03  2022-05-16         2022-05
# 20819         15     3444013752  2021-02-22  2022-06-10         2022-05
# 96680         15     8547480838  2020-11-25  2022-02-25         2022-02
#
# [218948 rows x 10 columns]

# %%
c_preds
# Out:
# Counter({13: 30850,
#          18: 27450,
#          14: 30508,
#          15: 28989,
#          12: 42322,
#          16: 28804,
#          17: 30025})

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq_mes(X_val, 'aging_aparelho')

# %%
plt.figure(figsize=(20, 6))

# plot_feature_freq(df, feature, qt_cat)
plot_feature_freq_mes(X_val, 'previsto')

# %% [markdown]
# ***
# ***
# ***
# ### Teste com outra base

# %%
dados_val_mes = dados_val[dados_val['trocou_aparelho'] == 1].reset_index(drop=True)

X_teste_mes = dados_val_mes.drop(['trocou_aparelho', 'aging_aparelho'], axis=1)

y_teste_mes = dados_val_mes['aging_aparelho']

# %%
preds_val_mes = pipeline.predict(X_teste_mes)
preds_val_mes
# Out:
# array([13, 14, 12, ..., 12, 17, 15])

# %%
y_probas = pipeline.predict_proba(X_teste_mes)
plot_roc(y_teste_mes, y_probas, plot_micro = False, plot_macro = False, figsize = (8, 8))
plt.show()

# %%
print(classification_report(y_teste_mes, preds_val_mes))
# Out:
#               precision    recall  f1-score   support
#
#           12       0.98      0.95      0.97     10433
#           13       0.97      0.96      0.97      9902
#           14       0.96      0.95      0.96      9410
#           15       0.96      0.95      0.96      9312
#           16       0.96      0.96      0.96      9039
#           17       0.96      0.97      0.96      8712
#           18       0.95      0.99      0.97      8620
#
#     accuracy                           0.96     65428
#    macro avg       0.96      0.96      0.96     65428
# weighted avg       0.96      0.96      0.96     65428

# %%
dados_val_mes['dt_ano_stts'].unique()
# Out:
# array([2016, 2018, 2019, 2017, 2015, 2014, 2012, 2013, 2021, 2011, 2010,
#        2009])

# %%
# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix, without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        pipeline,
        X_teste_mes,
        y_teste_mes,
        display_labels=y_teste_mes.unique(),
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.figure(figsize=(18, 18))
plt.show()
# Out:
# Confusion matrix, without normalization
# [[9933  263  127   64   27   11    8]
#  [  32 9551  168   89   51   10    1]
#  [  36   27 8983  196  109   50    9]
#  [  45   11   39 8891  165  104   57]
#  [  31    8   12    6 8718  161  103]
#  [  21    3    1    8   21 8420  238]
#  [  53   10   17   10   17   11 8502]]
# Normalized confusion matrix
# [[9.52075146e-01 2.52084731e-02 1.21729129e-02 6.13438129e-03
#   2.58794211e-03 1.05434678e-03 7.66797661e-04]
#  [3.23167037e-03 9.64552616e-01 1.69662694e-02 8.98808322e-03
#   5.15047465e-03 1.00989699e-03 1.00989699e-04]
#  [3.82571732e-03 2.86928799e-03 9.54622742e-01 2.08289054e-02
#   1.15834219e-02 5.31349628e-03 9.56429330e-04]
#  [4.83247423e-03 1.18127148e-03 4.18814433e-03 9.54789519e-01
#   1.77190722e-02 1.11683849e-02 6.12113402e-03]
#  [3.42958292e-03 8.85053656e-04 1.32758048e-03 6.63790242e-04
#   9.64487222e-01 1.78117048e-02 1.13950658e-02]
#  [2.41046832e-03 3.44352617e-04 1.14784206e-04 9.18273646e-04
#   2.41046832e-03 9.66483012e-01 2.73186410e-02]
#  [6.14849188e-03 1.16009281e-03 1.97215777e-03 1.16009281e-03
#   1.97215777e-03 1.27610209e-03 9.86310905e-01]]

# %%
train_yhat = pipeline.predict(X_train)
train_acc = accuracy_score(y_train, train_yhat)
print('Training Acuracy:', train_acc)
val_acc = accuracy_score(y_val, preds)
print('Validation Acuracy:', val_acc)
teste_acc = accuracy_score(y_teste, preds_val)
print('Test Acuracy:', teste_acc)
# Out:
# Training Acuracy: 0.8173256541537449
# Validation Acuracy: 0.8033734037305662
# Test Acuracy: 0.9777270052681398
