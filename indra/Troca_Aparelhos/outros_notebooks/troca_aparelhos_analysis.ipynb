# %%
## data
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.relativedelta import relativedelta
from unicodedata import normalize

## vis
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from IPython.display import display, HTML

## modelo
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

## alertas
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***
# ## Coleta de dados

# %%
PATH = "../datasets/"

# %%
FILE = "tabletest39043283878.xlsx"
dados = pd.read_excel(PATH + FILE)

dados
# Out:
#        a.msisdn            a.imsi           a.tac      a.dt_inicio    \
# 0     5511910004238     724102902565740     35414810   2021-10-29
# 1     5511910951409     724101996552176     35421087   2022-01-30
# 2     5511910004238     724102302106781     35421087   2022-04-28
# 3     5511910004238     724102302106781     86583405   2022-05-24
#
#      a.dt_fim      a.aging_aparelho     a.cat_aparelho    \
# 0   2022-04-28                      5                  0
# 1   NULL                            8                  0
# 2   2022-05-24                      0                  0
# 3   NULL                            4                  0
#
#     a.trocou_aparelho                   a.fabricante                 \
# 0                     1   Motorola Mobility LLC, a Lenovo Company
# 1                     0   GREYMARKET
# 2                     1   GREYMARKET
# 3                     1   XIAOMI
#
#           a.modelo          ...   a.subscriberstatuskey    \
# 0   TROIKA                  ...   A
# 1   HANDSET                 ...   A
# 2   HANDSET                 ...   A
# 3   REDMI 9C (M2006C3MG)    ...   A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 1   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
# 3   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc    a.assignedchargeamount    a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                            32.49          0
# 1   VIVO CONTROLE 4GB                               37.61          0
# 2   VIVO CONTROLE 4GB IV                            32.49          0
# 3   VIVO CONTROLE 4GB IV                            32.49          0
#
#    a.fl_4g    a.fl_5g    a.dt_ano_stts
# 0          1          0             2019
# 1          1          0             2021
# 2          1          0             2021
# 3          1          0             2020
#
# [4 rows x 26 columns]

# %% [markdown]
# ### Limpeza dos dados

# %%
def just_check_nan(df):
    # Check NaN Pandas and Numpy
    missing_val_count_by_column = (df.isna().sum())

    columns_with_nan = missing_val_count_by_column[missing_val_count_by_column > 0]
    print('Dados com NaN:')
    print(columns_with_nan)
    print('')
    print('columns_with_nan.shape', columns_with_nan.shape)
    print('')

# %%
just_check_nan(dados)
# Out:
# Dados com NaN:
# Series([], dtype: int64)
#
# columns_with_nan.shape (0,)

# %% [markdown]
# ***
# ## Analise dos dados

# %%
dados.columns
# Out:
# Index(['    a.msisdn    ', '      a.imsi      ', '   a.tac   ',
#        ' a.dt_inicio  ', '  a.dt_fim   ', ' a.aging_aparelho  ',
#        ' a.cat_aparelho  ', ' a.trocou_aparelho  ',
#        '               a.fabricante               ', '       a.modelo        ',
#        '      a.imei      ', ' a.ranking  ', ' a.cpfidentifier  ',
#        ' a.subscriberkey  ', ' a.customerkey  ', ' a.customersubtypedesc  ',
#        ' a.subscriberstatuskey  ', ' a.offertechnology  ', ' a.citydesc  ',
#        ' a.statedesc  ', ' a.subscribermainofferdesc  ',
#        ' a.assignedchargeamount  ', ' a.fl_3g  ', ' a.fl_4g  ', ' a.fl_5g  ',
#        ' a.dt_ano_stts  '],
#       dtype='object')

# %%
# dados_analysis = ProfileReport(dados, title="Profiling Report", progress_bar=False, infer_dtypes=False)
# profile_td_html = dados_analysis.to_html()

# %%
# display(HTML(profile_td_html))

# %% [markdown]
# ***
# ## Exploração dos dados

# %% [markdown]
# ### seleção de features

# %%
# define features
X = dados[[' a.cat_aparelho  ', ' a.trocou_aparelho  ',
           '               a.fabricante               ', '       a.modelo        ',
           ' a.ranking  ', 
           ' a.customersubtypedesc  ', ' a.subscriberstatuskey  ', 
           ' a.offertechnology  ', 
           ' a.citydesc  ', ' a.statedesc  ', ' a.subscribermainofferdesc  ',
           ' a.assignedchargeamount  ', ' a.fl_3g  ', ' a.fl_4g  ', ' a.fl_5g  ',
           ' a.dt_ano_stts  ']]
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 1   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
# 3   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 1   VIVO CONTROLE 4GB                                37.61           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
# 3   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts
# 0           1           0              2019
# 1           1           0              2021
# 2           1           0              2021
# 3           1           0              2020

# %% [markdown]
# #### Variaveis Categoricas

# %%
# Get list of categorical variables
s = (X.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables: ", len(object_cols))
print(object_cols)
# Out:
# Categorical variables:  8
# ['               a.fabricante               ', '       a.modelo        ', ' a.customersubtypedesc  ', ' a.subscriberstatuskey  ', ' a.offertechnology  ', ' a.citydesc  ', ' a.statedesc  ', ' a.subscribermainofferdesc  ']

# %% [markdown]
# #### Variaveis Numéricas

# %%
# Criando uma lista de variaveis numéricas
numerical_cols = [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]
print("Numerical variables: ", len(numerical_cols))
print(numerical_cols)
# Out:
# Numerical variables:  8
# [' a.cat_aparelho  ', ' a.trocou_aparelho  ', ' a.ranking  ', ' a.assignedchargeamount  ', ' a.fl_3g  ', ' a.fl_4g  ', ' a.fl_5g  ', ' a.dt_ano_stts  ']

# %% [markdown]
# ***
# ## Mostrando a correlação entre os dados numéricos

# %%
# corr = X.corr()

# fig, ax = plt.subplots(figsize=(20,10))
# sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, annot = True)

# %% [markdown]
# ***
# ## Definição do Target

# %%
# define target
y = dados[' a.aging_aparelho  ']
y
# Out:
# 0    5
# 1    8
# 2    0
# 3    4
# Name:  a.aging_aparelho  , dtype: int64

# %% [markdown]
# ***
# ## Modelagem

# %%
# contagem de aging
from collections import Counter

c = Counter(y)
c
# Out:
# Counter({5: 1, 8: 1, 0: 1, 4: 1})

# %%
# features de treinamento
X.columns
# Out:
# Index([' a.cat_aparelho  ', ' a.trocou_aparelho  ',
#        '               a.fabricante               ', '       a.modelo        ',
#        ' a.ranking  ', ' a.customersubtypedesc  ', ' a.subscriberstatuskey  ',
#        ' a.offertechnology  ', ' a.citydesc  ', ' a.statedesc  ',
#        ' a.subscribermainofferdesc  ', ' a.assignedchargeamount  ',
#        ' a.fl_3g  ', ' a.fl_4g  ', ' a.fl_5g  ', ' a.dt_ano_stts  '],
#       dtype='object')

# %%
# Dividindo as features em dados de treino e teste - 70% para dados de treinamento e 30% para dados de teste
X_train, X_val, y_train, y_val = train_test_split(X, 
                                                  y, 
                                                  test_size=0.30, 
                                                  random_state = 2048)

# %%
# Pré-processamento para Dados Numéricos
numerical_transformer = Pipeline([
                                  ('scaler', StandardScaler())
                                 ])

# %%
# Pré-processamento para Dados Categóricos
categorical_transformer = Pipeline([
                                    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
                                   ])

# %%
# Pré-processamento de pacote de dados numéricos e categóricos
preprocessor = ColumnTransformer(transformers=[
                                                ('num', numerical_transformer, numerical_cols),
                                                ('cat', categorical_transformer, object_cols)
                                              ], n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
                            ('preprocessor', preprocessor),
                            ('model', RandomForestRegressor(random_state=2048, n_jobs=-1))
                          ])

# %%
# Preprocessing of training data, fit model 
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   [' a.cat_aparelho  ',
#                                                    ' a.trocou_aparelho  ',
#                                                    ' a.ranking  ',
#                                                    ' a.assignedchargeamount  ',
#                                                    ' a.fl_3g  ', ' a.fl_4g  ',
#                                                    ' a.fl_5g  ',
#                                                    ' a.dt_ano_stts  ']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['               '
#                                                    'a.fabricante               ',
#                                                    '       a.modelo        ',
#                                                    ' a.customersubtypedesc  ',
#                                                    ' a.subscriberstatuskey  ',
#                                                    ' a.offertechnology  ',
#                                                    ' a.citydesc  ',
#                                                    ' a.statedesc  ',
#                                                    ' '
#                                                    'a.subscribermainofferdesc  '])])),
#                 ('model', RandomForestRegressor(n_jobs=-1, random_state=2048))])

# %%
# Preprocessing of validation data, get predictions
preds = np.asarray(pipeline.predict(X_val), dtype = 'int')

# %%
preds
# Out:
# array([5, 6])

# %% [markdown]
# ***
# ## Métricas

# %% [markdown]
# ***
# ## Mesclando resultados com tabela

# %% [markdown]
# ### Com a base de validação

# %%
X_val['a.aging_aparelho'] = y_val

# %%
X_val['previsto'] = preds
X_val
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 2                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 2   GREYMARKET                                  HANDSET
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 2             2   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto
# 0           1           0              2019                 5         5
# 2           1           0              2021                 0         6

# %%
X_val[' a.cpfidentifier  '] = dados[' a.cpfidentifier  ']
X_val
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 2                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 2   GREYMARKET                                  HANDSET
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 2             2   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 2           1           0              2021                 0         6
#
#     a.cpfidentifier
# 0         39043283878
# 2         39043283878

# %%
X_val[' a.dt_inicio  '] = dados[' a.dt_inicio  ']
X_val
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 2                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 2   GREYMARKET                                  HANDSET
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 2             2   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 2           1           0              2021                 0         6
#
#     a.cpfidentifier     a.dt_inicio
# 0         39043283878   2021-10-29
# 2         39043283878   2022-04-28

# %%
X_val['  a.dt_fim   '] = dados['  a.dt_fim   ']
X_val
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 2                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 2   GREYMARKET                                  HANDSET
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 2             2   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    ...  \
# 0   Controle              NULL           SAO PAULO      ...
# 2   Controle              NULL           SAO PAULO      ...
#
#    a.assignedchargeamount     a.fl_3g     a.fl_4g     a.fl_5g    \
# 0                     32.49           0           1           0
# 2                     32.49           0           1           0
#
#     a.dt_ano_stts    a.aging_aparelho  previsto   a.cpfidentifier    \
# 0              2019                 5         5         39043283878
# 2              2021                 0         6         39043283878
#
#     a.dt_inicio      a.dt_fim
# 0   2021-10-29      2022-04-28
# 2   2022-04-28      2022-05-24
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Calculando data prevista

# %%
X_val['a.dt_fim_previsto'] = ((pd.to_datetime(X_val[' a.dt_inicio  ']).dt.to_period('M')) + X_val['previsto']).dt.to_timestamp()
X_val
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 2                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 2   GREYMARKET                                  HANDSET
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 2             2   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    ...  a.fl_3g    \
# 0   Controle              NULL           SAO PAULO      ...          0
# 2   Controle              NULL           SAO PAULO      ...          0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 2           1           0              2021                 0         6
#
#     a.cpfidentifier     a.dt_inicio      a.dt_fim    a.dt_fim_previsto
# 0         39043283878   2021-10-29      2022-04-28          2022-03-01
# 2         39043283878   2022-04-28      2022-05-24          2022-10-01
#
# [2 rows x 22 columns]

# %% [markdown]
# ***
# ## Teste com a base toda

# %%
# Preprocessing of validation data, get predictions
preds_Test = np.asarray(pipeline.predict(X), dtype = 'int')
preds_Test
# Out:
# array([5, 7, 6, 5])

# %%
X['a.aging_aparelho'] = y

# %%
X['previsto'] = preds_Test
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 1   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
# 3   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 1   VIVO CONTROLE 4GB                                37.61           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
# 3   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto
# 0           1           0              2019                 5         5
# 1           1           0              2021                 8         7
# 2           1           0              2021                 0         6
# 3           1           0              2020                 4         5

# %%
X[' a.cpfidentifier  '] = dados[' a.cpfidentifier  ']
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 1   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
# 3   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 1   VIVO CONTROLE 4GB                                37.61           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
# 3   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 1           1           0              2021                 8         7
# 2           1           0              2021                 0         6
# 3           1           0              2020                 4         5
#
#     a.cpfidentifier
# 0         39043283878
# 1         39043283878
# 2         39043283878
# 3         39043283878

# %%
X[' a.dt_inicio  '] = dados[' a.dt_inicio  ']
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    \
# 0   Controle              NULL           SAO PAULO
# 1   Controle              NULL           SAO PAULO
# 2   Controle              NULL           SAO PAULO
# 3   Controle              NULL           SAO PAULO
#
#     a.subscribermainofferdesc     a.assignedchargeamount     a.fl_3g    \
# 0   VIVO CONTROLE 4GB IV                             32.49           0
# 1   VIVO CONTROLE 4GB                                37.61           0
# 2   VIVO CONTROLE 4GB IV                             32.49           0
# 3   VIVO CONTROLE 4GB IV                             32.49           0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 1           1           0              2021                 8         7
# 2           1           0              2021                 0         6
# 3           1           0              2020                 4         5
#
#     a.cpfidentifier     a.dt_inicio
# 0         39043283878   2021-10-29
# 1         39043283878   2022-01-30
# 2         39043283878   2022-04-28
# 3         39043283878   2022-05-24

# %%
X['  a.dt_fim   '] = dados['  a.dt_fim   ']
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    ...  \
# 0   Controle              NULL           SAO PAULO      ...
# 1   Controle              NULL           SAO PAULO      ...
# 2   Controle              NULL           SAO PAULO      ...
# 3   Controle              NULL           SAO PAULO      ...
#
#    a.assignedchargeamount     a.fl_3g     a.fl_4g     a.fl_5g    \
# 0                     32.49           0           1           0
# 1                     37.61           0           1           0
# 2                     32.49           0           1           0
# 3                     32.49           0           1           0
#
#     a.dt_ano_stts    a.aging_aparelho  previsto   a.cpfidentifier    \
# 0              2019                 5         5         39043283878
# 1              2021                 8         7         39043283878
# 2              2021                 0         6         39043283878
# 3              2020                 4         5         39043283878
#
#     a.dt_inicio      a.dt_fim
# 0   2021-10-29      2022-04-28
# 1   2022-01-30      NULL
# 2   2022-04-28      2022-05-24
# 3   2022-05-24      NULL
#
# [4 rows x 21 columns]

# %% [markdown]
# ## Calculando data prevista

# %%
X['a.dt_fim_previsto'] = ((pd.to_datetime(X[' a.dt_inicio  ']).dt.to_period('M')) + X['previsto']).dt.to_timestamp()
X
# Out:
#     a.cat_aparelho     a.trocou_aparelho    \
# 0                  0                     1
# 1                  0                     0
# 2                  0                     1
# 3                  0                     1
#
#                   a.fabricante                        a.modelo          \
# 0   Motorola Mobility LLC, a Lenovo Company     TROIKA
# 1   GREYMARKET                                  HANDSET
# 2   GREYMARKET                                  HANDSET
# 3   XIAOMI                                      REDMI 9C (M2006C3MG)
#
#     a.ranking     a.customersubtypedesc     a.subscriberstatuskey    \
# 0             1   Pessoa Física             A
# 1             1   Pessoa Física             A
# 2             2   Pessoa Física             A
# 3             3   Pessoa Física             A
#
#     a.offertechnology     a.citydesc     a.statedesc    ...  a.fl_3g    \
# 0   Controle              NULL           SAO PAULO      ...          0
# 1   Controle              NULL           SAO PAULO      ...          0
# 2   Controle              NULL           SAO PAULO      ...          0
# 3   Controle              NULL           SAO PAULO      ...          0
#
#     a.fl_4g     a.fl_5g     a.dt_ano_stts    a.aging_aparelho  previsto  \
# 0           1           0              2019                 5         5
# 1           1           0              2021                 8         7
# 2           1           0              2021                 0         6
# 3           1           0              2020                 4         5
#
#     a.cpfidentifier     a.dt_inicio      a.dt_fim    a.dt_fim_previsto
# 0         39043283878   2021-10-29      2022-04-28          2022-03-01
# 1         39043283878   2022-01-30      NULL                2022-08-01
# 2         39043283878   2022-04-28      2022-05-24          2022-10-01
# 3         39043283878   2022-05-24      NULL                2022-10-01
#
# [4 rows x 22 columns]
